# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
import pyhive
from pyhive import hive

# %%
spark = SparkSession.builder.appName('CARGA').getOrCreate()
spark
# Out:
# 23/11/21 08:41:27 WARN Utils: Your hostname, rodrigo-Nitro-AN515-54 resolves to a loopback address: 127.0.1.1; using 192.168.0.112 instead (on interface wlp8s0)
# 23/11/21 08:41:27 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/11/21 08:41:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.112:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>CARGA</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# - Comentários

# %%
df_comentarios = spark.read \
    .parquet('hdfs://localhost:9000/projeto/datalake_youtube/comentarios.parquet')
df_comentarios.show(truncate=False)
# Out:
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/home/rodrigo/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/venv/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/home/rodrigo/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/venv/lib/python3.10/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/usr/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/rodrigo/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/notebooks/carga_hive.ipynb Célula 4 line 2
#       <a href='vscode-notebook-cell:/home/rodrigo/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/notebooks/carga_hive.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df_comentarios = spark.read \
# ----> <a href='vscode-notebook-cell:/home/rodrigo/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/notebooks/carga_hive.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a>     .parquet('hdfs://localhost:9000/projeto/datalake_youtube/comentarios.parquet')
#       <a href='vscode-notebook-cell:/home/rodrigo/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/notebooks/carga_hive.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> df_comentarios.show(truncate=False)
#
# File ~/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/venv/lib/python3.10/site-packages/pyspark/sql/readwriter.py:364, in DataFrameReader.parquet(self, *paths, **options)
#     353 int96RebaseMode = options.get("int96RebaseMode", None)
#     354 self._set_opts(
#     355     mergeSchema=mergeSchema,
#     356     pathGlobFilter=pathGlobFilter,
#    (...)
#     361     int96RebaseMode=int96RebaseMode,
#     362 )
# --> 364 return self._df(self._jreader.parquet(_to_seq(self._spark._sc, paths)))
#
# File ~/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/venv/lib/python3.10/site-packages/py4j/java_gateway.py:1320, in JavaMember.__call__(self, *args)
#    1313 args_command, temp_args = self._build_args(*args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
# -> 1320 answer = self.gateway_client.send_command(command)
#    1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#
# File ~/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/venv/lib/python3.10/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File ~/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/venv/lib/python3.10/site-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
colunas = df_comentarios.columns

# %%
for coluna in colunas:  
    df_comentarios.groupBy(coluna).count().orderBy('count', ascending=False).show()
# Out:
# +--------------------+-----+
# |       ID_COMENTARIO|count|
# +--------------------+-----+
# |Ugx-CBADFfLN2LXHG...|    4|
# |UgyLcZQQ-UXT8opnn...|    4|
# |UgyhIODhwnwl2v-2r...|    4|
# |UgwZnmXg3QTVsBHX_...|    4|
# |UgxagHpwgXsn-uUmX...|    4|
# |Ugx6VSRc7MrsQJaRv...|    4|
# |Ugz9FSLqB9pcG6iLr...|    4|
# |Ugwtb0MSIh1mdFeTh...|    4|
# |UgwXtYzBUR23fDdzC...|    4|
# |UgwZib0WRyS_ty6mW...|    4|
# |Ugyitahmf0gm4Evwd...|    4|
# |Ugwg5lGVRWse5KY0E...|    4|
# |Ugwxut6XxqmWMDOxM...|    2|
# |UgwJzcgdd6A1IVIU1...|    2|
# |Ugz1SCTGyUbT4jI1l...|    2|
# |UgzwUwBVh_G0vXEvA...|    2|
# |Ugy1nOWB9dfkABwT3...|    2|
# |UgxmagRai22giD5Rv...|    2|
# |UgwCiwEsoDIQXU5HW...|    2|
# |Ugw6IepG-8NxZxYFg...|    2|
# +--------------------+-----+
# only showing top 20 rows
# +--------------------+-----+
# |    TEXTO_COMENTARIO|count|
# +--------------------+-----+
# |            Avançado|   24|
# |    Horizonte Delta.|   20|
# |                   ❤|   12|
# |            Finanças|   12|
# |          Finalmente|   10|
# |Fala galera!\r<br...|    9|
# |                 top|    8|
# |                 Top|    8|
# |          Muito bom!|    7|
# |Veja mais vídeos ...|    7|
# |            Consulta|    7|
# |Alguém sabe me di...|    6|
# |Critica construti...|    6|
# |Gostaria muito de...|    6|
# |           Boa noite|    6|
# |➡Lembre de deixar...|    6|
# |            Primeiro|    6|
# |Bom vídeo Morpheu...|    6|
# |          Vou baixar|    6|
# |A lá ele!!<a href...|    6|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
# |             ASSUNTO|count|
# +--------------------+-----+
# |assunto_cities_sk...| 3879|
# |assunto_cities_sk...| 3826|
# |assunto_python_an...| 1111|
# |    assunto_power_bi|  927|
# +--------------------+-----+
#
# +--------------------+-----+
# |            ID_CANAL|count|
# +--------------------+-----+
# |UCrOH1V-FyMunBIMr...| 3338|
# |UCe9jrI0YQ5SM6h5Q...|  899|
# |UCfY4ggUDPeecGSCN...|  616|
# |UCoTIpyf8_RGzJ1LP...|  510|
# |UCrUcdH_bCfX77xpX...|  442|
# |UCayiH2Y5JBEOSubq...|  352|
# |UCEQ12yB8QLw9pVOY...|  337|
# |UCrxFTbIV_8sUVJ59...|  268|
# |UCDGo_s0I-2JpO3o3...|  256|
# |UCHQun4keJGrj8RqD...|  240|
# |UCcinq1ymmAmhFZzy...|  174|
# |UC_Fk7hHbl7vv_7K8...|  150|
# |UCcuLEJUZy4jo9iFv...|  141|
# |UC1mk6EtfMjxR4eEZ...|  132|
# |UCw0leRmeaX7R_9BD...|  128|
# |UCaj6FB2mFZ2T9a61...|  102|
# |UCxIMGC-GmZ2pXE_j...|   98|
# |UCCe4Be21OPPltTTI...|   98|
# |UCI0hxWIdIqSuX_Mc...|   95|
# |UCYEb5mbKZ5JJzN0x...|   68|
# +--------------------+-----+
# only showing top 20 rows
#
# +-----------+-----+
# |   ID_VIDEO|count|
# +-----------+-----+
# |wCLSZxLfUAk|  702|
# |L17Ox3uFAdo|  510|
# |ShVmR8yQweU|  432|
# |vzzeZU07rmo|  430|
# |6RgEh-9KAgY|  340|
# |V_sQAmzhrdE|  337|
# |totHMIv6_hI|  300|
# |9SGBZ7GE5EA|  298|
# |QwXP79P4xS0|  274|
# |vy-upTpchig|  274|
# |ND4pLB1ZRyM|  268|
# |TBZuVHi3QdM|  222|
# |xSAyLQ9h22k|  218|
# |KfzZNkdyeEs|  208|
# |EuUoqqXA6jI|  184|
# |ANa7la0wqNc|  184|
# |OH-qmlI4A3o|  150|
# |up4KrHrRwLY|  138|
# |dRzwiPwGH_M|  126|
# |h4rXTjnHu4A|  122|
# +-----------+-----+
# only showing top 20 rows

# %%
df_comentarios.select('ID_VIDEO').distinct().collect()
# Out:
# [Row(ID_VIDEO='6TKJFUX-Uzg'),
#  Row(ID_VIDEO='up4KrHrRwLY'),
#  Row(ID_VIDEO='ND4pLB1ZRyM'),
#  Row(ID_VIDEO='VUgmLKbC8tY'),
#  Row(ID_VIDEO='LGLnm6csfZo'),
#  Row(ID_VIDEO='vzzeZU07rmo'),
#  Row(ID_VIDEO='9SGBZ7GE5EA'),
#  Row(ID_VIDEO='TqDfKIao-1Q'),
#  Row(ID_VIDEO='EuUoqqXA6jI'),
#  Row(ID_VIDEO='e0OcwwSfvaM'),
#  Row(ID_VIDEO='h4rXTjnHu4A'),
#  Row(ID_VIDEO='xSAyLQ9h22k'),
#  Row(ID_VIDEO='zFO5_abqEss'),
#  Row(ID_VIDEO='GwvpvIEGCK0'),
#  Row(ID_VIDEO='t4pfQW9O3Lw'),
#  Row(ID_VIDEO='Cs2q5eDBvgI'),
#  Row(ID_VIDEO='SYyvURilQFI'),
#  Row(ID_VIDEO='xCaUzgIM6Bg'),
#  Row(ID_VIDEO='totHMIv6_hI'),
#  Row(ID_VIDEO='i0TpDwek80U'),
#  Row(ID_VIDEO='ShVmR8yQweU'),
#  Row(ID_VIDEO='V_sQAmzhrdE'),
#  Row(ID_VIDEO='EYyTd5WDGdk'),
#  Row(ID_VIDEO='mKgATax4ecI'),
#  Row(ID_VIDEO='dRzwiPwGH_M'),
#  Row(ID_VIDEO='pSc5EcLz7d8'),
#  Row(ID_VIDEO='O37hZJz5pjY'),
#  Row(ID_VIDEO='UJd9K8nK5H4'),
#  Row(ID_VIDEO='FFJNJqQVL7M'),
#  Row(ID_VIDEO='vkQCGDs8wMo'),
#  Row(ID_VIDEO='USd9yzBJLV4'),
#  Row(ID_VIDEO='ykt0QE2XxP0'),
#  Row(ID_VIDEO='ANa7la0wqNc'),
#  Row(ID_VIDEO='KfzZNkdyeEs'),
#  Row(ID_VIDEO='zyG3nFm9BB8'),
#  Row(ID_VIDEO='wCLSZxLfUAk'),
#  Row(ID_VIDEO='C1s-hsI9JaY'),
#  Row(ID_VIDEO='D3IsaJDB5ew'),
#  Row(ID_VIDEO='OH-qmlI4A3o'),
#  Row(ID_VIDEO='6RgEh-9KAgY'),
#  Row(ID_VIDEO='Ji4p7EjWe-A'),
#  Row(ID_VIDEO='fTeqTuEHs7I'),
#  Row(ID_VIDEO='gYl77Ot9oDU'),
#  Row(ID_VIDEO='TBZuVHi3QdM'),
#  Row(ID_VIDEO='UtkPIpov6h8'),
#  Row(ID_VIDEO='QwXP79P4xS0'),
#  Row(ID_VIDEO='RKa9PtQbAGQ'),
#  Row(ID_VIDEO='W6TjOORgEG0'),
#  Row(ID_VIDEO='L17Ox3uFAdo'),
#  Row(ID_VIDEO='g-MxTsj3GQA'),
#  Row(ID_VIDEO='vy-upTpchig'),
#  Row(ID_VIDEO='vt0A0U2PGqM'),
#  Row(ID_VIDEO='EEU9mOFMZSU'),
#  Row(ID_VIDEO='Yvcuxu2ch10'),
#  Row(ID_VIDEO='FK-EYFdPqpA'),
#  Row(ID_VIDEO='ys65q5CvWKU'),
#  Row(ID_VIDEO='v3YF3Bgyq68'),
#  Row(ID_VIDEO='YhXTcceM1NA'),
#  Row(ID_VIDEO='7OCQ0XZbFGQ'),
#  Row(ID_VIDEO='0yQZmZYmhqs'),
#  Row(ID_VIDEO='fTMGhu-b_bA'),
#  Row(ID_VIDEO='2c5QZgVUdGo'),
#  Row(ID_VIDEO='dccMZwhIvqo'),
#  Row(ID_VIDEO='IXHHbqUMW8o'),
#  Row(ID_VIDEO='rfnT7rJrXuo'),
#  Row(ID_VIDEO='BJH6Or12MrA'),
#  Row(ID_VIDEO='WfxauEGmDfg'),
#  Row(ID_VIDEO='sUO06_ONDLM'),
#  Row(ID_VIDEO='Gl60rzPP9VQ'),
#  Row(ID_VIDEO='fKctS-pM1tU'),
#  Row(ID_VIDEO='-lB67HbJ4_E'),
#  Row(ID_VIDEO='V1jZ4em2xO0'),
#  Row(ID_VIDEO='fSw3Cf2Olx0'),
#  Row(ID_VIDEO='pQMNnHA34sY'),
#  Row(ID_VIDEO='g4qCJ8Bzfj8'),
#  Row(ID_VIDEO='mmzA7GQ3jGM'),
#  Row(ID_VIDEO='wfRHaX4Iu2k'),
#  Row(ID_VIDEO='kAD40XkiXnM'),
#  Row(ID_VIDEO='pUtTRHkERGA'),
#  Row(ID_VIDEO='M-XdRc59oO0'),
#  Row(ID_VIDEO='vmBgHMIuBu4'),
#  Row(ID_VIDEO='OFGA4HI7ua8'),
#  Row(ID_VIDEO='KsWGb7aVhkI'),
#  Row(ID_VIDEO='GTeXBKAwAx8'),
#  Row(ID_VIDEO='YKCXBP9dZso'),
#  Row(ID_VIDEO='upq6KuDJQv8'),
#  Row(ID_VIDEO='KT42W1zQero'),
#  Row(ID_VIDEO='7qO2gNyBnLM'),
#  Row(ID_VIDEO='MEafMxF9AHc'),
#  Row(ID_VIDEO='CFt_ZH8f_Rk'),
#  Row(ID_VIDEO='bFIUwqaRhwc'),
#  Row(ID_VIDEO='PXFSPpOhqiU'),
#  Row(ID_VIDEO='zd7inolZtns'),
#  Row(ID_VIDEO='1Z_EHhu8dZ8'),
#  Row(ID_VIDEO='4s273-0o0iw'),
#  Row(ID_VIDEO='BruAJAArUg8'),
#  Row(ID_VIDEO='8lXiztAV1ZI'),
#  Row(ID_VIDEO='uz1jNjd8l18'),
#  Row(ID_VIDEO='Fa9A8FJNgIQ'),
#  Row(ID_VIDEO='IpWkSTkljqg'),
#  Row(ID_VIDEO='9DH3GvZmfM4'),
#  Row(ID_VIDEO='4XKTwsMg5bQ'),
#  Row(ID_VIDEO='kUmHkTUwV1E'),
#  Row(ID_VIDEO='JI2b9Q7b9sU'),
#  Row(ID_VIDEO='rZX5J7Xugus'),
#  Row(ID_VIDEO='gWqpzVLRq8Y'),
#  Row(ID_VIDEO='MRf3cGrl7-w'),
#  Row(ID_VIDEO='Q-yk-KVzBs4'),
#  Row(ID_VIDEO='ozbFzsakdGw'),
#  Row(ID_VIDEO='oXdlQTNMS6M'),
#  Row(ID_VIDEO='473TnC-bM7U'),
#  Row(ID_VIDEO='AGGQZRu4K4U'),
#  Row(ID_VIDEO='OUkUBgfel00'),
#  Row(ID_VIDEO='SQg_cqgyDLg'),
#  Row(ID_VIDEO='End_beEw42E'),
#  Row(ID_VIDEO='E2KEJU765SQ'),
#  Row(ID_VIDEO='STEuEi4ESjw'),
#  Row(ID_VIDEO='BxMtSb2w9Sk'),
#  Row(ID_VIDEO='4EPdvnnvkAw'),
#  Row(ID_VIDEO='kkPRDzrBUiY'),
#  Row(ID_VIDEO='KosQvtjxPwM'),
#  Row(ID_VIDEO='I8PSpoki4T0'),
#  Row(ID_VIDEO='XOUzWJ0bHuw'),
#  Row(ID_VIDEO='Z5JT2QG6vEI'),
#  Row(ID_VIDEO='J4ZAE8KhvAw'),
#  Row(ID_VIDEO='FCZBQdsVSbM'),
#  Row(ID_VIDEO='yLVmbLmRmpc'),
#  Row(ID_VIDEO='8XFusmwJ4tk'),
#  Row(ID_VIDEO='THuiHJMMvKc'),
#  Row(ID_VIDEO='3SsUx-y5Ik0'),
#  Row(ID_VIDEO='E7xUSDHjWRI'),
#  Row(ID_VIDEO='7B7GJboNysI'),
#  Row(ID_VIDEO='oh2FJBJT4zk'),
#  Row(ID_VIDEO='EvhojKcFpX4'),
#  Row(ID_VIDEO='50u1fJAYjcM'),
#  Row(ID_VIDEO='9aTPAbE-DP8'),
#  Row(ID_VIDEO='7hOtsfC8nIQ'),
#  Row(ID_VIDEO='DM1fwtgJFBM'),
#  Row(ID_VIDEO='X_2feTvxkp0'),
#  Row(ID_VIDEO='4UJOLOzhHtY'),
#  Row(ID_VIDEO='Dpz3Gw_Wcd4'),
#  Row(ID_VIDEO='8spAaaHolIc'),
#  Row(ID_VIDEO='zvKIck8aLhY'),
#  Row(ID_VIDEO='3wr5jTR6ZvQ'),
#  Row(ID_VIDEO='IBk2kXOKalA'),
#  Row(ID_VIDEO='5yvZdeB2Bzw'),
#  Row(ID_VIDEO='6qHqkq9yZpM'),
#  Row(ID_VIDEO='JQxD02yprhY'),
#  Row(ID_VIDEO='OBLJgSHFgqA'),
#  Row(ID_VIDEO='mRrJvS-am8c'),
#  Row(ID_VIDEO='qf5Qsf7y6gQ'),
#  Row(ID_VIDEO='VXg6qSSZ2dw'),
#  Row(ID_VIDEO='Qz-O549rDqA'),
#  Row(ID_VIDEO='4PuMoD5K1ug'),
#  Row(ID_VIDEO='z2wuhLPrUWg'),
#  Row(ID_VIDEO='9tmP8eZeMqs'),
#  Row(ID_VIDEO='DgKYwt3uJhE'),
#  Row(ID_VIDEO='3iHndL3Rnk4'),
#  Row(ID_VIDEO='Nr6Hpux5X0M'),
#  Row(ID_VIDEO='r-5wmbhU70c'),
#  Row(ID_VIDEO='hDdyFGnlDpo'),
#  Row(ID_VIDEO='Nqc0WeSFDg4'),
#  Row(ID_VIDEO='HAMqkeF9RPI'),
#  Row(ID_VIDEO='BVfvusk9sWs'),
#  Row(ID_VIDEO='S3yRptRZ_c0'),
#  Row(ID_VIDEO='nBl9bUXm4Xo'),
#  Row(ID_VIDEO='iCHWOQJz_IU'),
#  Row(ID_VIDEO='62dTsgBmqaM'),
#  Row(ID_VIDEO='-Jg3j6EH7cg'),
#  Row(ID_VIDEO='26zYG23Jjts'),
#  Row(ID_VIDEO='rCwCKTDaoV8'),
#  Row(ID_VIDEO='2qDGrXMCHPE'),
#  Row(ID_VIDEO='eLMZaLncq4w'),
#  Row(ID_VIDEO='KblbfZfNXok'),
#  Row(ID_VIDEO='zS3t3k4ZtU8'),
#  Row(ID_VIDEO='VBzzQtDGbfM'),
#  Row(ID_VIDEO='HxbSg6J-HBQ'),
#  Row(ID_VIDEO='j_Ngcrl9iDA'),
#  Row(ID_VIDEO='BfNdUOnhKEI'),
#  Row(ID_VIDEO='D8VPLdhGO8g'),
#  Row(ID_VIDEO='Fr-wIUJyL0g'),
#  Row(ID_VIDEO='XI8UVvd4vuk'),
#  Row(ID_VIDEO='ThTDnpK0jjE'),
#  Row(ID_VIDEO='8l01fDttqC8'),
#  Row(ID_VIDEO='TL9F-IPreyU'),
#  Row(ID_VIDEO='30HRESsC_js'),
#  Row(ID_VIDEO='8JH3XlaCfKs'),
#  Row(ID_VIDEO='7TzQAUd9JSA'),
#  Row(ID_VIDEO='ALBScxExplc'),
#  Row(ID_VIDEO='p5sjmV0_Yto'),
#  Row(ID_VIDEO='eJakfK_hqk8'),
#  Row(ID_VIDEO='l2eMfUsIleQ'),
#  Row(ID_VIDEO='Hz7H6HLKP_I'),
#  Row(ID_VIDEO='mUxRTZBYw8E'),
#  Row(ID_VIDEO='4KF4mkutuZo'),
#  Row(ID_VIDEO='QA4Zm02TnlQ'),
#  Row(ID_VIDEO='b6wo5cpbngw'),
#  Row(ID_VIDEO='Aq4Sf81lQno'),
#  Row(ID_VIDEO='vv6aCAZvpxc'),
#  Row(ID_VIDEO='IWZZ9ejWCRA'),
#  Row(ID_VIDEO='ZwYriuw9hlk'),
#  Row(ID_VIDEO='u1aRkx4eqJY'),
#  Row(ID_VIDEO='sbVChS7YsW4'),
#  Row(ID_VIDEO='0OjqrVKxgtM'),
#  Row(ID_VIDEO='u2Waj2ZJaL0'),
#  Row(ID_VIDEO='kYajggrGLeY'),
#  Row(ID_VIDEO='tdYiDzAHtR4'),
#  Row(ID_VIDEO='zNMNDqupQY8'),
#  Row(ID_VIDEO='_IRWrn2BVIQ'),
#  Row(ID_VIDEO='7jLVuZPVe3E'),
#  Row(ID_VIDEO='frM56bLOhbk'),
#  Row(ID_VIDEO='N6BKjgkuD_8'),
#  Row(ID_VIDEO='kFuQ91HpOrY'),
#  Row(ID_VIDEO='ZMeaCaDJhDg'),
#  Row(ID_VIDEO='rWncF2wcFWs'),
#  Row(ID_VIDEO='prLwnOZoyhY'),
#  Row(ID_VIDEO='He8UCpn5NCk'),
#  Row(ID_VIDEO='LYNZ5cU83k0'),
#  Row(ID_VIDEO='FW11WBBHJTI'),
#  Row(ID_VIDEO='q1UyymhOhFg'),
#  Row(ID_VIDEO='aldLNrBv82A'),
#  Row(ID_VIDEO='EY5_hzMFs3k'),
#  Row(ID_VIDEO='hMyRVIPWyHk'),
#  Row(ID_VIDEO='NGnk0S5RZKo'),
#  Row(ID_VIDEO='Au_S69vysXw'),
#  Row(ID_VIDEO='T1VrA9yi7UM'),
#  Row(ID_VIDEO='HEAzvJFgMqs'),
#  Row(ID_VIDEO='j465VQhJXTk'),
#  Row(ID_VIDEO='gXS_ie3Scds'),
#  Row(ID_VIDEO='W8JA9cQ5ANY'),
#  Row(ID_VIDEO='9scAe1bSorw'),
#  Row(ID_VIDEO='l6qsZCnJYBo'),
#  Row(ID_VIDEO='f5KCwk3t5sI'),
#  Row(ID_VIDEO='tU2TIZTLIEE'),
#  Row(ID_VIDEO='rcrwBl5orxQ'),
#  Row(ID_VIDEO='F9y9LN1X62g'),
#  Row(ID_VIDEO='cFnFsLFzbeY'),
#  Row(ID_VIDEO='zC2r1ElQOT0'),
#  Row(ID_VIDEO='rGaQpPIcy_E'),
#  Row(ID_VIDEO='Kidp3MmAbwc'),
#  Row(ID_VIDEO='p51OUKouhr0'),
#  Row(ID_VIDEO='jDTv255WSBQ'),
#  Row(ID_VIDEO='6EnWUjEocXQ'),
#  Row(ID_VIDEO='DVJOF93OsTw'),
#  Row(ID_VIDEO='UOE6pE8zxvU'),
#  Row(ID_VIDEO='874y6PZTZas'),
#  Row(ID_VIDEO='igxEHvMej3g'),
#  Row(ID_VIDEO='iXV9YtLyScw'),
#  Row(ID_VIDEO='3sI1qZzMG44'),
#  Row(ID_VIDEO='zzg-0c5jGY0'),
#  Row(ID_VIDEO='kD_JZcmnD5s'),
#  Row(ID_VIDEO='88tUOK9RHkQ'),
#  Row(ID_VIDEO='Sd2vygEJopQ'),
#  Row(ID_VIDEO='GVF-MC4RCzk'),
#  Row(ID_VIDEO='Ie4WpGMh0wU'),
#  Row(ID_VIDEO='qBsTx6SbuEI'),
#  Row(ID_VIDEO='TI_4qn0KEUs'),
#  Row(ID_VIDEO='x0YV5fs2ybM'),
#  Row(ID_VIDEO='ILcfXAVX85E'),
#  Row(ID_VIDEO='4V3N_iO8IHE'),
#  Row(ID_VIDEO='Eitva26pA8U'),
#  Row(ID_VIDEO='w_ZNxHX8FUM'),
#  Row(ID_VIDEO='evewy1P9938'),
#  Row(ID_VIDEO='OWU8nJ4Y8qc'),
#  Row(ID_VIDEO='xztUQRYFpNI'),
#  Row(ID_VIDEO='EMJho5TI26w'),
#  Row(ID_VIDEO='mL04WKzgV4s'),
#  Row(ID_VIDEO='BretVq76yzM'),
#  Row(ID_VIDEO='XPAHZ0X1ATQ'),
#  Row(ID_VIDEO='qnrAkMOJWJU'),
#  Row(ID_VIDEO='IHby-Dtzznk'),
#  Row(ID_VIDEO='vftn874Vh0w'),
#  Row(ID_VIDEO='weciQDqn07g'),
#  Row(ID_VIDEO='i3jdwJbl5yM'),
#  Row(ID_VIDEO='HkkO-absbbM'),
#  Row(ID_VIDEO='LYmfsVIOovo'),
#  Row(ID_VIDEO='HaHgPXzLS7U'),
#  Row(ID_VIDEO='JW54ZU2RpEA'),
#  Row(ID_VIDEO='BN7TOTd5THg'),
#  Row(ID_VIDEO='c4VdDPlRXMg'),
#  Row(ID_VIDEO='yRyH0ojDi5Y'),
#  Row(ID_VIDEO='O8qMpGpbl-0'),
#  Row(ID_VIDEO='DLMGApvk4jU'),
#  Row(ID_VIDEO='kt_0wxJZoGc'),
#  Row(ID_VIDEO='MiE9wstTNVs'),
#  Row(ID_VIDEO='pyaK4cfgJIY'),
#  Row(ID_VIDEO='-lpuR6CpJc8'),
#  Row(ID_VIDEO='Btm53nCucXY'),
#  Row(ID_VIDEO='Vh6FS-pqjsM'),
#  Row(ID_VIDEO='zBfn2Ae5RIo'),
#  Row(ID_VIDEO='my8vZ-tMzVs'),
#  Row(ID_VIDEO='XqrIqDpiRLY'),
#  Row(ID_VIDEO='XzZCR318HOg'),
#  Row(ID_VIDEO='r_2IEGjYcv4'),
#  Row(ID_VIDEO='_1L63tF4tKg'),
#  Row(ID_VIDEO='aNrS3_W6Fsk'),
#  Row(ID_VIDEO='Gu_MQ8RJ7f4'),
#  Row(ID_VIDEO='zEHZpgrv3D8'),
#  Row(ID_VIDEO='SY0_eLxzf5I'),
#  Row(ID_VIDEO='1bCLxUE5vJ8'),
#  Row(ID_VIDEO='qvycUFYZ0EY'),
#  Row(ID_VIDEO='q0lOhwnIqMg'),
#  Row(ID_VIDEO='BrU8XxRxd70'),
#  Row(ID_VIDEO='9bGAJKPfVh4'),
#  Row(ID_VIDEO='h2GcW32MjPI'),
#  Row(ID_VIDEO='yKobaBPvi20'),
#  Row(ID_VIDEO='M34bccK5G1U'),
#  Row(ID_VIDEO='4PF2iJgHPzw'),
#  Row(ID_VIDEO='_gfDFHBqYMk'),
#  Row(ID_VIDEO='wmWIRWYc53A'),
#  Row(ID_VIDEO='7Fgl66GMYW0'),
#  Row(ID_VIDEO='GtAxFTe5jFs'),
#  Row(ID_VIDEO='Y1aZ19eCTEY'),
#  Row(ID_VIDEO='Ueq0IfDL1eQ'),
#  Row(ID_VIDEO='pZlsfaVk7c0'),
#  Row(ID_VIDEO='uYVqLgqtS1s'),
#  Row(ID_VIDEO='RZN653am-R8'),
#  Row(ID_VIDEO='k_lcoRiVkHA'),
#  Row(ID_VIDEO='N_tQiUkyor4'),
#  Row(ID_VIDEO='HnZnlCfXlMg'),
#  Row(ID_VIDEO='X4v776WzZQY'),
#  Row(ID_VIDEO='ZCPbAwRwv5o'),
#  Row(ID_VIDEO='fXIGGJR6HmM'),
#  Row(ID_VIDEO='Bu4GDVJpS2M'),
#  Row(ID_VIDEO='SjkWTy0xFGY'),
#  Row(ID_VIDEO='tm86ohpl6bI'),
#  Row(ID_VIDEO='MmFzQ5g0CAs'),
#  Row(ID_VIDEO='ajlDAp9aJtQ'),
#  Row(ID_VIDEO='B3FZXk_Nhys'),
#  Row(ID_VIDEO='6vmSmES4TRE'),
#  Row(ID_VIDEO='T6N8Tb36_eU'),
#  Row(ID_VIDEO='XwncN1bQF4s'),
#  Row(ID_VIDEO='Hpdf1eE6OmY'),
#  Row(ID_VIDEO='V5mWOOWYLBo'),
#  Row(ID_VIDEO='afi-189_svQ'),
#  Row(ID_VIDEO='yiNziiO76W0'),
#  Row(ID_VIDEO='d-cK9SmdR6U'),
#  Row(ID_VIDEO='qe9cKDNhk98'),
#  Row(ID_VIDEO='V3RO_fXfBj0'),
#  Row(ID_VIDEO='r4xIloItxsw'),
#  Row(ID_VIDEO='Nfd7IGFBEhM'),
#  Row(ID_VIDEO='SwXKekGGN70'),
#  Row(ID_VIDEO='DOrOIn2T7YU'),
#  Row(ID_VIDEO='QrNC4WTNZbg'),
#  Row(ID_VIDEO='mL14Jp98WQk'),
#  Row(ID_VIDEO='rtUcXQ9zr3A'),
#  Row(ID_VIDEO='ftlPupeDEqI'),
#  Row(ID_VIDEO='vuIbULSCT_o'),
#  Row(ID_VIDEO='nuT7guo29Nw'),
#  Row(ID_VIDEO='uK6Ec_ckjpk'),
#  Row(ID_VIDEO='00l30LL94uM'),
#  Row(ID_VIDEO='AATFgn2y_ns'),
#  Row(ID_VIDEO='YT5adYfgdfs'),
#  Row(ID_VIDEO='3DhpH-MgFUs'),
#  Row(ID_VIDEO='aOIgV64NNoI'),
#  Row(ID_VIDEO='wc22tG5IGUU'),
#  Row(ID_VIDEO='XzOBpvTCXEs'),
#  Row(ID_VIDEO='aGKQyduebH4'),
#  Row(ID_VIDEO='06OQTEk2Lcc'),
#  Row(ID_VIDEO='Z8x9SWsgsqc'),
#  Row(ID_VIDEO='9vn_Am3oLmc'),
#  Row(ID_VIDEO='Gag4JvVjxrg'),
#  Row(ID_VIDEO='oBXtdvmjP-Y'),
#  Row(ID_VIDEO='R7DKBMnpk64'),
#  Row(ID_VIDEO='H1TkuRbFf38'),
#  Row(ID_VIDEO='QdIWW41VIC0'),
#  Row(ID_VIDEO='Ce9sI7hOy0Y'),
#  Row(ID_VIDEO='j8CyPf2eEZA'),
#  Row(ID_VIDEO='id4puuTRfDk'),
#  Row(ID_VIDEO='eNv9hUFqCvU'),
#  Row(ID_VIDEO='RkxCFE4_4T0'),
#  Row(ID_VIDEO='_z_tzSRanNQ'),
#  Row(ID_VIDEO='YaP2CDmB2nw'),
#  Row(ID_VIDEO='CzRAPL6D23Q'),
#  Row(ID_VIDEO='VK8Aj7bB-kY'),
#  Row(ID_VIDEO='kZ1DbTNZjqk'),
#  Row(ID_VIDEO='fUuSj7tUfbo'),
#  Row(ID_VIDEO='XwqZ15r0LrY'),
#  Row(ID_VIDEO='lqLVfyHKFoQ'),
#  Row(ID_VIDEO='35_FkoRogNY')]

# %%
lista_videos = [ linha['ID_VIDEO'] for linha in df_comentarios.select('ID_VIDEO').distinct().collect()]
lista_videos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/rodrigo/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/notebooks/carga_hive.ipynb Célula 8 line 1
# ----> <a href='vscode-notebook-cell:/home/rodrigo/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/notebooks/carga_hive.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> lista_videos = [ linha['ID_VIDEO'] for linha in df_comentarios.select('ID_VIDEO').distinct().collect()]
#       <a href='vscode-notebook-cell:/home/rodrigo/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/notebooks/carga_hive.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> lista_videos
#
# NameError: name 'df_comentarios' is not defined

# %%
len(df_comentarios.select('ID_VIDEO').distinct().collect())
# Out:
# 380

# %%
lista_assunto = [
        'assunto_cities_skylines',
        'assunto_cities_skylines_2',
        'assunto_power_bi',
        'assunto_python_and_dados'
]

# %%
for video in lista_videos:
    df_comentarios \
        .filter(df_comentarios.ID_VIDEO == video) \
        .write \
        .parquet(f'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_{video}.parquet')

# %%
spark.stop()

# %%
conn = hive.Connection(host='localhost', port=10000, username='rodrigo')

# %%
conn

# %%
lista_videos
# Out:
# ['6TKJFUX-Uzg',
#  'up4KrHrRwLY',
#  'ND4pLB1ZRyM',
#  'VUgmLKbC8tY',
#  'LGLnm6csfZo',
#  'vzzeZU07rmo',
#  '9SGBZ7GE5EA',
#  'TqDfKIao-1Q',
#  'EuUoqqXA6jI',
#  'e0OcwwSfvaM',
#  'h4rXTjnHu4A',
#  'xSAyLQ9h22k',
#  'zFO5_abqEss',
#  'GwvpvIEGCK0',
#  't4pfQW9O3Lw',
#  'Cs2q5eDBvgI',
#  'SYyvURilQFI',
#  'xCaUzgIM6Bg',
#  'totHMIv6_hI',
#  'i0TpDwek80U',
#  'ShVmR8yQweU',
#  'V_sQAmzhrdE',
#  'EYyTd5WDGdk',
#  'mKgATax4ecI',
#  'dRzwiPwGH_M',
#  'pSc5EcLz7d8',
#  'O37hZJz5pjY',
#  'UJd9K8nK5H4',
#  'FFJNJqQVL7M',
#  'vkQCGDs8wMo',
#  'USd9yzBJLV4',
#  'ykt0QE2XxP0',
#  'ANa7la0wqNc',
#  'KfzZNkdyeEs',
#  'zyG3nFm9BB8',
#  'wCLSZxLfUAk',
#  'C1s-hsI9JaY',
#  'D3IsaJDB5ew',
#  'OH-qmlI4A3o',
#  '6RgEh-9KAgY',
#  'Ji4p7EjWe-A',
#  'fTeqTuEHs7I',
#  'gYl77Ot9oDU',
#  'TBZuVHi3QdM',
#  'UtkPIpov6h8',
#  'QwXP79P4xS0',
#  'RKa9PtQbAGQ',
#  'W6TjOORgEG0',
#  'L17Ox3uFAdo',
#  'g-MxTsj3GQA',
#  'vy-upTpchig',
#  'vt0A0U2PGqM',
#  'EEU9mOFMZSU',
#  'Yvcuxu2ch10',
#  'FK-EYFdPqpA',
#  'ys65q5CvWKU',
#  'v3YF3Bgyq68',
#  'YhXTcceM1NA',
#  '7OCQ0XZbFGQ',
#  '0yQZmZYmhqs',
#  'fTMGhu-b_bA',
#  '2c5QZgVUdGo',
#  'dccMZwhIvqo',
#  'IXHHbqUMW8o',
#  'rfnT7rJrXuo',
#  'BJH6Or12MrA',
#  'WfxauEGmDfg',
#  'sUO06_ONDLM',
#  'Gl60rzPP9VQ',
#  'fKctS-pM1tU',
#  '-lB67HbJ4_E',
#  'V1jZ4em2xO0',
#  'fSw3Cf2Olx0',
#  'pQMNnHA34sY',
#  'g4qCJ8Bzfj8',
#  'mmzA7GQ3jGM',
#  'wfRHaX4Iu2k',
#  'kAD40XkiXnM',
#  'pUtTRHkERGA',
#  'M-XdRc59oO0',
#  'vmBgHMIuBu4',
#  'OFGA4HI7ua8',
#  'KsWGb7aVhkI',
#  'GTeXBKAwAx8',
#  'YKCXBP9dZso',
#  'upq6KuDJQv8',
#  'KT42W1zQero',
#  '7qO2gNyBnLM',
#  'MEafMxF9AHc',
#  'CFt_ZH8f_Rk',
#  'bFIUwqaRhwc',
#  'PXFSPpOhqiU',
#  'zd7inolZtns',
#  '1Z_EHhu8dZ8',
#  '4s273-0o0iw',
#  'BruAJAArUg8',
#  '8lXiztAV1ZI',
#  'uz1jNjd8l18',
#  'Fa9A8FJNgIQ',
#  'IpWkSTkljqg',
#  '9DH3GvZmfM4',
#  '4XKTwsMg5bQ',
#  'kUmHkTUwV1E',
#  'JI2b9Q7b9sU',
#  'rZX5J7Xugus',
#  'gWqpzVLRq8Y',
#  'MRf3cGrl7-w',
#  'Q-yk-KVzBs4',
#  'ozbFzsakdGw',
#  'oXdlQTNMS6M',
#  '473TnC-bM7U',
#  'AGGQZRu4K4U',
#  'OUkUBgfel00',
#  'SQg_cqgyDLg',
#  'End_beEw42E',
#  'E2KEJU765SQ',
#  'STEuEi4ESjw',
#  'BxMtSb2w9Sk',
#  '4EPdvnnvkAw',
#  'kkPRDzrBUiY',
#  'KosQvtjxPwM',
#  'I8PSpoki4T0',
#  'XOUzWJ0bHuw',
#  'Z5JT2QG6vEI',
#  'J4ZAE8KhvAw',
#  'FCZBQdsVSbM',
#  'yLVmbLmRmpc',
#  '8XFusmwJ4tk',
#  'THuiHJMMvKc',
#  '3SsUx-y5Ik0',
#  'E7xUSDHjWRI',
#  '7B7GJboNysI',
#  'oh2FJBJT4zk',
#  'EvhojKcFpX4',
#  '50u1fJAYjcM',
#  '9aTPAbE-DP8',
#  '7hOtsfC8nIQ',
#  'DM1fwtgJFBM',
#  'X_2feTvxkp0',
#  '4UJOLOzhHtY',
#  'Dpz3Gw_Wcd4',
#  '8spAaaHolIc',
#  'zvKIck8aLhY',
#  '3wr5jTR6ZvQ',
#  'IBk2kXOKalA',
#  '5yvZdeB2Bzw',
#  '6qHqkq9yZpM',
#  'JQxD02yprhY',
#  'OBLJgSHFgqA',
#  'mRrJvS-am8c',
#  'qf5Qsf7y6gQ',
#  'VXg6qSSZ2dw',
#  'Qz-O549rDqA',
#  '4PuMoD5K1ug',
#  'z2wuhLPrUWg',
#  '9tmP8eZeMqs',
#  'DgKYwt3uJhE',
#  '3iHndL3Rnk4',
#  'Nr6Hpux5X0M',
#  'r-5wmbhU70c',
#  'hDdyFGnlDpo',
#  'Nqc0WeSFDg4',
#  'HAMqkeF9RPI',
#  'BVfvusk9sWs',
#  'S3yRptRZ_c0',
#  'nBl9bUXm4Xo',
#  'iCHWOQJz_IU',
#  '62dTsgBmqaM',
#  '-Jg3j6EH7cg',
#  '26zYG23Jjts',
#  'rCwCKTDaoV8',
#  '2qDGrXMCHPE',
#  'eLMZaLncq4w',
#  'KblbfZfNXok',
#  'zS3t3k4ZtU8',
#  'VBzzQtDGbfM',
#  'HxbSg6J-HBQ',
#  'j_Ngcrl9iDA',
#  'BfNdUOnhKEI',
#  'D8VPLdhGO8g',
#  'Fr-wIUJyL0g',
#  'XI8UVvd4vuk',
#  'ThTDnpK0jjE',
#  '8l01fDttqC8',
#  'TL9F-IPreyU',
#  '30HRESsC_js',
#  '8JH3XlaCfKs',
#  '7TzQAUd9JSA',
#  'ALBScxExplc',
#  'p5sjmV0_Yto',
#  'eJakfK_hqk8',
#  'l2eMfUsIleQ',
#  'Hz7H6HLKP_I',
#  'mUxRTZBYw8E',
#  '4KF4mkutuZo',
#  'QA4Zm02TnlQ',
#  'b6wo5cpbngw',
#  'Aq4Sf81lQno',
#  'vv6aCAZvpxc',
#  'IWZZ9ejWCRA',
#  'ZwYriuw9hlk',
#  'u1aRkx4eqJY',
#  'sbVChS7YsW4',
#  '0OjqrVKxgtM',
#  'u2Waj2ZJaL0',
#  'kYajggrGLeY',
#  'tdYiDzAHtR4',
#  'zNMNDqupQY8',
#  '_IRWrn2BVIQ',
#  '7jLVuZPVe3E',
#  'frM56bLOhbk',
#  'N6BKjgkuD_8',
#  'kFuQ91HpOrY',
#  'ZMeaCaDJhDg',
#  'rWncF2wcFWs',
#  'prLwnOZoyhY',
#  'He8UCpn5NCk',
#  'LYNZ5cU83k0',
#  'FW11WBBHJTI',
#  'q1UyymhOhFg',
#  'aldLNrBv82A',
#  'EY5_hzMFs3k',
#  'hMyRVIPWyHk',
#  'NGnk0S5RZKo',
#  'Au_S69vysXw',
#  'T1VrA9yi7UM',
#  'HEAzvJFgMqs',
#  'j465VQhJXTk',
#  'gXS_ie3Scds',
#  'W8JA9cQ5ANY',
#  '9scAe1bSorw',
#  'l6qsZCnJYBo',
#  'f5KCwk3t5sI',
#  'tU2TIZTLIEE',
#  'rcrwBl5orxQ',
#  'F9y9LN1X62g',
#  'cFnFsLFzbeY',
#  'zC2r1ElQOT0',
#  'rGaQpPIcy_E',
#  'Kidp3MmAbwc',
#  'p51OUKouhr0',
#  'jDTv255WSBQ',
#  '6EnWUjEocXQ',
#  'DVJOF93OsTw',
#  'UOE6pE8zxvU',
#  '874y6PZTZas',
#  'igxEHvMej3g',
#  'iXV9YtLyScw',
#  '3sI1qZzMG44',
#  'zzg-0c5jGY0',
#  'kD_JZcmnD5s',
#  '88tUOK9RHkQ',
#  'Sd2vygEJopQ',
#  'GVF-MC4RCzk',
#  'Ie4WpGMh0wU',
#  'qBsTx6SbuEI',
#  'TI_4qn0KEUs',
#  'x0YV5fs2ybM',
#  'ILcfXAVX85E',
#  '4V3N_iO8IHE',
#  'Eitva26pA8U',
#  'w_ZNxHX8FUM',
#  'evewy1P9938',
#  'OWU8nJ4Y8qc',
#  'xztUQRYFpNI',
#  'EMJho5TI26w',
#  'mL04WKzgV4s',
#  'BretVq76yzM',
#  'XPAHZ0X1ATQ',
#  'qnrAkMOJWJU',
#  'IHby-Dtzznk',
#  'vftn874Vh0w',
#  'weciQDqn07g',
#  'i3jdwJbl5yM',
#  'HkkO-absbbM',
#  'LYmfsVIOovo',
#  'HaHgPXzLS7U',
#  'JW54ZU2RpEA',
#  'BN7TOTd5THg',
#  'c4VdDPlRXMg',
#  'yRyH0ojDi5Y',
#  'O8qMpGpbl-0',
#  'DLMGApvk4jU',
#  'kt_0wxJZoGc',
#  'MiE9wstTNVs',
#  'pyaK4cfgJIY',
#  '-lpuR6CpJc8',
#  'Btm53nCucXY',
#  'Vh6FS-pqjsM',
#  'zBfn2Ae5RIo',
#  'my8vZ-tMzVs',
#  'XqrIqDpiRLY',
#  'XzZCR318HOg',
#  'r_2IEGjYcv4',
#  '_1L63tF4tKg',
#  'aNrS3_W6Fsk',
#  'Gu_MQ8RJ7f4',
#  'zEHZpgrv3D8',
#  'SY0_eLxzf5I',
#  '1bCLxUE5vJ8',
#  'qvycUFYZ0EY',
#  'q0lOhwnIqMg',
#  'BrU8XxRxd70',
#  '9bGAJKPfVh4',
#  'h2GcW32MjPI',
#  'yKobaBPvi20',
#  'M34bccK5G1U',
#  '4PF2iJgHPzw',
#  '_gfDFHBqYMk',
#  'wmWIRWYc53A',
#  '7Fgl66GMYW0',
#  'GtAxFTe5jFs',
#  'Y1aZ19eCTEY',
#  'Ueq0IfDL1eQ',
#  'pZlsfaVk7c0',
#  'uYVqLgqtS1s',
#  'RZN653am-R8',
#  'k_lcoRiVkHA',
#  'N_tQiUkyor4',
#  'HnZnlCfXlMg',
#  'X4v776WzZQY',
#  'ZCPbAwRwv5o',
#  'fXIGGJR6HmM',
#  'Bu4GDVJpS2M',
#  'SjkWTy0xFGY',
#  'tm86ohpl6bI',
#  'MmFzQ5g0CAs',
#  'ajlDAp9aJtQ',
#  'B3FZXk_Nhys',
#  '6vmSmES4TRE',
#  'T6N8Tb36_eU',
#  'XwncN1bQF4s',
#  'Hpdf1eE6OmY',
#  'V5mWOOWYLBo',
#  'afi-189_svQ',
#  'yiNziiO76W0',
#  'd-cK9SmdR6U',
#  'qe9cKDNhk98',
#  'V3RO_fXfBj0',
#  'r4xIloItxsw',
#  'Nfd7IGFBEhM',
#  'SwXKekGGN70',
#  'DOrOIn2T7YU',
#  'QrNC4WTNZbg',
#  'mL14Jp98WQk',
#  'rtUcXQ9zr3A',
#  'ftlPupeDEqI',
#  'vuIbULSCT_o',
#  'nuT7guo29Nw',
#  'uK6Ec_ckjpk',
#  '00l30LL94uM',
#  'AATFgn2y_ns',
#  'YT5adYfgdfs',
#  '3DhpH-MgFUs',
#  'aOIgV64NNoI',
#  'wc22tG5IGUU',
#  'XzOBpvTCXEs',
#  'aGKQyduebH4',
#  '06OQTEk2Lcc',
#  'Z8x9SWsgsqc',
#  '9vn_Am3oLmc',
#  'Gag4JvVjxrg',
#  'oBXtdvmjP-Y',
#  'R7DKBMnpk64',
#  'H1TkuRbFf38',
#  'QdIWW41VIC0',
#  'Ce9sI7hOy0Y',
#  'j8CyPf2eEZA',
#  'id4puuTRfDk',
#  'eNv9hUFqCvU',
#  'RkxCFE4_4T0',
#  '_z_tzSRanNQ',
#  'YaP2CDmB2nw',
#  'CzRAPL6D23Q',
#  'VK8Aj7bB-kY',
#  'kZ1DbTNZjqk',
#  'fUuSj7tUfbo',
#  'XwqZ15r0LrY',
#  'lqLVfyHKFoQ',
#  '35_FkoRogNY']

# %%
cursor = conn.cursor()
cursor.execute('USE youtube')
for chave,  video in enumerate(lista_videos):

    print(f'iteração {chave + 1} --- de {len(lista_videos) + 1}')
    try:
        

        query = f'''
        LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_{video}.parquet'
        INTO TABLE comentarios_youtube
        '''
        print(query)
        
        cursor.execute(query)
    except:
        cursor.close()
        print(f'deu ruim em {chave + 1}')
        break

cursor.close()
# Out:
# iteração 1 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_6TKJFUX-Uzg.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 2 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_up4KrHrRwLY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 3 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_ND4pLB1ZRyM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 4 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_VUgmLKbC8tY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 5 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_LGLnm6csfZo.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 6 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_vzzeZU07rmo.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 7 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_9SGBZ7GE5EA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 8 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_TqDfKIao-1Q.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 9 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_EuUoqqXA6jI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 10 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_e0OcwwSfvaM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 11 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_h4rXTjnHu4A.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 12 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_xSAyLQ9h22k.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 13 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_zFO5_abqEss.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 14 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_GwvpvIEGCK0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 15 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_t4pfQW9O3Lw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 16 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Cs2q5eDBvgI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 17 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_SYyvURilQFI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 18 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_xCaUzgIM6Bg.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 19 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_totHMIv6_hI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 20 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_i0TpDwek80U.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 21 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_ShVmR8yQweU.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 22 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_V_sQAmzhrdE.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 23 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_EYyTd5WDGdk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 24 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_mKgATax4ecI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 25 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_dRzwiPwGH_M.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 26 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_pSc5EcLz7d8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 27 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_O37hZJz5pjY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 28 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_UJd9K8nK5H4.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 29 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_FFJNJqQVL7M.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 30 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_vkQCGDs8wMo.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 31 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_USd9yzBJLV4.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 32 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_ykt0QE2XxP0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 33 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_ANa7la0wqNc.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 34 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_KfzZNkdyeEs.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 35 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_zyG3nFm9BB8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 36 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_wCLSZxLfUAk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 37 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_C1s-hsI9JaY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 38 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_D3IsaJDB5ew.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 39 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_OH-qmlI4A3o.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 40 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_6RgEh-9KAgY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 41 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Ji4p7EjWe-A.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 42 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_fTeqTuEHs7I.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 43 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_gYl77Ot9oDU.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 44 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_TBZuVHi3QdM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 45 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_UtkPIpov6h8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 46 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_QwXP79P4xS0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 47 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_RKa9PtQbAGQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 48 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_W6TjOORgEG0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 49 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_L17Ox3uFAdo.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 50 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_g-MxTsj3GQA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 51 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_vy-upTpchig.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 52 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_vt0A0U2PGqM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 53 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_EEU9mOFMZSU.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 54 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Yvcuxu2ch10.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 55 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_FK-EYFdPqpA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 56 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_ys65q5CvWKU.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 57 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_v3YF3Bgyq68.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 58 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_YhXTcceM1NA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 59 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_7OCQ0XZbFGQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 60 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_0yQZmZYmhqs.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 61 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_fTMGhu-b_bA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 62 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_2c5QZgVUdGo.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 63 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_dccMZwhIvqo.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 64 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_IXHHbqUMW8o.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 65 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_rfnT7rJrXuo.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 66 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_BJH6Or12MrA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 67 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_WfxauEGmDfg.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 68 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_sUO06_ONDLM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 69 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Gl60rzPP9VQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 70 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_fKctS-pM1tU.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 71 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_-lB67HbJ4_E.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 72 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_V1jZ4em2xO0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 73 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_fSw3Cf2Olx0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 74 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_pQMNnHA34sY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 75 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_g4qCJ8Bzfj8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 76 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_mmzA7GQ3jGM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 77 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_wfRHaX4Iu2k.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 78 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_kAD40XkiXnM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 79 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_pUtTRHkERGA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 80 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_M-XdRc59oO0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 81 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_vmBgHMIuBu4.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 82 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_OFGA4HI7ua8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 83 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_KsWGb7aVhkI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 84 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_GTeXBKAwAx8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 85 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_YKCXBP9dZso.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 86 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_upq6KuDJQv8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 87 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_KT42W1zQero.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 88 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_7qO2gNyBnLM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 89 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_MEafMxF9AHc.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 90 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_CFt_ZH8f_Rk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 91 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_bFIUwqaRhwc.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 92 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_PXFSPpOhqiU.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 93 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_zd7inolZtns.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 94 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_1Z_EHhu8dZ8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 95 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_4s273-0o0iw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 96 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_BruAJAArUg8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 97 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_8lXiztAV1ZI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 98 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_uz1jNjd8l18.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 99 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Fa9A8FJNgIQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 100 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_IpWkSTkljqg.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 101 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_9DH3GvZmfM4.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 102 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_4XKTwsMg5bQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 103 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_kUmHkTUwV1E.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 104 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_JI2b9Q7b9sU.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 105 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_rZX5J7Xugus.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 106 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_gWqpzVLRq8Y.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 107 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_MRf3cGrl7-w.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 108 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Q-yk-KVzBs4.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 109 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_ozbFzsakdGw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 110 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_oXdlQTNMS6M.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 111 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_473TnC-bM7U.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 112 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_AGGQZRu4K4U.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 113 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_OUkUBgfel00.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 114 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_SQg_cqgyDLg.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 115 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_End_beEw42E.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 116 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_E2KEJU765SQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 117 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_STEuEi4ESjw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 118 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_BxMtSb2w9Sk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 119 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_4EPdvnnvkAw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 120 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_kkPRDzrBUiY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 121 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_KosQvtjxPwM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 122 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_I8PSpoki4T0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 123 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_XOUzWJ0bHuw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 124 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Z5JT2QG6vEI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 125 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_J4ZAE8KhvAw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 126 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_FCZBQdsVSbM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 127 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_yLVmbLmRmpc.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 128 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_8XFusmwJ4tk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 129 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_THuiHJMMvKc.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 130 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_3SsUx-y5Ik0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 131 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_E7xUSDHjWRI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 132 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_7B7GJboNysI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 133 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_oh2FJBJT4zk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 134 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_EvhojKcFpX4.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 135 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_50u1fJAYjcM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 136 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_9aTPAbE-DP8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 137 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_7hOtsfC8nIQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 138 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_DM1fwtgJFBM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 139 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_X_2feTvxkp0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 140 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_4UJOLOzhHtY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 141 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Dpz3Gw_Wcd4.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 142 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_8spAaaHolIc.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 143 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_zvKIck8aLhY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 144 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_3wr5jTR6ZvQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 145 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_IBk2kXOKalA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 146 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_5yvZdeB2Bzw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 147 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_6qHqkq9yZpM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 148 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_JQxD02yprhY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 149 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_OBLJgSHFgqA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 150 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_mRrJvS-am8c.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 151 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_qf5Qsf7y6gQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 152 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_VXg6qSSZ2dw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 153 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Qz-O549rDqA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 154 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_4PuMoD5K1ug.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 155 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_z2wuhLPrUWg.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 156 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_9tmP8eZeMqs.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 157 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_DgKYwt3uJhE.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 158 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_3iHndL3Rnk4.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 159 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Nr6Hpux5X0M.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 160 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_r-5wmbhU70c.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 161 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_hDdyFGnlDpo.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 162 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Nqc0WeSFDg4.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 163 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_HAMqkeF9RPI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 164 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_BVfvusk9sWs.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 165 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_S3yRptRZ_c0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 166 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_nBl9bUXm4Xo.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 167 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_iCHWOQJz_IU.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 168 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_62dTsgBmqaM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 169 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_-Jg3j6EH7cg.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 170 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_26zYG23Jjts.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 171 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_rCwCKTDaoV8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 172 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_2qDGrXMCHPE.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 173 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_eLMZaLncq4w.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 174 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_KblbfZfNXok.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 175 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_zS3t3k4ZtU8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 176 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_VBzzQtDGbfM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 177 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_HxbSg6J-HBQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 178 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_j_Ngcrl9iDA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 179 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_BfNdUOnhKEI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 180 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_D8VPLdhGO8g.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 181 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Fr-wIUJyL0g.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 182 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_XI8UVvd4vuk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 183 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_ThTDnpK0jjE.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 184 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_8l01fDttqC8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 185 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_TL9F-IPreyU.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 186 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_30HRESsC_js.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 187 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_8JH3XlaCfKs.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 188 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_7TzQAUd9JSA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 189 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_ALBScxExplc.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 190 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_p5sjmV0_Yto.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 191 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_eJakfK_hqk8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 192 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_l2eMfUsIleQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 193 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Hz7H6HLKP_I.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 194 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_mUxRTZBYw8E.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 195 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_4KF4mkutuZo.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 196 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_QA4Zm02TnlQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 197 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_b6wo5cpbngw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 198 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Aq4Sf81lQno.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 199 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_vv6aCAZvpxc.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 200 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_IWZZ9ejWCRA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 201 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_ZwYriuw9hlk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 202 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_u1aRkx4eqJY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 203 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_sbVChS7YsW4.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 204 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_0OjqrVKxgtM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 205 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_u2Waj2ZJaL0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 206 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_kYajggrGLeY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 207 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_tdYiDzAHtR4.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 208 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_zNMNDqupQY8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 209 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios__IRWrn2BVIQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 210 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_7jLVuZPVe3E.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 211 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_frM56bLOhbk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 212 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_N6BKjgkuD_8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 213 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_kFuQ91HpOrY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 214 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_ZMeaCaDJhDg.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 215 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_rWncF2wcFWs.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 216 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_prLwnOZoyhY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 217 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_He8UCpn5NCk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 218 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_LYNZ5cU83k0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 219 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_FW11WBBHJTI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 220 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_q1UyymhOhFg.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 221 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_aldLNrBv82A.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 222 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_EY5_hzMFs3k.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 223 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_hMyRVIPWyHk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 224 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_NGnk0S5RZKo.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 225 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Au_S69vysXw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 226 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_T1VrA9yi7UM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 227 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_HEAzvJFgMqs.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 228 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_j465VQhJXTk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 229 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_gXS_ie3Scds.parquet'
#         INTO TABLE comentarios_youtube
#
# ...
#         INTO TABLE comentarios_youtube
#
# iteração 305 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_h2GcW32MjPI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 306 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_yKobaBPvi20.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 307 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_M34bccK5G1U.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 308 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_4PF2iJgHPzw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 309 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios__gfDFHBqYMk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 310 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_wmWIRWYc53A.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 311 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_7Fgl66GMYW0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 312 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_GtAxFTe5jFs.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 313 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Y1aZ19eCTEY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 314 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Ueq0IfDL1eQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 315 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_pZlsfaVk7c0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 316 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_uYVqLgqtS1s.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 317 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_RZN653am-R8.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 318 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_k_lcoRiVkHA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 319 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_N_tQiUkyor4.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 320 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_HnZnlCfXlMg.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 321 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_X4v776WzZQY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 322 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_ZCPbAwRwv5o.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 323 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_fXIGGJR6HmM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 324 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Bu4GDVJpS2M.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 325 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_SjkWTy0xFGY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 326 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_tm86ohpl6bI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 327 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_MmFzQ5g0CAs.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 328 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_ajlDAp9aJtQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 329 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_B3FZXk_Nhys.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 330 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_6vmSmES4TRE.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 331 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_T6N8Tb36_eU.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 332 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_XwncN1bQF4s.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 333 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Hpdf1eE6OmY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 334 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_V5mWOOWYLBo.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 335 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_afi-189_svQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 336 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_yiNziiO76W0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 337 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_d-cK9SmdR6U.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 338 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_qe9cKDNhk98.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 339 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_V3RO_fXfBj0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 340 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_r4xIloItxsw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 341 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Nfd7IGFBEhM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 342 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_SwXKekGGN70.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 343 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_DOrOIn2T7YU.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 344 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_QrNC4WTNZbg.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 345 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_mL14Jp98WQk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 346 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_rtUcXQ9zr3A.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 347 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_ftlPupeDEqI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 348 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_vuIbULSCT_o.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 349 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_nuT7guo29Nw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 350 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_uK6Ec_ckjpk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 351 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_00l30LL94uM.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 352 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_AATFgn2y_ns.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 353 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_YT5adYfgdfs.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 354 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_3DhpH-MgFUs.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 355 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_aOIgV64NNoI.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 356 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_wc22tG5IGUU.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 357 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_XzOBpvTCXEs.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 358 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_aGKQyduebH4.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 359 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_06OQTEk2Lcc.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 360 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Z8x9SWsgsqc.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 361 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_9vn_Am3oLmc.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 362 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Gag4JvVjxrg.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 363 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_oBXtdvmjP-Y.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 364 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_R7DKBMnpk64.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 365 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_H1TkuRbFf38.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 366 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_QdIWW41VIC0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 367 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_Ce9sI7hOy0Y.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 368 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_j8CyPf2eEZA.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 369 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_id4puuTRfDk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 370 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_eNv9hUFqCvU.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 371 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_RkxCFE4_4T0.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 372 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios__z_tzSRanNQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 373 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_YaP2CDmB2nw.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 374 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_CzRAPL6D23Q.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 375 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_VK8Aj7bB-kY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 376 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_kZ1DbTNZjqk.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 377 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_fUuSj7tUfbo.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 378 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_XwqZ15r0LrY.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 379 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_lqLVfyHKFoQ.parquet'
#         INTO TABLE comentarios_youtube
#
# iteração 380 --- de 381
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/comentarios/comentarios_35_FkoRogNY.parquet'
#         INTO TABLE comentarios_youtube

# %%
df_total_video_publicacao_semana = spark.read \
    .parquet('hdfs://localhost:9000/projeto/datalake_youtube/backup/video_publicado_semana.parquet')
df_total_video_publicacao_semana = df_total_video_publicacao_semana.withColumn('TOTAL_VIDEOS', F.col('TOTAL_VIDEOS').cast('int'))
df_total_video_publicacao_semana.show(truncate=False)
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +----------------+---------------------------+------------+---------------+------------------------+------------------------+
# |SEMANA_TRADUZIDA|NM_CANAL                   |TOTAL_VIDEOS|DATA_PUBLICACAO|ASSUNTO                 |ID_CANAL                |
# +----------------+---------------------------+------------+---------------+------------------------+------------------------+
# |Segunda-feira   |Patricia de Siqueira Ramos |1           |2023-10-23     |assunto_python_and_dados|UCd8_GwocCAx0aIi9gwWA0rQ|
# |Terça-feira     |Data Science Challenge ITA |1           |2023-10-24     |assunto_python_and_dados|UC5WY2gtQ136zqASt2kdCjcA|
# |Terça-feira     |Ciência de Dados Prática   |1           |2023-10-17     |assunto_python_and_dados|UCnR_-6nHlN-RrKl76IHOxcw|
# |Sexta-feira     |Jason AI - Português       |1           |2023-10-27     |assunto_python_and_dados|UCYvDxCsrwxOA-8MBZAzzFIA|
# |Sexta-feira     |IA Descomplicada           |1           |2023-10-27     |assunto_python_and_dados|UCYvDxCsrwxOA-8MBZAzzFIA|
# |Quarta-feira    |Garotos da Programação     |1           |2023-10-25     |assunto_python_and_dados|UCw8oQLhyxGelpxXjnKiqWOA|
# |Terça-feira     |Programação e Liberdade    |1           |2023-10-17     |assunto_python_and_dados|UCa-d0hwYHOu6ehwc_oMjOoA|
# |Quarta-feira    |Professor Gabriel Pacheco  |1           |2023-10-25     |assunto_python_and_dados|UC7FD56H8vyZA30oL8c7ziHQ|
# |Quarta-feira    |Variedades e Dicas         |1           |2023-10-18     |assunto_python_and_dados|UCSsSCK_7t7QP_rHh8zu_0Iw|
# |Quarta-feira    |MARCELO ELIDIO             |1           |2023-10-18     |assunto_python_and_dados|UCSsSCK_7t7QP_rHh8zu_0Iw|
# |Quinta-feira    |Xperiun | Data Analytics   |1           |2023-10-19     |assunto_python_and_dados|UCOcjS2ppQSqIsbMgWGCfLew|
# |Quinta-feira    |Ciência de Dados Brasil    |1           |2023-10-26     |assunto_python_and_dados|UCwwLM_dJ2o52sTJHN7hojxw|
# |Sábado          |Eduardo | Ciência dos Dados|1           |2023-10-21     |assunto_python_and_dados|UCd3ThZLzVDDnKSZMsbK0icg|
# |Quarta-feira    |Programador Aventureiro    |1           |2023-10-18     |assunto_python_and_dados|UCKJ2JOMmbgpoRnu7G6-notQ|
# |Quarta-feira    |Programador Aventureiro    |1           |2023-10-25     |assunto_python_and_dados|UCKJ2JOMmbgpoRnu7G6-notQ|
# |Terça-feira     |EEMTI Waldir Leopércio     |1           |2023-10-24     |assunto_python_and_dados|UC-SgvBqx-XY3MXiqhsQB-FQ|
# |Quinta-feira    |Programação Dinâmica       |1           |2023-10-26     |assunto_python_and_dados|UC70mr11REaCqgKke7DPJoLg|
# |Sábado          |#Orientação Em Tecnologia  |1           |2023-10-21     |assunto_python_and_dados|UCtfSUve5SABGVxMOuYXn8HA|
# |Terça-feira     |Digital Tech Formation     |1           |2023-10-17     |assunto_python_and_dados|UCPGt5HY30kWEbzT1-KAjHqg|
# |Sexta-feira     |Ninja da Programação       |1           |2023-10-20     |assunto_python_and_dados|UCNqlxCA5plQcNHB0w3D1ndA|
# +----------------+---------------------------+------------+---------------+------------------------+------------------------+
# only showing top 20 rows

# %%
df_total_video_publicacao_semana.printSchema()
# Out:
# root
#  |-- SEMANA_TRADUZIDA: string (nullable = true)
#  |-- NM_CANAL: string (nullable = true)
#  |-- TOTAL_VIDEOS: integer (nullable = true)
#  |-- DATA_PUBLICACAO: date (nullable = true)
#  |-- ASSUNTO: string (nullable = true)
#  |-- ID_CANAL: string (nullable = true)

# %%
colunas_video_publicado = df_total_video_publicacao_semana.columns

# %%
colunas_video_publicado
# Out:
# ['SEMANA_TRADUZIDA',
#  'NM_CANAL',
#  'TOTAL_VIDEOS',
#  'DATA_PUBLICACAO',
#  'ASSUNTO',
#  'ID_CANAL']

# %%
for coluna_video_publicado in colunas_video_publicado:
    df_total_video_publicacao_semana.groupBy(coluna_video_publicado).count().orderBy('count', ascending=False).show()
# Out:
# +----------------+-----+
# |SEMANA_TRADUZIDA|count|
# +----------------+-----+
# |   Segunda-feira|  157|
# |     Sexta-feira|  155|
# |    Quarta-feira|  154|
# |    Quinta-feira|  153|
# |     Terça-feira|  147|
# |         Domingo|   82|
# |          Sábado|   68|
# +----------------+-----+
#
# +--------------------+-----+
# |            NM_CANAL|count|
# +--------------------+-----+
# |     ChratosGameplay|   26|
# |       Irmãos Cities|   18|
# |       Canal do Void|   16|
# |          Simularies|   13|
# |Hashtag Treinamentos|   12|
# |        Lille School|   12|
# |           MetalBear|   12|
# |      Betospa Gaming|   12|
# |Lucas gameplays b...|   11|
# |          Data Mundo|   10|
# |       Túlio Melibeu|   10|
# |Prof. Dr. Lucimar...|   10|
# |    Cristão Pensador|   10|
# |       Análise Macro|    9|
# |       Tales Augusto|    9|
# |      Barbosa Cities|    9|
# |            Majestic|    8|
# |Office Resolve - ...|    8|
# |      Cabrunco Games|    8|
# |  Lives do IVDMALUCO|    8|
# +--------------------+-----+
# only showing top 20 rows
#
# +------------+-----+
# |TOTAL_VIDEOS|count|
# +------------+-----+
# |           1|  916|
# +------------+-----+
#
# +---------------+-----+
# |DATA_PUBLICACAO|count|
# +---------------+-----+
# |     2023-10-23|   96|
# |     2023-10-26|   93|
# |     2023-10-27|   90|
# |     2023-10-24|   86|
# |     2023-10-25|   85|
# |     2023-10-18|   69|
# |     2023-10-21|   68|
# |     2023-10-20|   65|
# |     2023-10-16|   61|
# |     2023-10-17|   61|
# |     2023-10-19|   60|
# |     2023-10-22|   54|
# |     2023-10-15|   28|
# +---------------+-----+
#
# +--------------------+-----+
# |             ASSUNTO|count|
# +--------------------+-----+
# |    assunto_power_bi|  308|
# |assunto_cities_sk...|  235|
# |assunto_python_an...|  197|
# |assunto_cities_sk...|  176|
# +--------------------+-----+
#
# +--------------------+-----+
# |            ID_CANAL|count|
# +--------------------+-----+
# |UCrOH1V-FyMunBIMr...|   26|
# |UC1mk6EtfMjxR4eEZ...|   18|
# |UCrUcdH_bCfX77xpX...|   16|
# |UCDGo_s0I-2JpO3o3...|   13|
# |UCqj1vaTl3NZtFElz...|   12|
# |UCw0leRmeaX7R_9BD...|   12|
# |UCfY4ggUDPeecGSCN...|   12|
# |UCkXA2EoaXRFW18vr...|   12|
# |UCOYJm7BsLV8VCkW2...|   11|
# |UCENbpaPgVhO2GtlN...|   10|
# |UCVM5Kg0mLSmmvdmh...|   10|
# |UC0MyjIBbIDlOBCUf...|   10|
# |UCrQQUCh77WceaMFa...|   10|
# |UCCxTIMnbG7xoGDD5...|   10|
# |UCMdNR-VCYnozREcE...|    9|
# |UCShgvN-cGaRtsu4J...|    9|
# |UCe9jrI0YQ5SM6h5Q...|    9|
# |UCRIafgU7_URCZXt6...|    8|
# |UC7v51W2NoLFawizg...|    8|
# |UCts_EXWl-EeycUUA...|    8|
# +--------------------+-----+
# only showing top 20 rows

# %%
lista_canaislista_semana_traduzida = [ linha['SEMANA_TRADUZIDA'] for linha in df_total_video_publicacao_semana.select('SEMANA_TRADUZIDA').distinct().collect()]
lista_semana_traduzida
# Out:
# ['Segunda-feira',
#  'Quarta-feira',
#  'Terça-feira',
#  'Sábado',
#  'Sexta-feira',
#  'Domingo',
#  'Quinta-feira']

# %%
for semana_traduzida in lista_semana_traduzida:
    df_total_video_publicacao_semana \
        .filter(df_total_video_publicacao_semana.SEMANA_TRADUZIDA == semana_traduzida) \
        .write \
        .parquet(f'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/video_publicado_semana/video_publicado_semana_{semana_traduzida}.parquet')
# Out:
# [Stage 8:>                                                          (0 + 7) / 7]
# 23/11/20 16:02:44 WARN MemoryManager: Total allocation exceeds 95,00% (906.992.014 bytes) of heap memory
# Scaling row group sizes to 96,54% for 7 writers
# 23/11/20 16:02:47 WARN MemoryManager: Total allocation exceeds 95,00% (906.992.014 bytes) of heap memory
# Scaling row group sizes to 96,54% for 7 writers
# [Stage 10:>                                                         (0 + 7) / 7]
# 23/11/20 16:02:48 WARN MemoryManager: Total allocation exceeds 95,00% (906.992.014 bytes) of heap memory
# Scaling row group sizes to 96,54% for 7 writers
# 23/11/20 16:02:50 WARN MemoryManager: Total allocation exceeds 95,00% (906.992.014 bytes) of heap memory
# Scaling row group sizes to 96,54% for 7 writers
# 23/11/20 16:02:51 WARN MemoryManager: Total allocation exceeds 95,00% (906.992.014 bytes) of heap memory
# Scaling row group sizes to 96,54% for 7 writers
# 23/11/20 16:02:53 WARN MemoryManager: Total allocation exceeds 95,00% (906.992.014 bytes) of heap memory
# Scaling row group sizes to 96,54% for 7 writers
# 23/11/20 16:02:55 WARN MemoryManager: Total allocation exceeds 95,00% (906.992.014 bytes) of heap memory
# Scaling row group sizes to 96,54% for 7 writers

# %%
spark.stop()

# %%
len(lista_semana_traduzida)
# Out:
# 7

# %%
cursor = conn.cursor()
cursor.execute('USE youtube')
for chave,  semana_traduzida in enumerate(lista_semana_traduzida):

    print(f'iteração {chave + 1} --- de {str(len(lista_semana_traduzida) + 1)}')
    try:
        

        query = f'''
        LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/video_publicado_semana/video_publicado_semana_{semana_traduzida}.parquet'
        INTO TABLE TOTAL_VIDEO_PUBLICADO_SEMANA
        '''
        print(query)
        
        cursor.execute(query)
    except:
        cursor.close()
        print(f'deu ruim em {chave + 1}')
        break

cursor.close()
# Out:
# iteração 1 --- de 8
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/video_publicado_semana/video_publicado_semana_Segunda-feira.parquet'
#         INTO TABLE TOTAL_VIDEO_PUBLICADO_SEMANA
#
# iteração 2 --- de 8
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/video_publicado_semana/video_publicado_semana_Quarta-feira.parquet'
#         INTO TABLE TOTAL_VIDEO_PUBLICADO_SEMANA
#
# iteração 3 --- de 8
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/video_publicado_semana/video_publicado_semana_Terça-feira.parquet'
#         INTO TABLE TOTAL_VIDEO_PUBLICADO_SEMANA
#
# iteração 4 --- de 8
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/video_publicado_semana/video_publicado_semana_Sábado.parquet'
#         INTO TABLE TOTAL_VIDEO_PUBLICADO_SEMANA
#
# iteração 5 --- de 8
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/video_publicado_semana/video_publicado_semana_Sexta-feira.parquet'
#         INTO TABLE TOTAL_VIDEO_PUBLICADO_SEMANA
#
# iteração 6 --- de 8
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/video_publicado_semana/video_publicado_semana_Domingo.parquet'
#         INTO TABLE TOTAL_VIDEO_PUBLICADO_SEMANA
#
# iteração 7 --- de 8
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/video_publicado_semana/video_publicado_semana_Quinta-feira.parquet'
#         INTO TABLE TOTAL_VIDEO_PUBLICADO_SEMANA

# %%
df_total_visualizacoes_semana = spark.read \
    .parquet('hdfs://localhost:9000/projeto/datalake_youtube/backup/total_visualizacoes_semana.parquet')
df_total_visualizacoes_semana.show(truncate=False)
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +---------------+---------------------------------------------------------------------------------------------+---------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+----------+-------------------+-----------------+-----------+-----------------------+---------------------+---------------+-------------+-----------------------+------------------------+-----------+
# |NM_CANAL       |TITULO_VIDEO                                                                                 |TOTAL_CARACTERE_VIDEO|TAGS                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |DURACAO_VIDEO_MINUTOS|TOTAL_TAGS|TOTAL_VISUALIZACOES|TOTAL_COMENTARIOS|TOTAL_LIKES|TOTAL_VISUALIZACOES_DIA|TOTAL_COMENTARIOS_DIA|TOTAL_LIKES_DIA|data_extracao|ASSUNTO                |ID_CANAL                |ID_VIDEO   |
# +---------------+---------------------------------------------------------------------------------------------+---------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+----------+-------------------+-----------------+-----------+-----------------------+---------------------+---------------+-------------+-----------------------+------------------------+-----------+
# |ChratosGameplay|CITIES SKYLINES 2: É PAU É PEDRA É A ECONOMIA DA CIDADE DO CHAT! (LINK DESCRIÇÃO)            |81                   |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |0.0                  |0         |0                  |0                |50         |0                      |0                    |50             |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|-QaSHAsHQSs|
# |ChratosGameplay|PREFEITURA E PREVIDÊNCIA CHEGAM A CIDADE! 🏙️ - Cities Skylines 2 #7                         |67                   |[cities skylines, cities skylines 2, cities skylines gameplay, cities skylines 2 gameplay, cities, skylines, gameplay, city builder, cities skylines como começar, cities skylines tutorial, city skylines, tutorial, citybuilder, brasil, cities: skylines, mods, cities skylines pt br, cidade, chratos, cities skylines 2 vs 1, cities skylines 2 tutorial, cities skylines 2 mods, cities skylines ii, cities 2, cs2, city skylines 2, cities skylines 2 ptbr, cities: skylines 2 pt br, pt, br, ptbr]              |26.88                |31        |42650              |220              |5600       |3257                   |5                    |283            |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|6RgEh-9KAgY|
# |ChratosGameplay|SUPER SUBÚRBIO FAZ ALCANÇAR 10000 HABITANTES 🏙️ - Cities Skylines 2 #4                      |70                   |[cities skylines, cities skylines 2, cities skylines gameplay, cities skylines 2 gameplay, cities, skylines, gameplay, city builder, cities skylines como começar, cities skylines tutorial, city skylines, tutorial, citybuilder, brasil, cities: skylines, mods, cities skylines pt br, cidade, chratos, cities skylines 2 vs 1, cities skylines 2 tutorial, cities skylines 2 mods, cities skylines ii, cities 2, cs2, city skylines 2, cities skylines 2 ptbr, cities: skylines 2 pt br, pt, br, ptbr]              |25.67                |31        |54375              |213              |6855       |1561                   |213                  |148            |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|9SGBZ7GE5EA|
# |ChratosGameplay|POLUIÇÃO FORÇA MIGRAÇÃO DA INDÚSTRIA PARA NOVO DISTRITO 🏙️ - Cities Skylines 2 #5           |81                   |[cities skylines, cities skylines 2, cities skylines gameplay, cities skylines 2 gameplay, cities, skylines, gameplay, city builder, cities skylines como começar, cities skylines tutorial, city skylines, tutorial, citybuilder, brasil, cities: skylines, mods, cities skylines pt br, cidade, chratos, cities skylines 2 vs 1, cities skylines 2 tutorial, cities skylines 2 mods, cities skylines ii, cities 2, cs2, city skylines 2, cities skylines 2 ptbr, cities: skylines 2 pt br, pt, br, ptbr]              |28.43                |31        |50789              |124              |6448       |1853                   |124                  |165            |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|KfzZNkdyeEs|
# |ChratosGameplay|TRANSPORTE PÚBLICO DE MASSA COM TRENS! 🏙️ - Cities Skylines 2 #8                            |64                   |[cities skylines, cities skylines 2, cities skylines gameplay, cities skylines 2 gameplay, cities, skylines, gameplay, city builder, cities skylines como começar, cities skylines tutorial, city skylines, tutorial, citybuilder, brasil, cities: skylines, mods, cities skylines pt br, cidade, chratos, cities skylines 2 vs 1, cities skylines 2 tutorial, cities skylines 2 mods, cities skylines ii, cities 2, cs2, city skylines 2, cities skylines 2 ptbr, cities: skylines 2 pt br, pt, br, ptbr]              |32.28                |31        |39265              |180              |5046       |13719                  |37                   |1003           |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|QwXP79P4xS0|
# |ChratosGameplay|BALSAS, BUSÕES E BONDES SALVARAM TRÂNSITO? 🏙️ - Cities Skylines 2 #6                        |68                   |[cities skylines, cities skylines 2, cities skylines gameplay, cities skylines 2 gameplay, cities, skylines, gameplay, city builder, cities skylines como começar, cities skylines tutorial, city skylines, tutorial, citybuilder, brasil, cities: skylines, mods, cities skylines pt br, cidade, chratos, cities skylines 2 vs 1, cities skylines 2 tutorial, cities skylines 2 mods, cities skylines ii, cities 2, cs2, city skylines 2, cities skylines 2 ptbr, cities: skylines 2 pt br, pt, br, ptbr]              |29.13                |31        |50480              |157              |6330       |2027                   |2                    |171            |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|TBZuVHi3QdM|
# |ChratosGameplay|CITIES SKYLINES 2: LANÇAMENTO OFICIAL E EXPLORANDO A ECONOMIA DO JOGO! (LINK DESCRIÇÃO)      |87                   |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |0.0                  |0         |0                  |0                |51         |0                      |0                    |51             |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|V_d6T_UKRDg|
# |ChratosGameplay|MODDERS decidem fazer O MELHOR JOGO DE GERENCIMENTO COM COMBATE TÁTICO? 🎖️ - Ascent of Ashes|92                   |[ascent of ashes, rimworld, chratos, gameplay, chratosgameplay, pt, br, ptbr, portugal, brasil, ascent of ashes gameplay, colony sim, rimworld gameplay, rimworld mods, base building, city builder, ascent of ashes game, colony sim games 2023, colony simulator, colony sim games, estratégia, gerenciamento, 2023, ascent of ashes steam, ascent of ashes download, rimworld fans, rimworld lets play, rimworld combat extended, strategy, rts, real time tactics, tático, combate]                                 |23.25                |33        |9540               |33               |1078       |19                     |33                   |2              |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|
# |ChratosGameplay|Planejamento inicial PODE SALVAR SUA CIDADE! 🚗 - Cities Skylines  - CONSERTANDO O TRÂNSITO  |90                   |[Cities Skylines, parklife, dlc, new, gameplay, chratos, paradox, citybuilder, cities: skylines, video game, city builder, paradox interactive, game, cities, colossal order, city building, cities skylines dlc, skylines, let's play, construir, parque, portugal, pt-br, pt br, brasil, steam, jogo, tutorial, lets play, mod, mods, cities skylines tutorial roads, cities skylines gameplay, cities skylines como começar, cities skylines gameplay 2020, cities skylines dicas transito, cities skylines tutorial]|25.22                |37        |18599              |79               |2418       |169                    |79                   |14             |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|dRzwiPwGH_M|
# |ChratosGameplay|CITIES SKYLINES 2: BORA LEVANTAR UMA CIDADE COM A PARTICIPAÇÃO DO CHAT! (LINK DESCRIÇÃO)     |88                   |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |0.0                  |0         |0                  |0                |149        |0                      |0                    |149            |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|mfCGsYnClDU|
# |ChratosGameplay|PEQUENA FORTUNA EM SERVIÇOS PÚBLICOS BÁSICOS 🏙️ - Cities Skylines 2 #2                      |70                   |[cities skylines, cities skylines 2, cities skylines gameplay, cities skylines 2 gameplay, cities, skylines, gameplay, city builder, cities skylines como começar, cities skylines tutorial, city skylines, tutorial, citybuilder, brasil, cities: skylines, mods, cities skylines pt br, cidade, chratos, cities skylines 2 vs 1, cities skylines 2 tutorial, cities skylines 2 mods, cities skylines ii, cities 2, cs2, city skylines 2, cities skylines 2 ptbr, cities: skylines 2 pt br, pt, br, ptbr]              |31.92                |31        |71357              |188              |8978       |1889                   |2                    |139            |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|totHMIv6_hI|
# |ChratosGameplay|DO CRIADOR DA MELHOR CIDADE JÁ FEITA, A NOVA MELHOR CIDADE? 🏢 - Cities Skylines Showcase    |88                   |[cities skylines, cities skylines 2, cities skylines gameplay, cities skylines 2 gameplay, cities skylines financial district, cities skylines airport, cities skylines timelapse, cities skylines vanilla, cities skylines mods, cities skylines dlc, cities, skylines, gameplay, city builder, cities skylines como começar, cities skylines tutorial, city skylines, tutorial, colossal order, citybuilder, paradox, brasil, lets play, cities: skylines, mods, cities skylines pt br, cidade, chratos]              |42.43                |28        |33628              |111              |3382       |1246                   |1                    |61             |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|up4KrHrRwLY|
# |ChratosGameplay|PRIMEIRA PRAÇA DA CIDADE SAI DO PAPEL 🏙️ - Cities Skylines 2 #3                             |63                   |[cities skylines, cities skylines 2, cities skylines gameplay, cities skylines 2 gameplay, cities, skylines, gameplay, city builder, cities skylines como começar, cities skylines tutorial, city skylines, tutorial, citybuilder, brasil, cities: skylines, mods, cities skylines pt br, cidade, chratos, cities skylines 2 vs 1, cities skylines 2 tutorial, cities skylines 2 mods, cities skylines ii, cities 2, cs2, city skylines 2, cities skylines 2 ptbr, cities: skylines 2 pt br, pt, br, ptbr]              |22.95                |31        |60786              |201              |7321       |1568                   |1                    |156            |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|vy-upTpchig|
# |ChratosGameplay|MELHOR JOGO DE CONSTRUIR CIDADES CHEGOU E ESTÁ LINDO 🏙️ - Cities Skylines 2                 |75                   |[cities skylines, cities skylines 2, cities skylines gameplay, cities skylines 2 gameplay, cities, skylines, gameplay, city builder, cities skylines como começar, cities skylines tutorial, city skylines, tutorial, citybuilder, brasil, cities: skylines, mods, cities skylines pt br, cidade, chratos, cities skylines 2 vs 1, cities skylines 2 tutorial, cities skylines 2 mods, cities skylines ii, cities 2, cs2, city skylines 2, cities skylines 2 ptbr, cities: skylines 2 pt br, pt, br, ptbr]              |19.63                |31        |120812             |418              |13988      |3437                   |2                    |204            |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|wCLSZxLfUAk|
# |ChratosGameplay|Vias expressas/Rodovias e aneis rodoviários - Guia de planejamento - Cities Skylines 2       |86                   |[cities skylines, cities skylines 2, cities skylines gameplay, cities skylines 2 gameplay, cities, skylines, gameplay, city builder, cities skylines como começar, cities skylines tutorial, city skylines, tutorial, citybuilder, brasil, cities: skylines, mods, cities skylines pt br, cidade, chratos, cities skylines 2 vs 1, cities skylines 2 tutorial, cities skylines 2 mods, cities skylines ii, cities 2, cs2, city skylines 2, cities skylines 2 ptbr, cities: skylines 2 pt br, pt, br, ptbr]              |19.02                |31        |18620              |54               |1368       |2388                   |3                    |100            |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|xCaUzgIM6Bg|
# |ChratosGameplay|OBRAS DO ANEL RODOVIÁRIO COMPLETA! 🏙️ - Cities Skylines 2 #9                                |60                   |[cities skylines, cities skylines 2, cities skylines gameplay, cities skylines 2 gameplay, cities, skylines, gameplay, city builder, cities skylines como começar, cities skylines tutorial, city skylines, tutorial, citybuilder, brasil, cities: skylines, mods, cities skylines pt br, cidade, chratos, cities skylines 2 vs 1, cities skylines 2 tutorial, cities skylines 2 mods, cities skylines ii, cities 2, cs2, city skylines 2, cities skylines 2 ptbr, cities: skylines 2 pt br, pt, br, ptbr]              |26.32                |31        |15805              |139              |2753       |15805                  |139                  |2753           |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|xSAyLQ9h22k|
# |ChratosGameplay|Vias coletoras/arteriais e avenidas - Guia de planejamento - Cities Skylines 2               |78                   |[cities skylines, cities skylines 2, cities skylines gameplay, cities skylines 2 gameplay, cities, skylines, gameplay, city builder, cities skylines como começar, cities skylines tutorial, city skylines, tutorial, citybuilder, brasil, cities: skylines, mods, cities skylines pt br, cidade, chratos, cities skylines 2 vs 1, cities skylines 2 tutorial, cities skylines 2 mods, cities skylines ii, cities 2, cs2, city skylines 2, cities skylines 2 ptbr, cities: skylines 2 pt br, pt, br, ptbr]              |16.78                |31        |19942              |63               |1950       |435                    |1                    |32             |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|zFO5_abqEss|
# |ChratosGameplay|SIMULADOR DE PLATAFORMA DE PETRÓLEO DA PETROBRÁS! ⛽ - Drill Deal                             |64                   |[drill deal, drill deal oil tycoon, oil tycoon, drill deal – oil tycoon, drill deal gameplay, drill deal ps4, drill deal pc, drill deal oil tycoon gameplay, oil tycoon game, chratos, gameplay, chratosgameplay, pt, br, ptbr, português, portugal, brasil, drill deal oil tycoon review, drill deals, pt br, magnata do petróleo, drill deal trailer, drill deal game, drill deal lets play, tycoon, petrobrás, petróleo, plataforma, estratégia, gerenciamento, city builder, cities skylines]                       |34.05                |33        |24021              |40               |2441       |324                    |40                   |8              |2023-10-27   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|zyG3nFm9BB8|
# |ChratosGameplay|CITIES SKYLINES 2: É PAU É PEDRA É A ECONOMIA DA CIDADE DO CHAT! (LINK DESCRIÇÃO)            |81                   |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |0.0                  |0         |0                  |0                |50         |0                      |0                    |50             |2023-10-26   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|-QaSHAsHQSs|
# |ChratosGameplay|PREFEITURA E PREVIDÊNCIA CHEGAM A CIDADE! 🏙️ - Cities Skylines 2 #7                         |67                   |[cities skylines, cities skylines 2, cities skylines gameplay, cities skylines 2 gameplay, cities, skylines, gameplay, city builder, cities skylines como começar, cities skylines tutorial, city skylines, tutorial, citybuilder, brasil, cities: skylines, mods, cities skylines pt br, cidade, chratos, cities skylines 2 vs 1, cities skylines 2 tutorial, cities skylines 2 mods, cities skylines ii, cities 2, cs2, city skylines 2, cities skylines 2 ptbr, cities: skylines 2 pt br, pt, br, ptbr]              |26.88                |31        |39393              |215              |5317       |14489                  |36                   |1215           |2023-10-26   |assunto_cities_skylines|UCrOH1V-FyMunBIMrKL0y0xQ|6RgEh-9KAgY|
# +---------------+---------------------------------------------------------------------------------------------+---------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+----------+-------------------+-----------------+-----------+-----------------------+---------------------+---------------+-------------+-----------------------+------------------------+-----------+
# only showing top 20 rows

# %%
colunas_visualizacoes_semana = df_total_visualizacoes_semana.columns
colunas_visualizacoes_semana
# Out:
# ['NM_CANAL',
#  'TITULO_VIDEO',
#  'TOTAL_CARACTERE_VIDEO',
#  'TAGS',
#  'DURACAO_VIDEO_MINUTOS',
#  'TOTAL_TAGS',
#  'TOTAL_VISUALIZACOES',
#  'TOTAL_COMENTARIOS',
#  'TOTAL_LIKES',
#  'TOTAL_VISUALIZACOES_DIA',
#  'TOTAL_COMENTARIOS_DIA',
#  'TOTAL_LIKES_DIA',
#  'data_extracao',
#  'ASSUNTO',
#  'ID_CANAL',
#  'ID_VIDEO']

# %%
lista_canais = [ linha['ID_CANAL'] for linha in df_total_visualizacoes_semana.select('ID_CANAL').distinct().collect()]
lista_canais
# Out:
# ['UCfY4ggUDPeecGSCNePyyVSA',
#  'UCYEb5mbKZ5JJzN0xBuKyaig',
#  'UCShgvN-cGaRtsu4JeZJ5NWw',
#  'UC0MyjIBbIDlOBCUfl7iO9bg',
#  'UCNNJFz7px0NBlg7Lw6A9tMg',
#  'UCxDJUOOiBlEl_jl5Ox24qjg',
#  'UC6JcLNZDLTNI_XsjJtMR3lQ',
#  'UCp7gzkfbWE7jazP65W9ZtWg',
#  'UCqj1vaTl3NZtFElzCZNyKpA',
#  'UCBSrzvbMoru6PsayN3Z7ZsA',
#  'UCLB1zHWq064-nxdxVrABiUA',
#  'UC-BDIFDYMrh4aqlEuqnldEg',
#  'UChTLNqbdIMNny_vCqn6e-iA',
#  'UCwwLM_dJ2o52sTJHN7hojxw',
#  'UCw0leRmeaX7R_9BDd3TvCzg',
#  'UCqFAXxARXQHx0t_mm_eElcA',
#  'UCtRNcB3lcaJ75CsRUG7CcLw',
#  'UCaTiVclf7mD7Wzbbsm6gGOA',
#  'UCoGkNtefcmsMbTosHEgLrdw',
#  'UCMqGy4xIIGs01ZVcBv0B8Cw',
#  'UC9LwSTLQx2V7G8wmJiJw8KA',
#  'UCrSWO9gdMOC1qO34bbAX9RQ',
#  'UCe9jrI0YQ5SM6h5QRZ9FZlA',
#  'UCafFexaRoRylOKdzGBU6Pgg',
#  'UCL5k8vBBo1JOHh7AnvoD8xQ',
#  'UCCxTIMnbG7xoGDD5YsqeBag',
#  'UCkfyKm2S5eSurJDt3TATq-A',
#  'UC7v51W2NoLFawizgcNuVBOA',
#  'UCjKatVVFkhVdufkU7EyuTGg',
#  'UCDGo_s0I-2JpO3o3xlkMQVA',
#  'UCKJ2JOMmbgpoRnu7G6-notQ',
#  'UC9sKp_hMnOsATpvh0Ad54fw',
#  'UCn7w7H6jL0G3TNpV1v0SZRg',
#  'UCcuLEJUZy4jo9iFvngkoBUg',
#  'UC70mr11REaCqgKke7DPJoLg',
#  'UCvz12BbOXa7nJ-zbkQ6tI6A',
#  'UC4sR2FCJkVIq4pqFxLyOArA',
#  'UCayiH2Y5JBEOSubqoQhufDA',
#  'UC-cKIIGsroQqpH91A7nQGgg',
#  'UC5Bn1EuTqaQNCCKo_9SAi_w',
#  'UCqqJsllgIjDZjLE74Bba9og',
#  'UCKlyjSFal7jgtMVDEGnB7YQ',
#  'UCtfSUve5SABGVxMOuYXn8HA',
#  'UCtaDOcil7AXjT28K0mW7UQA',
#  'UCHQun4keJGrj8RqDPPpyUsg',
#  'UCGyqOs1_RKC8CBndIkzTxzw',
#  'UCsi_LmcdII_1jAPSuGEjgnA',
#  'UCcinq1ymmAmhFZzyOeaGjiA',
#  'UCDqzBrUOm7guqqyU8eDackg',
#  'UCrUcdH_bCfX77xpXHyq2fJw',
#  'UChu8BOyORQaKfaf8cUmVrlg',
#  'UCp98bXHSc01w8fBfkkgHB1Q',
#  'UCwMQikMlRfKkcn6A7nx2EmQ',
#  'UC-4oKsd_5_Q5sy8t6g3JMRA',
#  'UCmg3_taw1BrGuo1ITlQe2hA',
#  'UC6whuyplYhUcz4k0I7Cx0_g',
#  'UCm4Btb0FJ1OymCphQ0HTsVw',
#  'UC8FS3_qf6F194QTYwxwFGMw',
#  'UCkXA2EoaXRFW18vrAE01BpQ',
#  'UCxIMGC-GmZ2pXE_jGGW2C9A',
#  'UC1mk6EtfMjxR4eEZ7C43zTQ',
#  'UCrOH1V-FyMunBIMrKL0y0xQ',
#  'UCMdNR-VCYnozREcEt1xkcHg',
#  'UCYDluKEjFODZQueXT0pZJfg',
#  'UCrxFTbIV_8sUVJ596fkzBsg',
#  'UCEdUXu7Rgo0KT7UAtMy-Qkw',
#  'UCwBN6GQiolq3EkRPYC7OTtA',
#  'UCRIafgU7_URCZXt6X9XMbAg',
#  'UC-N8y8IuT8B44h-IQQAmq4w',
#  'UCOYJm7BsLV8VCkW2DC1MI5w',
#  'UCENbpaPgVhO2GtlNcwAJ8mA',
#  'UCYvDxCsrwxOA-8MBZAzzFIA',
#  'UCrQQUCh77WceaMFae4ykm7w',
#  'UCg6yqeJJ2WMFVt9bXeUd-zA',
#  'UC3P9lC-O8Rr1Ggc3oIIqIkg',
#  'UCgLBFiwTtgJ8hdNFeFAkeyw',
#  'UCOcjS2ppQSqIsbMgWGCfLew',
#  'UCOe_x5ararWwWajBKbFKNkA',
#  'UCM7FGFGU3NL7frvJ7MkNzAg',
#  'UCHEuAFdws9OCZPcfTBuxtCw',
#  'UCNv3_KHnWEzLc3BCxYXpHFQ',
#  'UCxy9ZMwZfP8ccgMrpbVtmTA',
#  'UCf15n72n6pV0RK6-GOi1s1Q',
#  'UCts_EXWl-EeycUUAEy44NmQ',
#  'UCOvNVIUa1wq7Aq7xaOI3P7g',
#  'UCiaL33s_HVulWylA63eMXJw',
#  'UCEn6ZNpD9Qpgqh28c0nT1Rw',
#  'UCQqcBxrAKR1ixtPNHL9U3Ew',
#  'UC_bJMXMZkxdkLcSeZGCqTqQ',
#  'UCW7i1eD6-PVfHsBIfsGOkXA',
#  'UC21HmquxkP-IAqa2HNLhFOg',
#  'UCwd-rkFy2k-Jv-5sSS_py3A',
#  'UClIi1-5iixE2yLdV9JiXLbQ',
#  'UCojjOrsQAKNOOrE4mocSghw',
#  'UCMWG5_iw-j-eLFfIJAlWLOQ',
#  'UC5K-TQsItHnNLjqYf8A3CTw',
#  'UCBgYMaTBbXgaP5YsEDoShTg',
#  'UCck21CJKhTfldiwrfJo7HgA',
#  'UCak0L-2P3B9-sf9-yiuJj6Q',
#  'UCfAPIE6M2aHyNO-AXwbID2w',
#  'UCiRdaC8jG1-K87ciSUbT2iw',
#  'UCCe4Be21OPPltTTIHP4lDvg',
#  'UC4sUVsopaPbjn5JzHDwdjMg',
#  'UCMLxzf6bkTtKe_V5novlVwg',
#  'UC7FD56H8vyZA30oL8c7ziHQ',
#  'UCJYFuFymG6_6TLUxC-4YHzA',
#  'UCdZK6DwemFBiKHlkez2tdUA',
#  'UCSlrbSybttMqpM_TDcXojyw',
#  'UCEQkAgXk_T3sDMx9YSdz-cQ',
#  'UCORAFKQRRpiCov_kFQoGONQ',
#  'UCo95QXpNpiX-J_sy4ujSE-g',
#  'UCcT7u9KeCH6v_ReHZcUhXoA',
#  'UCEc5jA0NvvR-yJC0SISV6nw',
#  'UCTrNnXivZU_1-aJqn1uNANg',
#  'UC0Yr63KmXTFXy07iT4egAOA',
#  'UCNqlxCA5plQcNHB0w3D1ndA',
#  'UCKGeaczIbVQsXG8Mwy8EadA',
#  'UCABm0SdJCoM6z0MFod7s3Lg',
#  'UC-ueVxV50bTa6cCwsIl5eHA',
#  'UC_Fk7hHbl7vv_7K8tYqJd5A',
#  'UClZqcB3EsrcngoOxXh4rp8A',
#  'UCZh2Y-xZQ586ZFO5FYw8A1A',
#  'UCivfb2x3HUx3EukY_DIWB-g',
#  'UCGi_mAdy_Vp1x8RaUnmViqg',
#  'UCTKuRhO9EuWPUgMtF7VrY0Q',
#  'UCslMsMAL4dMtJCIAgQNevDQ',
#  'UCV4t8SmkcGLHXHbHteDiyHw',
#  'UC7sP7azSWwnqnSfuWLFJMrg',
#  'UCDvA6dimWFCsbYdhVJL5W1w',
#  'UCLAUYEY8ITQC8b47xyqybxg',
#  'UC_tHKzrUF6UWMmsE571lwbg',
#  'UCBrf43bKmJiAsfZCRMSnTzg',
#  'UCdUh1qAXm1gkZEk4L3rYRoA',
#  'UChKvQZHn33iHwAu8YMnLaIA',
#  'UCk8a_ETbXVLOlfmMBKgDlug',
#  'UCY9SX2eszZG1C63NpRARA9g',
#  'UCccdWOiGy2vEQKjUhNZHB_g',
#  'UCHuvObnh1-2fs6zL5nhVGtg',
#  'UCVM5Kg0mLSmmvdmhWH9OhiA',
#  'UC0ANZre7BfygNTf5RFDFTVA',
#  'UCuINY5yvdmMrMjuhlQ-NNuw',
#  'UCl2bR-hSQjx7stTrP9BSevw',
#  'UCECueo5gAX7odvuiLCjklbA',
#  'UCywooHx7UiGuhvyQS4qcHvA',
#  'UCR69dJLCC9C6dTBY1uNxcWg',
#  'UCaj6FB2mFZ2T9a61QtZsKPA',
#  'UCJHBJmrVd7ujf2eCEujukog',
#  'UCfpv91g04FgdO25S3lsZjsA',
#  'UC-p4bIdGN_XNPT8kz0i5u1w',
#  'UCvf1dm1mnzIqyCQpJYbVMUA',
#  'UCIv5D2ro1owj6P7OdZ4-BiA',
#  'UC-z3zm3WSO68tpB8y5SWLZA',
#  'UCIMUxCvkVcuDFXzwoR8H3fQ',
#  'UCla_gQERStTS74gxHMS6Tzw',
#  'UCbww3yb1rObMQURafrYgOiQ',
#  'UClGA2euv_zdZ442GcVBjcbg',
#  'UC44qgwxGNPbfaAGQV1K6kVg',
#  'UCPGt5HY30kWEbzT1-KAjHqg',
#  'UC_cAH76qc44vTEFBVXULPjQ',
#  'UCxtXKH7HqVxD5EOJKfMxCDw',
#  'UCo7EHzKF2zDFWszw7Dg4mPw',
#  'UCfSs49h-BXeShswb4P-tXFQ',
#  'UCsxON5820u2py83RRj-yElQ',
#  'UCfuxXVeeaS8cLj2kxcvOdYw',
#  'UCge0EdfsF-RPcr_efb4TMHQ',
#  'UC9KoV-VIjVins1OKHCj-BiA',
#  'UCtp_Ac43h5uUQcrtBbVS2IQ',
#  'UCIEd_yNwTVZr1JChrgYR7sw',
#  'UCezFMTgl1ezYv4HXG8b-dDg',
#  'UC6ZlYmIr3sdAmDLxnx-fk0g',
#  'UCjJUe8JYQgqOxC57jZyVsEg',
#  'UC_8n2zOvnrk_oh5tx9n621w',
#  'UCz1XR21d0ivMHFpe8h4alww',
#  'UCdsG3oYcpaxIZNm_Vy_nMxA',
#  'UCGved3ynk6ZhUvSKxzgweTw',
#  'UCfkgc6FfJCP362BdVNBpZHw',
#  'UCScwap3Ok7uI585dOVt4uBg',
#  'UCRGbH0l1TAZbIAUr10NpNnA',
#  'UCDZxPzC2DJ3aTkzTfTqyXHw',
#  'UCxfK8fA5D95ClVoK5D6oKHg',
#  'UCsyYkiEF8I270881fKSQV8w',
#  'UCd3ThZLzVDDnKSZMsbK0icg',
#  'UCTrEq-s7713neJ1Td9bg0Zg',
#  'UC9c1ArBS7twtRpy_NJ_qGwA',
#  'UCMsbzwrSvRJoa0JhS5YcsqQ',
#  'UCiEH9Jok5WimMmM9OIAR43Q',
#  'UCYlKzOEFqJso5foiWbRLZMA',
#  'UC49wSv8iP9xRoY7lgw-YmPg',
#  'UCFawuhdXRN3VNG2hjtH1hxg',
#  'UCS4vJlnzDYiPA7iWQI65IQw',
#  'UCC5w9Ias-S8E15hyS00Cfew',
#  'UCWABKW1m8Jb-uuBsLxe-16w',
#  'UCrvLV2DfjVctYlwCEB49MVg',
#  'UCTKHoF3nltC5Vc7p5kvyYMw',
#  'UCC6ayGbvqQ6R63aoz95ovuA',
#  'UCXOrxAfsH2rDmC_FkTVVm1Q',
#  'UCVGeMHXGFIPjzosF8SOYemA',
#  'UC3lDiHsc1pr3oBE66uQ-f0w',
#  'UCu3zxvlrYc6dYM3102Y5Y9g',
#  'UCrhZH-oxUpmnZRISf8Xw7rQ',
#  'UCHet69jpaA8xngifPoBstYw',
#  'UCNCMu1_0mQFX5NsB2Um4Oxg',
#  'UCrlUvYytIVrkoIZuvy9DF0A',
#  'UC7VsdBUkBvIBMRP7CU45XMA',
#  'UCaGrIWpwjWXT6OIQh9W4Riw',
#  'UCRt5pfs_8hq3-GUSjULoV9Q',
#  'UCoTIpyf8_RGzJ1LPTmvadaA',
#  'UCNaIAElKPANu-d7ysRpLcUg',
#  'UColWqaBtRa6AEyDen2h5lRg',
#  'UCBbMl4vZDvArxHrWoPtg_cw',
#  'UC5csyUXd3EC4PO56Tylhjrg',
#  'UCFUU89Kw-ZVXaFVwV3I2M1w',
#  'UCr7Zt9xGiQGXhTon-wHni7g',
#  'UCSsSCK_7t7QP_rHh8zu_0Iw',
#  'UCArranHxpFguoPoOndKkdTA',
#  'UC_Ed5ksOnDgmpUdK81z81gw',
#  'UCXso4Ho8UARhzS3I_LOVTKA',
#  'UCcn60fs5EMW8A_k9R-e4gEg',
#  'UCYbN_aCTRaUnzuLgLNohwSQ',
#  'UCQ75KjXjYW8y_M3jw7NRFow',
#  'UCRPuVExQTAAbc0yLhUD1f_g',
#  'UCvEj9EurcC8q5hkV-Apf4jA',
#  'UCrAkYq70CJ62yiXt-lgIDcg',
#  'UC8-rAGgllEhJpnRPaVTEw1w',
#  'UCw8oQLhyxGelpxXjnKiqWOA',
#  'UCVsCm0DE0N-yNMazJ01RYsg',
#  'UCmCavIluxnSwtPRLgxw3bYA',
#  'UCUUFXfP7yc1pGC9h3oASYyQ',
#  'UCxaCu5ht7d3jvisTpiW6vxw',
#  'UCZEu8O6o-1t4b37JHFqeZ3g',
#  'UCsupiBmxkPHFmlW_B8NuvuQ',
#  'UCEfL_pp3h8Ul-LIL1C4o34w',
#  'UCSbjl-r8UgyK76TEL7rPBSQ',
#  'UCsqqTMUSdNEuizhugdB5ONg',
#  'UCwroD4k2RJTCx0gCEEoI1xQ',
#  'UCO8Ml6DWcrRxTvsAtqzbq3A',
#  'UC2OFCX94xIJiPs1V7Ur5MAg',
#  'UCRN2uKmqOkShT6v0nVnmcGw',
#  'UC0Gru-jrD7sWd-pqDH8y_OA',
#  'UC7usiNBwIhHZzRfGvAks_iA',
#  'UCDG2KrBheEYOcp3UvVwfMUA',
#  'UCbizLUsvMMknWFxRpqbj-Tg',
#  'UCAg-ddg4ptqzTP8mu4NlLSA',
#  'UCCAHeCgkTtJlaDfX4p5Ku9g',
#  'UCaPC9VDw9IjaLJYk2ntqD5Q',
#  'UC3_hDMY4IQLXfQFwb6ud77A',
#  'UCiFq8QP019WknnA8isURAlg',
#  'UCY4gHV66e4JQ2q6-y3V2Uzg',
#  'UCM1ABndR4IE85o3yUrh5VOg',
#  'UCjI6jDi08UuLihvxxsfpr0A',
#  'UCjWkQ2mQayb38nXb_isZxfA',
#  'UCsx_ZsgsX6BIFueejCDBLkg',
#  'UCn5EO29OZpqazhaYuox-ieA',
#  'UCN16u-GFjdNmVWlxBZvRqsQ',
#  'UCI0hxWIdIqSuX_Mc7hnj2JQ',
#  'UC44Mzz2-5TpyfklUCQ5NuxQ',
#  'UCxKAuN76I7bkAK0sRVOWcuQ',
#  'UCEQ12yB8QLw9pVOY3lo34_g',
#  'UC-SgvBqx-XY3MXiqhsQB-FQ',
#  'UCOJ6VJ-mSIw789_N-0YwYRw',
#  'UCatDfA2Mfpd-xJt84s7yLkA',
#  'UCc6Ey-Jfnr9rHzWdcSQwwbQ',
#  'UC6rS3fNDO19l0us3HEaqpAQ',
#  'UCjxO6XpUJaylnvBI8LXQHiw',
#  'UCs6PxjTlnFIlXFrGG2d-RhQ',
#  'UC_a5ykpZR8o-5exRDYCFp0Q',
#  'UCOysGuzP_MRP1koo_p9p9_w',
#  'UC_P4BTuHkkB1m8LY7dayRgg',
#  'UCSm87xY78wwJgFR_TZJ-dUQ',
#  'UCst_4Wi9DkGAc28uEPlHHHw',
#  'UCUy0NlW6WlVFj8V3xhXegYQ',
#  'UCPUIz8-MATqJYdBt2CWcVQA',
#  'UCFPZDlaa4_81m63KoexqrtA',
#  'UCO44w2mIIITjEROHrEJIl8A',
#  'UCgnPfc_2XXV4UYctKQSmcOg',
#  'UCoBbeu5bEvrJJDCCRSQJb4Q',
#  'UCU1xEpdwRITwjZ0vnUxzYaw',
#  'UCkSLAYplobH42Vripj6xxzg',
#  'UCf6n1u156YDncbM_wxeaMbw',
#  'UCNiMyIFyw8qQrZcFpzpJIRQ',
#  'UCd8_GwocCAx0aIi9gwWA0rQ',
#  'UCmyLyYr0wq0oFeDGvQQqI1g',
#  'UCb9k9ydvGYErWBCmVS5JrdQ',
#  'UCar5Cr-pVz08GY_6I3RX9bA',
#  'UCHm9aiQsllQbGcxu4ynJCAA',
#  'UCaj-Oa5pPfbF9tDnoytsoFQ',
#  'UC1Lvev-8nHBf1QHfC6auWFA',
#  'UCrgItCm6edF70qA69I7xN5w',
#  'UCfWS9FTU7PM1y24zjOT-AwA',
#  'UCHO11Josy2nT_eS5UJqg6gA',
#  'UCkTGvFqQYWgeCjmYfL4taKg',
#  'UCA6PcJz0-vfOmnZhM5TirVQ',
#  'UCT1DmITSbFv3tN5GqalE-mg',
#  'UCt0IBPkhrVM43xSyP2vCnAw',
#  'UCyovHlk62wTss21erBEVFaQ',
#  'UCB6ML9WYxC5hXz0PEHD_-uw',
#  'UCM0BRpzfdEoUlG5Whnzri4A',
#  'UC0q_c7Q6KhdrX1gJ4GuFyLQ',
#  'UCBHDE9Wg3XxjTVg8sPfP5RQ',
#  'UC6Elcwqp_ejj_ZQbjSKBEuw',
#  'UCEZ12_9vkxdT1BuZFqtfkfw',
#  'UCchPZwAV59qmmp6tKQalL6Q',
#  'UCD9YHClUr3tSoAm-kj8ejDA',
#  'UCnR_-6nHlN-RrKl76IHOxcw',
#  'UCYg_YD3qX7qbQ4EQkbmE7Lw',
#  'UCElNoZcxhVqDtZBSrdEomnA',
#  'UCc5L11HhFcn9ecpxJRXsceQ',
#  'UCR58tReSsPr5owEYiq4v43g',
#  'UCEyiBoX-XXO9qI1x5eG35Nw',
#  'UCCn-lAbO9uXSZq4bBbO2h5Q',
#  'UCKZl457pStr0HGSBRKZ3k4A',
#  'UCrHD7gi1dsYJxd5mwLUBcMA',
#  'UCZJCKa3l5khIWKLJI2j4KzA',
#  'UCJ_PUBiy-NwJ-woO18z330Q',
#  'UCgQyAVrpTgFZg03oiQvgb5A',
#  'UC9mbPYau8RLWdZ_Nv_zZB2A',
#  'UCuSk5P2IAfhuFgTCPpq3MmQ',
#  'UC-bd2hrIl-TSSpnFI2LE9Gw',
#  'UCm63tB8wsKOVvxoU4iMpS2A',
#  'UCgXXn1YSEoak9JN2FgAE8Mg',
#  'UC7c3-2DMDQcFIy9CgX7GiuQ',
#  'UCZDHWPM_rRKb-lhv6g-MehQ',
#  'UCQCax5p1KIs6Ax4F17ffP0Q',
#  'UC5WY2gtQ136zqASt2kdCjcA',
#  'UCgjDilJmvwt2kgVTgVgxvkQ',
#  'UCXKcHLoRxrHpIvd6L6mg55Q',
#  'UC70kawNmZCDeZDZBbeiolHA',
#  'UCXnB4177KtdN_P_HotMoEWw',
#  'UCI7J2DPxA5PBGMaoSwq5png',
#  'UCK2tauyeJ2Zk041SdyuL5TQ',
#  'UCe2Mg0JDkzq_qxMHYZg_sOg',
#  'UCBXJLuZYFrFuPleG1utGECg',
#  'UCVwLHgQJD48V9ntrFHD1CAg',
#  'UCi9Uzh14BHqkN7UO_2lbrMw',
#  'UCh84012dEUE076wM2CVFN9A',
#  'UCM0jduWk1g-A-rjm5D-mZ0A',
#  'UCIphdX9Ubx6mycasvQOwwag',
#  'UCFA1Mjey9AbSuvZhLkYBIMQ',
#  'UCAcWjbcvRp_DIjGTs5MhGiw',
#  'UCdVo3xvNeIsv_idEnsubEOw',
#  'UCM48Xq3s7MTEMYuWQkGdo2A',
#  'UCMB6WVI6-fRRhw0AEPPVrUA',
#  'UCv9QoeyeK8NShsr86JW6Lzw',
#  'UC7zfNU5lKXPnMJ-gT-qaLLg',
#  'UCQAMYxLd-6N1m27NformCaw',
#  'UC9_nEEZN7YOPaPfoItaRycg',
#  'UCo6AmnXsvWa4yONxlSlrxZA',
#  'UCegoZme0oYH-Jykvghy4I8Q',
#  'UCHTni7AM41ljKK2ypJIVTwQ',
#  'UCdiLBfmHbDFYz51QX-GjLlg',
#  'UC0RBcmJ5FGE_j-lH3rYppXA',
#  'UCa-d0hwYHOu6ehwc_oMjOoA',
#  'UCWtL5XVIIX61llS01eNKf2Q',
#  'UC5nwcKnu3C4lEISu3D_JEDw',
#  'UCvTfJPDWR648DXPXkbUwTnA',
#  'UCocGh-G6RCQZZWV9QOJwFFQ',
#  'UCbrtakj7hV2tcct-d7eqHlQ',
#  'UCZT-d8Q9d3obS6NxhyxnznQ',
#  'UCjk_IWpMIsIdPsHIccPkEnQ',
#  'UCwsz8_u5T8yi8CahZAGHPkg',
#  'UC_tDwYyB0p2AT7sZC6lTchg',
#  'UCLXbP3xz78Yz7HW5avm4zDg',
#  'UCMmOl0cEG-b7ZTZuSuifxNg',
#  'UCkGScIRyds3b8Ofv_HYCwXA',
#  'UCY9iP6C1AOd4BJVkbT23A8A',
#  'UCEARfniph_Q6FDzpkQIhCNA',
#  'UC0pOOfOfwodNTENhTlv9ucA',
#  'UCfOfZ4S8KGDrn0S3pTvyNYQ',
#  'UCLPHJVH9vIaE09ycOM3ArSw',
#  'UC4Hn41px2zgjpVASrVnmYIA',
#  'UC_khuge22EajalbkOvrSq3A',
#  'UCOWDZ8YEXRvmFI8YlKx0Puw',
#  'UChypzKEi_xUsfMo9m6jB_ZA',
#  'UCVnq6PoW_yM2H87MvlTBuqQ',
#  'UC9ie1R625yIux9sQGTN2ztQ',
#  'UCvHtQtRlg19IneSRrLu7v7Q',
#  'UCv3ZcTj48oJOkERvBSTO11g']

# %%
len(lista_canais)
# Out:
# 377

# %%
for coluna in colunas_visualizacoes_semana:
    df_total_visualizacoes_semana.groupBy(coluna).count().orderBy('count', ascending=False).show()
# Out:
# +--------------------+-----+
# |            NM_CANAL|count|
# +--------------------+-----+
# |     ChratosGameplay|  228|
# |    Cristão Pensador|  191|
# |       Irmãos Cities|  134|
# |           MetalBear|  116|
# |Hashtag Treinamentos|   98|
# |Lucas gameplays b...|   96|
# |    Lives do Chratos|   96|
# |Desenvolvendo Me ...|   95|
# |       Tales Augusto|   89|
# |        Lille School|   87|
# |CANAL HAND - GAME...|   83|
# |  Alexandre Pereira |   80|
# |      Betospa Gaming|   76|
# |          Simularies|   75|
# |       Canal do Void|   74|
# |Prof. Dr. Lucimar...|   73|
# |       Túlio Melibeu|   67|
# |          Data Mundo|   66|
# |      Academia BePro|   60|
# |              DILSÃO|   57|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
# |        TITULO_VIDEO|count|
# +--------------------+-----+
# |Cities: Skylines ...|   47|
# |AGUARDANDO  citie...|   45|
# |Gameplay AO VIVO ...|   42|
# |Precisando elevar...|   38|
# |Sonhando acordado...|   35|
# |    Forza Motorsport|   28|
# |Metrópole sem mod...|   23|
# |🔴LIVE🔴 CITIES S...|   22|
# |MODDERS decidem f...|   22|
# |Cities Skylines u...|   22|
# |Cities Skylines, ...|   22|
# |Cities Skylines 2...|   22|
# |Cities: Skylines ...|   20|
# |Planejamento inic...|   20|
# |CITIES SKYLINES -...|   20|
# |Cities Skylines a...|   20|
# |Cities Skylines, ...|   20|
# |LUCRO, ÁGUA, LUZ ...|   20|
# |Apresentamos o Cu...|   20|
# |HOTEIS DE L City ...|   20|
# +--------------------+-----+
# only showing top 20 rows
#
# +---------------------+-----+
# |TOTAL_CARACTERE_VIDEO|count|
# +---------------------+-----+
# |                   64|  167|
# |                   70|  139|
# |                   53|  133|
# |                   69|  121|
# |                   35|  120|
# |                   58|  117|
# |                   57|  115|
# |                   88|  115|
# |                   63|  111|
# |                   38|  111|
# |                   71|  111|
# |                   52|  109|
# |                   59|  107|
# |                  100|  107|
# |                   73|  105|
# |                   42|  104|
# |                   75|  101|
# |                   72|   97|
# |                   80|   97|
# |                   93|   96|
# +---------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
# |                TAGS|count|
# +--------------------+-----+
# |                null| 1897|
# |[APOCALIPSE, 666,...|  191|
# |[cities skylines,...|  132|
# |[euro truck 2, lu...|   96|
# |[Chratos, Chratos...|   96|
# |[É POSSÍVEL TRABA...|   95|
# |[cities skylines,...|   83|
# |[#Citiesskylines,...|   76|
# |[excel, dicasdeex...|   75|
# |[Cities Skylines ...|   74|
# |[metalbear, Citie...|   74|
# |[bi, cienciadedad...|   49|
# |[COMEÇANDO UM NOV...|   48|
# |[cities skylines ...|   48|
# |[simularies, citi...|   42|
# |[metalbear, baldu...|   42|
# |[aula excel, curs...|   41|
# |[cities, skylines...|   38|
# |[simularies, citi...|   33|
# |[listas encadeada...|   32|
# +--------------------+-----+
# only showing top 20 rows
#
# +---------------------+-----+
# |DURACAO_VIDEO_MINUTOS|count|
# +---------------------+-----+
# |                  0.0|  161|
# |                  1.0|   98|
# |                 0.98|   81|
# |                 0.97|   66|
# |                 0.13|   57|
# |                 0.92|   48|
# |                 0.57|   46|
# |                 0.38|   44|
# |                 0.88|   38|
# |                 0.83|   37|
# |                 75.0|   36|
# |                 0.12|   36|
# |                 0.15|   35|
# |                11.55|   30|
# |                  0.7|   29|
# |                 19.3|   26|
# |                 1.02|   26|
# |                 18.6|   26|
# |                  0.4|   26|
# |                 0.95|   25|
# +---------------------+-----+
# only showing top 20 rows
#
# +----------+-----+
# |TOTAL_TAGS|count|
# +----------+-----+
# |         0| 1897|
# |        21|  317|
# |        31|  243|
# |        13|  243|
# |        36|  220|
# |        23|  210|
# |        10|  203|
# |        14|  200|
# |         3|  146|
# |        18|  145|
# |        20|  126|
# |        16|  113|
# |        33|  112|
# |         4|  104|
# |         8|  102|
# |         5|   96|
# |        12|   93|
# |        28|   90|
# |        17|   90|
# |         9|   88|
# +----------+-----+
# only showing top 20 rows
#
# +-------------------+-----+
# |TOTAL_VISUALIZACOES|count|
# +-------------------+-----+
# |                  0|  239|
# |                  8|  109|
# |                  4|  106|
# |                  5|   99|
# |                  1|   97|
# |                  9|   93|
# |                 27|   85|
# |                 12|   80|
# |                  3|   79|
# |                 11|   79|
# |                 20|   74|
# |                 16|   74|
# |                  7|   73|
# |                 14|   72|
# |                 10|   69|
# |                  2|   69|
# |                 15|   59|
# |                  6|   59|
# |                 13|   55|
# |                 22|   54|
# +-------------------+-----+
# only showing top 20 rows
#
# +-----------------+-----+
# |TOTAL_COMENTARIOS|count|
# +-----------------+-----+
# |                0| 2960|
# |                1|  594|
# |                2|  432|
# |                3|  237|
# |                4|  130|
# |                5|  112|
# |                8|   82|
# |                7|   69|
# |                6|   68|
# |               19|   52|
# |                9|   46|
# |               12|   45|
# |               20|   42|
# |               18|   35|
# |               25|   35|
# |               10|   34|
# |             null|   32|
# |               23|   31|
# |               27|   29|
# |               15|   28|
# +-----------------+-----+
# only showing top 20 rows
#
# +-----------+-----+
# |TOTAL_LIKES|count|
# +-----------+-----+
# |          0|  842|
# |          1|  607|
# |          2|  468|
# |          3|  343|
# |          4|  268|
# |          5|  235|
# |          7|  185|
# |          6|  159|
# |          8|  100|
# |         11|   91|
# |         12|   84|
# |          9|   83|
# |         10|   73|
# |       null|   66|
# |         13|   48|
# |         14|   48|
# |         22|   38|
# |         29|   32|
# |         20|   30|
# |         19|   27|
# +-----------+-----+
# only showing top 20 rows
#
# +-----------------------+-----+
# |TOTAL_VISUALIZACOES_DIA|count|
# +-----------------------+-----+
# |                      1|  603|
# |                      2|  341|
# |                      3|  260|
# |                      4|  259|
# |                      0|  239|
# |                      5|  217|
# |                      6|  143|
# |                      8|  141|
# |                      7|  130|
# |                      9|  112|
# |                     10|   97|
# |                     12|   94|
# |                     11|   94|
# |                     15|   76|
# |                     16|   72|
# |                     27|   70|
# |                     13|   69|
# |                     14|   64|
# |                     18|   62|
# |                     19|   58|
# +-----------------------+-----+
# only showing top 20 rows
#
# +---------------------+-----+
# |TOTAL_COMENTARIOS_DIA|count|
# +---------------------+-----+
# |                    0| 2960|
# |                    1|  798|
# |                    2|  540|
# |                    3|  258|
# |                    4|  155|
# |                    5|  117|
# |                    6|   91|
# |                    7|   77|
# |                    8|   75|
# |                    9|   46|
# |                   19|   40|
# |                   12|   40|
# |                   10|   36|
# |                   20|   33|
# |                   25|   32|
# |                 null|   32|
# |                   18|   28|
# |                   13|   28|
# |                   15|   25|
# |                   27|   24|
# +---------------------+-----+
# only showing top 20 rows
#
# +---------------+-----+
# |TOTAL_LIKES_DIA|count|
# +---------------+-----+
# |              1| 1027|
# |              0|  842|
# |              2|  636|
# |              3|  418|
# |              4|  297|
# |              5|  255|
# |              7|  187|
# |              6|  179|
# |              8|  110|
# |              9|   98|
# |             11|   86|
# |             12|   68|
# |           null|   66|
# |             10|   61|
# |             13|   44|
# |             14|   41|
# |             20|   35|
# |             22|   33|
# |             15|   32|
# |             16|   31|
# +---------------+-----+
# only showing top 20 rows
#
# +-------------+-----+
# |data_extracao|count|
# +-------------+-----+
# |   2023-10-27|  989|
# |   2023-10-26|  890|
# |   2023-10-25|  793|
# |   2023-10-24|  716|
# |   2023-10-23|  620|
# |   2023-10-22|  524|
# |   2023-10-21|  455|
# |   2023-10-20|  379|
# |   2023-10-19|  313|
# |   2023-10-16|   98|
# |   2023-10-15|   35|
# +-------------+-----+
#
# +--------------------+-----+
# |             ASSUNTO|count|
# +--------------------+-----+
# |    assunto_power_bi| 2049|
# |assunto_cities_sk...| 1465|
# |assunto_python_an...| 1336|
# |assunto_cities_sk...|  962|
# +--------------------+-----+
#
# +--------------------+-----+
# |            ID_CANAL|count|
# +--------------------+-----+
# |UCrOH1V-FyMunBIMr...|  228|
# |UC0MyjIBbIDlOBCUf...|  191|
# |UC1mk6EtfMjxR4eEZ...|  134|
# |UCfY4ggUDPeecGSCN...|  116|
# |UCw0leRmeaX7R_9BD...|   98|
# |UCOYJm7BsLV8VCkW2...|   96|
# |UCayiH2Y5JBEOSubq...|   96|
# |UCp98bXHSc01w8fBf...|   95|
# |UCMdNR-VCYnozREcE...|   89|
# |UCqj1vaTl3NZtFElz...|   87|
# |UC7v51W2NoLFawizg...|   83|
# |UC6whuyplYhUcz4k0...|   80|
# |UCkXA2EoaXRFW18vr...|   76|
# |UCDGo_s0I-2JpO3o3...|   75|
# |UCrUcdH_bCfX77xpX...|   74|
# |UCrQQUCh77WceaMFa...|   73|
# |UCENbpaPgVhO2GtlN...|   67|
# |UCCxTIMnbG7xoGDD5...|   66|
# |UCRIafgU7_URCZXt6...|   60|
# |UCTrNnXivZU_1-aJq...|   57|
# +--------------------+-----+
# only showing top 20 rows
#
# +-----------+-----+
# |   ID_VIDEO|count|
# +-----------+-----+
# |nMMr_myn5yI|   22|
# |YhXTcceM1NA|   22|
# |weciQDqn07g|   22|
# |XOUzWJ0bHuw|   22|
# |rie83X9qYpk|   22|
# |BJH6Or12MrA|   20|
# |1qDI1j9n2f0|   20|
# |dRzwiPwGH_M|   20|
# |kkPRDzrBUiY|   20|
# |fTeqTuEHs7I|   20|
# |EYNNLxG38yg|   20|
# |EMJho5TI26w|   20|
# |THuiHJMMvKc|   20|
# |8p7ulXmubg8|   20|
# |ANa7la0wqNc|   18|
# |2c5QZgVUdGo|   18|
# |zyG3nFm9BB8|   18|
# |mfCGsYnClDU|   18|
# |z2wuhLPrUWg|   18|
# |FW11WBBHJTI|   18|
# +-----------+-----+
# only showing top 20 rows

# %%
for canal in lista_canais:
    df_total_visualizacoes_semana \
        .filter(df_total_visualizacoes_semana.ID_CANAL == canal) \
        .write \
        .parquet(f'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_{canal}.parquet')
# Out:
# 23/11/20 16:37:00 WARN MemoryManager: Total allocation exceeds 95,00% (906.992.014 bytes) of heap memory
# Scaling row group sizes to 96,54% for 7 writers

# %%
spark.stop()

# %%
conn = hive.Connection(host='localhost', port=10000, username='rodrigo')

# %%
cursor = conn.cursor()
cursor.execute('USE youtube')
for chave,  canal in enumerate(lista_canais):

    print(f'iteração {chave + 1} --- de {str(len(lista_canais) - 1)}')
    try:
        

        query = f'''
        LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_{canal}.parquet'
        INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
        '''
        print(query)
        
        cursor.execute(query)
    except:
        cursor.close()
        print(f'deu ruim em {chave + 1}')
        break

cursor.close()
# Out:
# iteração 1 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCfY4ggUDPeecGSCNePyyVSA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 2 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCYEb5mbKZ5JJzN0xBuKyaig.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 3 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCShgvN-cGaRtsu4JeZJ5NWw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 4 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC0MyjIBbIDlOBCUfl7iO9bg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 5 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCNNJFz7px0NBlg7Lw6A9tMg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 6 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCxDJUOOiBlEl_jl5Ox24qjg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 7 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC6JcLNZDLTNI_XsjJtMR3lQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 8 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCp7gzkfbWE7jazP65W9ZtWg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 9 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCqj1vaTl3NZtFElzCZNyKpA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 10 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCBSrzvbMoru6PsayN3Z7ZsA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 11 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCLB1zHWq064-nxdxVrABiUA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 12 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC-BDIFDYMrh4aqlEuqnldEg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 13 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UChTLNqbdIMNny_vCqn6e-iA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 14 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCwwLM_dJ2o52sTJHN7hojxw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 15 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCw0leRmeaX7R_9BDd3TvCzg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 16 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCqFAXxARXQHx0t_mm_eElcA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 17 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCtRNcB3lcaJ75CsRUG7CcLw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 18 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCaTiVclf7mD7Wzbbsm6gGOA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 19 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCoGkNtefcmsMbTosHEgLrdw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 20 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCMqGy4xIIGs01ZVcBv0B8Cw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 21 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC9LwSTLQx2V7G8wmJiJw8KA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 22 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCrSWO9gdMOC1qO34bbAX9RQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 23 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCe9jrI0YQ5SM6h5QRZ9FZlA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 24 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCafFexaRoRylOKdzGBU6Pgg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 25 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCL5k8vBBo1JOHh7AnvoD8xQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 26 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCCxTIMnbG7xoGDD5YsqeBag.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 27 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCkfyKm2S5eSurJDt3TATq-A.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 28 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC7v51W2NoLFawizgcNuVBOA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 29 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCjKatVVFkhVdufkU7EyuTGg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 30 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCDGo_s0I-2JpO3o3xlkMQVA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 31 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCKJ2JOMmbgpoRnu7G6-notQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 32 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC9sKp_hMnOsATpvh0Ad54fw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 33 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCn7w7H6jL0G3TNpV1v0SZRg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 34 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCcuLEJUZy4jo9iFvngkoBUg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 35 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC70mr11REaCqgKke7DPJoLg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 36 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCvz12BbOXa7nJ-zbkQ6tI6A.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 37 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC4sR2FCJkVIq4pqFxLyOArA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 38 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCayiH2Y5JBEOSubqoQhufDA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 39 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC-cKIIGsroQqpH91A7nQGgg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 40 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC5Bn1EuTqaQNCCKo_9SAi_w.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 41 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCqqJsllgIjDZjLE74Bba9og.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 42 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCKlyjSFal7jgtMVDEGnB7YQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 43 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCtfSUve5SABGVxMOuYXn8HA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 44 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCtaDOcil7AXjT28K0mW7UQA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 45 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCHQun4keJGrj8RqDPPpyUsg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 46 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCGyqOs1_RKC8CBndIkzTxzw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 47 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCsi_LmcdII_1jAPSuGEjgnA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 48 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCcinq1ymmAmhFZzyOeaGjiA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 49 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCDqzBrUOm7guqqyU8eDackg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 50 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCrUcdH_bCfX77xpXHyq2fJw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 51 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UChu8BOyORQaKfaf8cUmVrlg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 52 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCp98bXHSc01w8fBfkkgHB1Q.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 53 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCwMQikMlRfKkcn6A7nx2EmQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 54 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC-4oKsd_5_Q5sy8t6g3JMRA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 55 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCmg3_taw1BrGuo1ITlQe2hA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 56 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC6whuyplYhUcz4k0I7Cx0_g.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 57 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCm4Btb0FJ1OymCphQ0HTsVw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 58 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC8FS3_qf6F194QTYwxwFGMw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 59 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCkXA2EoaXRFW18vrAE01BpQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 60 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCxIMGC-GmZ2pXE_jGGW2C9A.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 61 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC1mk6EtfMjxR4eEZ7C43zTQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 62 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCrOH1V-FyMunBIMrKL0y0xQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 63 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCMdNR-VCYnozREcEt1xkcHg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 64 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCYDluKEjFODZQueXT0pZJfg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 65 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCrxFTbIV_8sUVJ596fkzBsg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 66 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCEdUXu7Rgo0KT7UAtMy-Qkw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 67 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCwBN6GQiolq3EkRPYC7OTtA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 68 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCRIafgU7_URCZXt6X9XMbAg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 69 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC-N8y8IuT8B44h-IQQAmq4w.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 70 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCOYJm7BsLV8VCkW2DC1MI5w.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 71 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCENbpaPgVhO2GtlNcwAJ8mA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 72 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCYvDxCsrwxOA-8MBZAzzFIA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 73 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCrQQUCh77WceaMFae4ykm7w.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 74 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCg6yqeJJ2WMFVt9bXeUd-zA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 75 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC3P9lC-O8Rr1Ggc3oIIqIkg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 76 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCgLBFiwTtgJ8hdNFeFAkeyw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 77 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCOcjS2ppQSqIsbMgWGCfLew.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 78 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCOe_x5ararWwWajBKbFKNkA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 79 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCM7FGFGU3NL7frvJ7MkNzAg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 80 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCHEuAFdws9OCZPcfTBuxtCw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 81 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCNv3_KHnWEzLc3BCxYXpHFQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 82 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCxy9ZMwZfP8ccgMrpbVtmTA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 83 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCf15n72n6pV0RK6-GOi1s1Q.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 84 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCts_EXWl-EeycUUAEy44NmQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 85 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCOvNVIUa1wq7Aq7xaOI3P7g.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 86 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCiaL33s_HVulWylA63eMXJw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 87 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCEn6ZNpD9Qpgqh28c0nT1Rw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 88 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCQqcBxrAKR1ixtPNHL9U3Ew.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 89 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC_bJMXMZkxdkLcSeZGCqTqQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 90 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCW7i1eD6-PVfHsBIfsGOkXA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 91 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC21HmquxkP-IAqa2HNLhFOg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 92 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCwd-rkFy2k-Jv-5sSS_py3A.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 93 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UClIi1-5iixE2yLdV9JiXLbQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 94 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCojjOrsQAKNOOrE4mocSghw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 95 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCMWG5_iw-j-eLFfIJAlWLOQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 96 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC5K-TQsItHnNLjqYf8A3CTw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 97 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCBgYMaTBbXgaP5YsEDoShTg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 98 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCck21CJKhTfldiwrfJo7HgA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 99 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCak0L-2P3B9-sf9-yiuJj6Q.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 100 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCfAPIE6M2aHyNO-AXwbID2w.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 101 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCiRdaC8jG1-K87ciSUbT2iw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 102 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCCe4Be21OPPltTTIHP4lDvg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 103 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC4sUVsopaPbjn5JzHDwdjMg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 104 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCMLxzf6bkTtKe_V5novlVwg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 105 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC7FD56H8vyZA30oL8c7ziHQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 106 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCJYFuFymG6_6TLUxC-4YHzA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 107 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCdZK6DwemFBiKHlkez2tdUA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 108 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCSlrbSybttMqpM_TDcXojyw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 109 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCEQkAgXk_T3sDMx9YSdz-cQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 110 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCORAFKQRRpiCov_kFQoGONQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 111 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCo95QXpNpiX-J_sy4ujSE-g.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 112 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCcT7u9KeCH6v_ReHZcUhXoA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 113 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCEc5jA0NvvR-yJC0SISV6nw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 114 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCTrNnXivZU_1-aJqn1uNANg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 115 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC0Yr63KmXTFXy07iT4egAOA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 116 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCNqlxCA5plQcNHB0w3D1ndA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 117 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCKGeaczIbVQsXG8Mwy8EadA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 118 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCABm0SdJCoM6z0MFod7s3Lg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 119 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC-ueVxV50bTa6cCwsIl5eHA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 120 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC_Fk7hHbl7vv_7K8tYqJd5A.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 121 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UClZqcB3EsrcngoOxXh4rp8A.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 122 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCZh2Y-xZQ586ZFO5FYw8A1A.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 123 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCivfb2x3HUx3EukY_DIWB-g.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 124 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCGi_mAdy_Vp1x8RaUnmViqg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 125 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCTKuRhO9EuWPUgMtF7VrY0Q.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 126 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCslMsMAL4dMtJCIAgQNevDQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 127 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCV4t8SmkcGLHXHbHteDiyHw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 128 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC7sP7azSWwnqnSfuWLFJMrg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 129 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCDvA6dimWFCsbYdhVJL5W1w.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 130 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCLAUYEY8ITQC8b47xyqybxg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 131 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC_tHKzrUF6UWMmsE571lwbg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 132 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCBrf43bKmJiAsfZCRMSnTzg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 133 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCdUh1qAXm1gkZEk4L3rYRoA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 134 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UChKvQZHn33iHwAu8YMnLaIA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 135 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCk8a_ETbXVLOlfmMBKgDlug.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 136 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCY9SX2eszZG1C63NpRARA9g.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 137 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCccdWOiGy2vEQKjUhNZHB_g.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 138 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCHuvObnh1-2fs6zL5nhVGtg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 139 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCVM5Kg0mLSmmvdmhWH9OhiA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 140 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC0ANZre7BfygNTf5RFDFTVA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 141 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCuINY5yvdmMrMjuhlQ-NNuw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 142 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCl2bR-hSQjx7stTrP9BSevw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 143 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCECueo5gAX7odvuiLCjklbA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 144 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCywooHx7UiGuhvyQS4qcHvA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 145 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCR69dJLCC9C6dTBY1uNxcWg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 146 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCaj6FB2mFZ2T9a61QtZsKPA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 147 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCJHBJmrVd7ujf2eCEujukog.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 148 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCfpv91g04FgdO25S3lsZjsA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 149 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC-p4bIdGN_XNPT8kz0i5u1w.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 150 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCvf1dm1mnzIqyCQpJYbVMUA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 151 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCIv5D2ro1owj6P7OdZ4-BiA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 152 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC-z3zm3WSO68tpB8y5SWLZA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 153 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCIMUxCvkVcuDFXzwoR8H3fQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 154 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCla_gQERStTS74gxHMS6Tzw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 155 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCbww3yb1rObMQURafrYgOiQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 156 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UClGA2euv_zdZ442GcVBjcbg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 157 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC44qgwxGNPbfaAGQV1K6kVg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 158 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCPGt5HY30kWEbzT1-KAjHqg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 159 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC_cAH76qc44vTEFBVXULPjQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 160 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCxtXKH7HqVxD5EOJKfMxCDw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 161 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCo7EHzKF2zDFWszw7Dg4mPw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 162 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCfSs49h-BXeShswb4P-tXFQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 163 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCsxON5820u2py83RRj-yElQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 164 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCfuxXVeeaS8cLj2kxcvOdYw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 165 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCge0EdfsF-RPcr_efb4TMHQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 166 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC9KoV-VIjVins1OKHCj-BiA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 167 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCtp_Ac43h5uUQcrtBbVS2IQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 168 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCIEd_yNwTVZr1JChrgYR7sw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 169 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCezFMTgl1ezYv4HXG8b-dDg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 170 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC6ZlYmIr3sdAmDLxnx-fk0g.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 171 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCjJUe8JYQgqOxC57jZyVsEg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 172 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC_8n2zOvnrk_oh5tx9n621w.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 173 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCz1XR21d0ivMHFpe8h4alww.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 174 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCdsG3oYcpaxIZNm_Vy_nMxA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 175 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCGved3ynk6ZhUvSKxzgweTw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 176 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCfkgc6FfJCP362BdVNBpZHw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 177 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCScwap3Ok7uI585dOVt4uBg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 178 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCRGbH0l1TAZbIAUr10NpNnA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 179 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCDZxPzC2DJ3aTkzTfTqyXHw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 180 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCxfK8fA5D95ClVoK5D6oKHg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 181 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCsyYkiEF8I270881fKSQV8w.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 182 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCd3ThZLzVDDnKSZMsbK0icg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 183 --- de 376
#
# ...
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 318 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC-bd2hrIl-TSSpnFI2LE9Gw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 319 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCm63tB8wsKOVvxoU4iMpS2A.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 320 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCgXXn1YSEoak9JN2FgAE8Mg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 321 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC7c3-2DMDQcFIy9CgX7GiuQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 322 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCZDHWPM_rRKb-lhv6g-MehQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 323 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCQCax5p1KIs6Ax4F17ffP0Q.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 324 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC5WY2gtQ136zqASt2kdCjcA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 325 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCgjDilJmvwt2kgVTgVgxvkQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 326 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCXKcHLoRxrHpIvd6L6mg55Q.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 327 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC70kawNmZCDeZDZBbeiolHA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 328 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCXnB4177KtdN_P_HotMoEWw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 329 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCI7J2DPxA5PBGMaoSwq5png.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 330 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCK2tauyeJ2Zk041SdyuL5TQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 331 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCe2Mg0JDkzq_qxMHYZg_sOg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 332 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCBXJLuZYFrFuPleG1utGECg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 333 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCVwLHgQJD48V9ntrFHD1CAg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 334 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCi9Uzh14BHqkN7UO_2lbrMw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 335 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCh84012dEUE076wM2CVFN9A.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 336 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCM0jduWk1g-A-rjm5D-mZ0A.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 337 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCIphdX9Ubx6mycasvQOwwag.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 338 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCFA1Mjey9AbSuvZhLkYBIMQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 339 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCAcWjbcvRp_DIjGTs5MhGiw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 340 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCdVo3xvNeIsv_idEnsubEOw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 341 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCM48Xq3s7MTEMYuWQkGdo2A.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 342 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCMB6WVI6-fRRhw0AEPPVrUA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 343 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCv9QoeyeK8NShsr86JW6Lzw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 344 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC7zfNU5lKXPnMJ-gT-qaLLg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 345 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCQAMYxLd-6N1m27NformCaw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 346 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC9_nEEZN7YOPaPfoItaRycg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 347 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCo6AmnXsvWa4yONxlSlrxZA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 348 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCegoZme0oYH-Jykvghy4I8Q.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 349 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCHTni7AM41ljKK2ypJIVTwQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 350 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCdiLBfmHbDFYz51QX-GjLlg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 351 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC0RBcmJ5FGE_j-lH3rYppXA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 352 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCa-d0hwYHOu6ehwc_oMjOoA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 353 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCWtL5XVIIX61llS01eNKf2Q.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 354 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC5nwcKnu3C4lEISu3D_JEDw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 355 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCvTfJPDWR648DXPXkbUwTnA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 356 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCocGh-G6RCQZZWV9QOJwFFQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 357 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCbrtakj7hV2tcct-d7eqHlQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 358 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCZT-d8Q9d3obS6NxhyxnznQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 359 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCjk_IWpMIsIdPsHIccPkEnQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 360 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCwsz8_u5T8yi8CahZAGHPkg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 361 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC_tDwYyB0p2AT7sZC6lTchg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 362 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCLXbP3xz78Yz7HW5avm4zDg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 363 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCMmOl0cEG-b7ZTZuSuifxNg.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 364 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCkGScIRyds3b8Ofv_HYCwXA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 365 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCY9iP6C1AOd4BJVkbT23A8A.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 366 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCEARfniph_Q6FDzpkQIhCNA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 367 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC0pOOfOfwodNTENhTlv9ucA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 368 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCfOfZ4S8KGDrn0S3pTvyNYQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 369 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCLPHJVH9vIaE09ycOM3ArSw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 370 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC4Hn41px2zgjpVASrVnmYIA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 371 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC_khuge22EajalbkOvrSq3A.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 372 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCOWDZ8YEXRvmFI8YlKx0Puw.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 373 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UChypzKEi_xUsfMo9m6jB_ZA.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 374 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCVnq6PoW_yM2H87MvlTBuqQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 375 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UC9ie1R625yIux9sQGTN2ztQ.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 376 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCvHtQtRlg19IneSRrLu7v7Q.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA
#
# iteração 377 --- de 376
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/total_visualizacoes_semana/total_visualizacoes_semana_UCv3ZcTj48oJOkERvBSTO11g.parquet'
#         INTO TABLE TOTAL_VISUALIZACOES_POR_SEMANA

# %% [markdown]
#  - Resposta comentários

# %%
spark = SparkSession.builder.appName('CARGA').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.112:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>CARGA</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_resposta_comentarios = spark.read \
    .parquet('hdfs://localhost:9000/projeto/datalake_youtube/backup/resposta_comentarios.parquet')
df_resposta_comentarios = df_resposta_comentarios.distinct().sort('ID_RESPOSTA_COMENTARIOS')
df_resposta_comentarios.show(truncate=False)
# Out:
# [Stage 1:=======>                                                   (1 + 7) / 8]
# +-----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------+------------------------+-----------+--------------------------+
# |ID_RESPOSTA_COMENTARIOS|TEXTO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |ASSUNTO                  |ID_CANAL                |ID_VIDEO   |ID_COMENTARIO             |
# +-----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------+------------------------+-----------+--------------------------+
# |9vpBONW2oKu9vrj66G_tPL |Надеюсь на это, я хотел помочь своей семье, спасибо за поддержку.                                                                                                                                                                                                                                                                                                                                                                                                                                                |assunto_cities_skylines  |UCn7w7H6jL0G3TNpV1v0SZRg|FCZBQdsVSbM|Ugzq4E_Bdng3f-Y7QLx4AaABAg|
# |9vpBONW2oKu9vrj66G_tPL |Надеюсь на это, я хотел помочь своей семье, спасибо за поддержку.                                                                                                                                                                                                                                                                                                                                                                                                                                                |assunto_cities_skylines_2|UCn7w7H6jL0G3TNpV1v0SZRg|FCZBQdsVSbM|Ugzq4E_Bdng3f-Y7QLx4AaABAg|
# |9vpBQN4Nq-z9wNH-yZJOCs |Сохранять! Банк сильный! Спасибо за укрепление канала!                                                                                                                                                                                                                                                                                                                                                                                                                                                           |assunto_cities_skylines_2|UCn7w7H6jL0G3TNpV1v0SZRg|H1TkuRbFf38|UgwtCiTI5zBdS1TbHs94AaABAg|
# |9vpBQN4Nq-z9wNaQAyYmnN |@Gustavo Squassoni Спасибо, это будет самый крупный игровой канал на YouTube.                                                                                                                                                                                                                                                                                                                                                                                                                                    |assunto_cities_skylines_2|UCn7w7H6jL0G3TNpV1v0SZRg|H1TkuRbFf38|UgwtCiTI5zBdS1TbHs94AaABAg|
# |9vtg-CDu61r9vtu3PdedNq |Entendi nada                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |assunto_cities_skylines_2|UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vtg-CDu61r9vtu3PdedNq |Entendi nada                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |assunto_cities_skylines  |UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vtg-CDu61r9vuCIDh7Xs8 |@Douglas Deve ser porque o meu comentário foi direcionado a pessoas que sabem ler.                                                                                                                                                                                                                                                                                                                                                                                                                               |assunto_cities_skylines  |UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vtg-CDu61r9vuCIDh7Xs8 |@Douglas Deve ser porque o meu comentário foi direcionado a pessoas que sabem ler.                                                                                                                                                                                                                                                                                                                                                                                                                               |assunto_cities_skylines_2|UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vtg-CDu61r9vuD0jIzugQ |Eu (eu)\r\nNão (estou negando algo)\r\nConsigo (sou capaz de algo)\r\nJogar (participar de um jogo)\r\nRimworld (nome de um jogo)\r\nSem (ausência de algo)\r\nMod (modificação)\r\nCombat Extended (nome de um mod)\r\nDepois (após algo)\nDe (preposição)\r\nJogar (participar de um jogo)\r\nCom (juntamente com algo)\r\nO (artigo definido)\r\nSistema (conjunto de elementos inter-relacionados)\r\nRNG (sigla para Random Number Generator)\r\nÉ (existir)\r\nRuim (de má qualidade)\r\nDemais (excessivo)|assunto_cities_skylines_2|UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vtg-CDu61r9vuD0jIzugQ |Eu (eu)\r\nNão (estou negando algo)\r\nConsigo (sou capaz de algo)\r\nJogar (participar de um jogo)\r\nRimworld (nome de um jogo)\r\nSem (ausência de algo)\r\nMod (modificação)\r\nCombat Extended (nome de um mod)\r\nDepois (após algo)\nDe (preposição)\r\nJogar (participar de um jogo)\r\nCom (juntamente com algo)\r\nO (artigo definido)\r\nSistema (conjunto de elementos inter-relacionados)\r\nRNG (sigla para Random Number Generator)\r\nÉ (existir)\r\nRuim (de má qualidade)\r\nDemais (excessivo)|assunto_cities_skylines  |UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vtg-CDu61r9vuD2BrF_7S |Entendeu agora?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |assunto_cities_skylines_2|UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vtg-CDu61r9vuD2BrF_7S |Entendeu agora?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |assunto_cities_skylines  |UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vtg-CDu61r9vuV_6idPJF |KKKKKKKKKK                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |assunto_cities_skylines  |UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vtg-CDu61r9vuV_6idPJF |KKKKKKKKKK                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |assunto_cities_skylines_2|UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vtg-CDu61r9vupBdlANQ0 |@Cultosaurus Erectus kkkkkkkkkkk vou aderir a isso                                                                                                                                                                                                                                                                                                                                                                                                                                                               |assunto_cities_skylines  |UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vtg-CDu61r9vupBdlANQ0 |@Cultosaurus Erectus kkkkkkkkkkk vou aderir a isso                                                                                                                                                                                                                                                                                                                                                                                                                                                               |assunto_cities_skylines_2|UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vtg-CDu61r9vv6xwHcOWt |​@Cultosaurus Erectuskkkkkkkkkkkk                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |assunto_cities_skylines  |UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vtg-CDu61r9vv6xwHcOWt |​@Cultosaurus Erectuskkkkkkkkkkkk                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |assunto_cities_skylines_2|UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgxdyVex8HinQdQ7QyZ4AaABAg|
# |9vthDDQ-4xk9vtkxm7I29I |😂😂😂                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |assunto_cities_skylines_2|UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgzAey-NMzzvXpYySq14AaABAg|
# |9vthDDQ-4xk9vtkxm7I29I |😂😂😂                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |assunto_cities_skylines  |UCrOH1V-FyMunBIMrKL0y0xQ|XOUzWJ0bHuw|UgzAey-NMzzvXpYySq14AaABAg|
# +-----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------+------------------------+-----------+--------------------------+
# only showing top 20 rows

# %%
colunas_resposta_comentarios = df_resposta_comentarios.columns
colunas_resposta_comentarios
# Out:
# ['ID_RESPOSTA_COMENTARIOS',
#  'TEXTO',
#  'ASSUNTO',
#  'ID_CANAL',
#  'ID_VIDEO',
#  'ID_COMENTARIO']

# %%
for coluna in colunas_resposta_comentarios:
    df_resposta_comentarios.groupBy(coluna).count().orderBy('count', ascending=False).show()
# Out:
# +-----------------------+-----+
# |ID_RESPOSTA_COMENTARIOS|count|
# +-----------------------+-----+
# |   9vwRcZB4z2Y9vweRS...|    6|
# |   9w87TWefmUc9wAP-x...|    4|
# |   9w36sxWHCxh9w3EEh...|    4|
# |   9w87TWefmUc9wAUCY...|    4|
# |   9w87TWefmUc9w9v8N...|    4|
# |   9w87TWefmUc9wBN8H...|    4|
# |   9w87TWefmUc9wAKdw...|    4|
# |   9w87TWefmUc9wBwZy...|    4|
# |   9w2iRMu_2-e9w5LE1...|    2|
# |   9w3I7XXPhcq9w5aVI...|    2|
# |   9w0JIh4ntan9w0iuZ...|    2|
# |   9wLBpx-BUKe9wLKp_...|    2|
# |   9w86yYpkJ3e9w8DVZ...|    2|
# |   9w3a1434qZY9w4dro...|    2|
# |   9w0ZfxlYd9A9w0vDN...|    2|
# |   9wIRVwUlcq99wISTP...|    2|
# |   9w5JHUPgRKO9wBtPx...|    2|
# |   9wAm4WqNxtV9wAndH...|    2|
# |   9vwRcZB4z2Y9vyjp_...|    2|
# |   9w8EE2NpmqP9w8HaG...|    2|
# +-----------------------+-----+
# only showing top 20 rows
# +--------------------+-----+
# |               TEXTO|count|
# +--------------------+-----+
# |                  Up|   32|
# |                  up|   28|
# |                💜🚀|   11|
# |           Obrigado!|    8|
# |😃 O Power Query ...|    7|
# | Fico feliz em saber|    6|
# |     Eu que agradeço|    5|
# |     Muito obrigado!|    5|
# |            Obrigado|    5|
# |      Muito obrigado|    4|
# |Nós que agradecemos!|    4|
# |Aí não tem pc que...|    4|
# |Muito obrigado 🙏...|    4|
# |       Meus parabéns|    4|
# |            Anotado!|    4|
# |      Novo Horizonte|    4|
# |           Eu também|    4|
# |                 sim|    4|
# |           Boa tarde|    4|
# |                 Sim|    4|
# +--------------------+-----+
# only showing top 20 rows
# +--------------------+-----+
# |             ASSUNTO|count|
# +--------------------+-----+
# |assunto_cities_sk...| 1728|
# |assunto_cities_sk...| 1723|
# |assunto_python_an...|  598|
# |    assunto_power_bi|  384|
# +--------------------+-----+
# +--------------------+-----+
# |            ID_CANAL|count|
# +--------------------+-----+
# |UCrOH1V-FyMunBIMr...| 1140|
# |UCfY4ggUDPeecGSCN...|  342|
# |UCe9jrI0YQ5SM6h5Q...|  288|
# |UCoTIpyf8_RGzJ1LP...|  276|
# |UCEQ12yB8QLw9pVOY...|  196|
# |UCayiH2Y5JBEOSubq...|  194|
# |UCDGo_s0I-2JpO3o3...|  158|
# |UCHQun4keJGrj8RqD...|  142|
# |UCEfL_pp3h8Ul-LIL...|  140|
# |UC_Fk7hHbl7vv_7K8...|  132|
# |UCrxFTbIV_8sUVJ59...|  120|
# |UCaj6FB2mFZ2T9a61...|  102|
# |UC1mk6EtfMjxR4eEZ...|  102|
# |UCrUcdH_bCfX77xpX...|   90|
# |UCJHBJmrVd7ujf2eC...|   86|
# |UCcinq1ymmAmhFZzy...|   83|
# |UCYEb5mbKZ5JJzN0x...|   82|
# |UCElNoZcxhVqDtZBS...|   62|
# |UCJYFuFymG6_6TLUx...|   54|
# |UCcuLEJUZy4jo9iFv...|   53|
# +--------------------+-----+
# only showing top 20 rows
#
# +-----------+-----+
# |   ID_VIDEO|count|
# +-----------+-----+
# |L17Ox3uFAdo|  276|
# |V_sQAmzhrdE|  196|
# |vzzeZU07rmo|  186|
# |vy-upTpchig|  144|
# |wCLSZxLfUAk|  142|
# |OH-qmlI4A3o|  132|
# |VUgmLKbC8tY|  132|
# |9SGBZ7GE5EA|  128|
# |ND4pLB1ZRyM|  120|
# |ShVmR8yQweU|  114|
# |ykt0QE2XxP0|  108|
# |6RgEh-9KAgY|  102|
# |W6TjOORgEG0|  102|
# |fTeqTuEHs7I|  100|
# |TBZuVHi3QdM|   92|
# |mKgATax4ecI|   86|
# |up4KrHrRwLY|   84|
# |UJd9K8nK5H4|   80|
# |QwXP79P4xS0|   80|
# |totHMIv6_hI|   78|
# +-----------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
# |       ID_COMENTARIO|count|
# +--------------------+-----+
# |Ugy0n2RTLhGkN99mN...|   88|
# |Ugw78b1r-5e_Dj0wa...|   70|
# |UgykZAifisDqxp6sY...|   52|
# |UgxILnyjIlcyAnAIv...|   40|
# |Ugzm_o1Qjlkjvi53P...|   38|
# |UgxJl7t3bHyY0vaQF...|   38|
# |UgwjHHgaWcqqmrEtk...|   32|
# |UgxAhTxWuXPwkkmKH...|   30|
# |Ugxls8gLmgIFKx9Fq...|   30|
# |Ugy4zt9rIr4CYDK2_...|   30|
# |Ugx6Hwjsj4VOhH8qg...|   30|
# |Ugw_I4QstOoUSOZCg...|   26|
# |UgwrgrAhSIYbdP35D...|   26|
# |UgyI--hUg0boHKo_R...|   24|
# |UgyAygBP4Kagzw-Bs...|   24|
# |Ugx414gLLe0Dk34fB...|   22|
# |UgySWx2wsESOlb4NL...|   20|
# |UgzV6vY8kskxk_KeX...|   20|
# |UgyZb7P9u-CJDa1ea...|   20|
# |UgxY3CC6XwdJeJVxY...|   20|
# +--------------------+-----+
# only showing top 20 rows

# %%
lista_comentarios = [ linha['ID_COMENTARIO'] for linha in df_resposta_comentarios.select('ID_COMENTARIO').distinct().collect()]
lista_comentarios
# Out:
# ['UgzjtG8FbUI4PSjDgcR4AaABAg',
#  'UgyAygBP4Kagzw-BsRN4AaABAg',
#  'UgzqzEXFZeRzGP1vJoZ4AaABAg',
#  'UgyJhCBeqvIRcNEoxxh4AaABAg',
#  'UgwFgHQkWlDlA3sLFih4AaABAg',
#  'UgwSRK_MaZP50f6aR8V4AaABAg',
#  'UgyGN7EJFMJIGALL3uZ4AaABAg',
#  'UgysLWomkRBgycwEh4h4AaABAg',
#  'UgzO0izK_075lBI6Tht4AaABAg',
#  'UgwpWB7x2I0GbZa-2UR4AaABAg',
#  'UgyzwNWRIzCMRmwpq7J4AaABAg',
#  'UgwSPDUA5_cH8KWNeJJ4AaABAg',
#  'Ugx4913uDBuip0pUJpl4AaABAg',
#  'UgymIasxqwNFSUjv7RZ4AaABAg',
#  'Ugyn9QPEUFRhCqJGB8h4AaABAg',
#  'UgzFezA0NrM0DZClCot4AaABAg',
#  'UgxXgWLksXhddT8xijl4AaABAg',
#  'Ugz6Lh1IxEyBJrYZeL14AaABAg',
#  'UgyRSE9vvhbEpQarJv54AaABAg',
#  'Ugz6khMdz9YrKVuPzoB4AaABAg',
#  'UgzHt3fHKL1Q8XTYA6Z4AaABAg',
#  'Ugy0TCJeuMP4ZYhjrLx4AaABAg',
#  'UgyFlNjY9y9WCdHG5nx4AaABAg',
#  'UgwR2k1v4CBgPHJVk5R4AaABAg',
#  'Ugw3HdsDNDMQt74QF394AaABAg',
#  'UgxJh_42tlc8oblQVYx4AaABAg',
#  'Ugy1qzQk5dkEzQOSUUl4AaABAg',
#  'UgxfxfzA68wQy7IX7Nt4AaABAg',
#  'Ugxc6l-cggcM8rfEu554AaABAg',
#  'UgxfSuM-BvKNfHj_22V4AaABAg',
#  'Ugxd1H-6iumroOfI6p54AaABAg',
#  'Ugwj4srswzwMwsM77Hp4AaABAg',
#  'UgxXoRieCkrK-gJ5tQd4AaABAg',
#  'UgwxLIgYShzoymlziL54AaABAg',
#  'Ugy7wYt-WzUbXWUX20x4AaABAg',
#  'Ugws_ZumJrZMh-iVlMB4AaABAg',
#  'UgyRxMkksC1YPoHPHAJ4AaABAg',
#  'UgxHdhcW6Y1Fp2KhMNp4AaABAg',
#  'UgxvJjndxMCws4J5uMh4AaABAg',
#  'UgxR1_KxWLJ1oCKqIn94AaABAg',
#  'UgyL1gllk_FUl906IQV4AaABAg',
#  'UgylYVYgBa0K05bWPNx4AaABAg',
#  'UgwemzC1_iNiVxgSn6J4AaABAg',
#  'UgxqKg7do2O2t1SatU94AaABAg',
#  'UgykLTHQNvQkB9ZN85p4AaABAg',
#  'UgzcMSMjs3Oyym5Y7194AaABAg',
#  'Ugz61cPStg5DIxvmTGx4AaABAg',
#  'UgwG2Z6q8Fb9eNviEBd4AaABAg',
#  'Ugxc9hrY5wwCGNyDLR14AaABAg',
#  'UgywHj11NM5M74rCpJp4AaABAg',
#  'UgxdyVex8HinQdQ7QyZ4AaABAg',
#  'Ugx5KX2nZFPGlOMfOSJ4AaABAg',
#  'UgzmQf8oYGDtA6EhuRV4AaABAg',
#  'Ugyih3bSiywQub6ppuF4AaABAg',
#  'UgwijNBY9ICHHe3Z8_t4AaABAg',
#  'UgzlwF0si1Htbcotxbp4AaABAg',
#  'UgzLKocVFGR7fDgcdxd4AaABAg',
#  'UgzPkk3qw5BPxgMt9t94AaABAg',
#  'UgzM51oaOTmYTQJ4B854AaABAg',
#  'UgxKPSmr3uSlDcmXv6p4AaABAg',
#  'UgxZLOFUWSb5tbcz38J4AaABAg',
#  'Ugyc3nJfN2VNt9QFyQR4AaABAg',
#  'UgxPMVS4QYIQcLEd5fN4AaABAg',
#  'UgwlQl-acLQEdNP8fC14AaABAg',
#  'Ugwd1jErCx9m6X4Nrzx4AaABAg',
#  'UgyPs962f_gbhdZMLyN4AaABAg',
#  'UgwJPWxNkXPaYPxPmyJ4AaABAg',
#  'UgyKdGMvHdJfpL5jUV14AaABAg',
#  'UgwVUlKnbQhJS6Vx2UR4AaABAg',
#  'UgwKL4pj9hbYeA46Grx4AaABAg',
#  'UgzwizlpV0KjRZBbWyV4AaABAg',
#  'UgyvyTOlV06Xmel5rbN4AaABAg',
#  'UgwickGe_2Pi-ZtYwIF4AaABAg',
#  'UgxiTBr7T0Yd9U887fh4AaABAg',
#  'UgwL3ANOEuxD9HupTjx4AaABAg',
#  'UgwZdO1TVSd-wgKKk394AaABAg',
#  'Ugw6sBAWtYMDfAUFjeJ4AaABAg',
#  'UgwFHg9pkUxlKE0Vx454AaABAg',
#  'UgwcscFXDbaQoFbYcNN4AaABAg',
#  'UgwAwIfRzg6gK1EIVCd4AaABAg',
#  'UgxfYmWHqBxH16WXm4p4AaABAg',
#  'UgyYpSSPRS042KFlau94AaABAg',
#  'UgwQVrCdzHaCUcoWIsZ4AaABAg',
#  'Ugyl431QFsj2KalrgAt4AaABAg',
#  'UgwYuVfYfmqGDUlP-lJ4AaABAg',
#  'Ugy4NROACu15ZHZ-VNh4AaABAg',
#  'Ugwo1V78z5Cnu7CApXZ4AaABAg',
#  'UgxMdyNx9OaRXaklNkt4AaABAg',
#  'UgwouuUFkdLt2dChQIx4AaABAg',
#  'UgzoXf2oCAfbECeB9054AaABAg',
#  'UgypQMMnJuixHAWL1JN4AaABAg',
#  'UgwWA8EYB9d18wQ7hfd4AaABAg',
#  'UgwZ5t_gghdsK6XeeQN4AaABAg',
#  'Ugwkgvk1DIUIhfVxqb54AaABAg',
#  'Ugz_Q9B-Ch1IjkJJ1iF4AaABAg',
#  'UgykKoDSnkdjnHFcOBJ4AaABAg',
#  'Ugz5RkTTobiAB7A5GGd4AaABAg',
#  'UgxHfYBPLoPJCKOZeoZ4AaABAg',
#  'UgxClu1h1wC4Stvhk094AaABAg',
#  'Ugx1-gzck_0GfYHpT0x4AaABAg',
#  'UgwIxI3x7YMHdyBUzuN4AaABAg',
#  'UgyOHQ5Q2zx1cz6IOcJ4AaABAg',
#  'Ugzf1BJgluqBGWrH7ft4AaABAg',
#  'UgwF3gdrQNzjPO5ZI4J4AaABAg',
#  'UgyzYeWoosMm9D845it4AaABAg',
#  'UgwUZpoCNxDDnGqle0Z4AaABAg',
#  'UgzhymE0036a5duvGxx4AaABAg',
#  'UgzM82qP8m5SOG6vtyt4AaABAg',
#  'Ugwxy5KLNhTRQtQzwy94AaABAg',
#  'Ugx-oAnP8izbWG97UIl4AaABAg',
#  'UgxErdI6AaDyXuED-0d4AaABAg',
#  'Ugx63ICjpAFVzVcVv1N4AaABAg',
#  'Ugz3R87c8g6FpDvfEMl4AaABAg',
#  'UgxJf7fAx9_YcELcSBh4AaABAg',
#  'UgzqDc8MR3YL-tiAulV4AaABAg',
#  'Ugz8Stav6u4uISTwxEJ4AaABAg',
#  'UgzIMi9Z5qkxdM6gbc94AaABAg',
#  'UgwQ1-zhGuNZMqi6max4AaABAg',
#  'UgzG_7WV6_SRO_xlxs94AaABAg',
#  'Ugx0sGQbMj6b8jP6fI14AaABAg',
#  'UgzBe77r7b5SGDJhkm54AaABAg',
#  'Ugz37aaTklYsxqaQjR14AaABAg',
#  'UgyJe2MUKuz9lAmvIxV4AaABAg',
#  'Ugzmz2n6guVebS2VWtR4AaABAg',
#  'UgwLEzblCYhyrSZY46F4AaABAg',
#  'Ugy3mvOmhflP0gcIXGd4AaABAg',
#  'UgwpfqPZKTQFKjFflkZ4AaABAg',
#  'UgzKfH-jzu_bzCvVT5J4AaABAg',
#  'Ugyke45h7jX1gEY9Usp4AaABAg',
#  'UgxDb24SXDyxTRFmwvV4AaABAg',
#  'UgxKK_kz70ob_P5DMr14AaABAg',
#  'UgzjfSr_b1mn4gAsFAd4AaABAg',
#  'Ugzmp_6tp2DAzxVHXFV4AaABAg',
#  'UgwIwmPSXfo3Lunvik94AaABAg',
#  'Ugy6oqcqeq6MMnsxpyB4AaABAg',
#  'UgxKWbhOdwuzEiydCRN4AaABAg',
#  'UgzmYbtNH41mkcFbtR54AaABAg',
#  'Ugyr1iDkDWQdIfRRiHh4AaABAg',
#  'Ugxru9Ibnn5H0EgrPC94AaABAg',
#  'UgyyRQ1JtKRTVbxUpEx4AaABAg',
#  'Ugzdvv_RJSmgvLcqxYR4AaABAg',
#  'UgzIBG5f7svyiKnKb0Z4AaABAg',
#  'UgzXe5rJxXeVtkTiLDF4AaABAg',
#  'UgwBhgQpxrmPbxsVaGN4AaABAg',
#  'UgxwZDuNONTFBZqjfCp4AaABAg',
#  'UgzyMapZPoJeMvGQtm54AaABAg',
#  'Ugz0hRRRILcz1IfgTsp4AaABAg',
#  'UgysqO0fznEfRgcL8nJ4AaABAg',
#  'UgxMVsPY5bcdwLNmh_B4AaABAg',
#  'UgyzP42r2goyAmmEL2d4AaABAg',
#  'UgzOREOHrur13F8hz-R4AaABAg',
#  'Ugzjpfcqpkt6A3NpT8J4AaABAg',
#  'UgxZwi9c8arAWmMXUol4AaABAg',
#  'UgwsolFxkM_Atqem2SJ4AaABAg',
#  'UgwjTYtohUgZJeOUpdN4AaABAg',
#  'Ugw5y-c2afPE2ol4y_14AaABAg',
#  'Ugw9sBiYMzBeZSyS7Ul4AaABAg',
#  'Ugz3fPOBeTeBFmvLNxl4AaABAg',
#  'Ugz245-GzoLCPcuf39d4AaABAg',
#  'UgxzOnl5-IWaX4QilPN4AaABAg',
#  'UgwKbhMnClNfgb_I9xB4AaABAg',
#  'UgxTL7Cr-Mz8QJfHMlt4AaABAg',
#  'UgwM5X1_RKCBh_ZNxTB4AaABAg',
#  'Ugy2GIBxAQPUjxGJrkt4AaABAg',
#  'UgybYifXVrUpnu48Swp4AaABAg',
#  'UgwhLBhnT80P4LsTSxh4AaABAg',
#  'UgzTQBBM8cNfVCQZ98p4AaABAg',
#  'UgyyCCSTmCm9-Gs0SkR4AaABAg',
#  'Ugy3Vihnrj0gq0JUUax4AaABAg',
#  'Ugyv2VB5OF9eWadu-WR4AaABAg',
#  'Ugw6ApmqHSnHEmlDrK14AaABAg',
#  'UgzbaiXvf2_MISUDcHp4AaABAg',
#  'UgxGxvuG6LVHLdAjSlh4AaABAg',
#  'UgzblVG7Vv9eaW9drRl4AaABAg',
#  'UgxryhaL67Xx5eaGixd4AaABAg',
#  'Ugxe1T1GjJl-ZptSRAV4AaABAg',
#  'Ugwi1oI0dV2GqIhn0C54AaABAg',
#  'UgyfCP3twoOPgx2--BZ4AaABAg',
#  'UgwAhMNcynWuKlE4Se94AaABAg',
#  'UgxxkcLt3iBANaHCEVx4AaABAg',
#  'UgxHVJtWCfauIuFO6hx4AaABAg',
#  'Ugz0sYRCCgi2KKRTwuR4AaABAg',
#  'Ugy5s2yUgecYdQXMEZJ4AaABAg',
#  'UgzCgPGrN8CSSK_ySyl4AaABAg',
#  'UgyN7bJDvvmCYNA3Ngt4AaABAg',
#  'UgzZs44iBIlXkUtv_c94AaABAg',
#  'UgxMnYH4aeHhxl_wLnV4AaABAg',
#  'UgxJyPxcGsSLnLRVaj14AaABAg',
#  'Ugws0GPwiRnGXexDN0p4AaABAg',
#  'UgwsaJYOpgQS_2ei3Xp4AaABAg',
#  'UgzZ4OL45JYgI376SRt4AaABAg',
#  'UgxQY8IccsvcLlSAsWp4AaABAg',
#  'UgyQ4UlQwQ7ThFIdQV54AaABAg',
#  'UgwgNTGUhNXn3elnplR4AaABAg',
#  'Ugycr9Ua46eXBMKYPot4AaABAg',
#  'Ugx_QKNN7jyaCLLAmol4AaABAg',
#  'Ugz66Ab25UkZ-lAI-AR4AaABAg',
#  'UgzIYToo0UQdrcZZKdd4AaABAg',
#  'UgwjQQGHfvCKi5cN61V4AaABAg',
#  'UgwKuTsa_SPsx4WCBrd4AaABAg',
#  'UgzWcrzpsWqbkRZYQNJ4AaABAg',
#  'UgzvggnaxJlz4lEMw594AaABAg',
#  'UgwS8g07k1T6wMon50l4AaABAg',
#  'UgxxYpLknhy7d13do8Z4AaABAg',
#  'Ugy6p3zCW8IhedWvQ1h4AaABAg',
#  'UgwruZhfprFr4XHWLrd4AaABAg',
#  'UgxckKPug6B3P16X4dB4AaABAg',
#  'UgwvZRgMG3Y7CPo1jWd4AaABAg',
#  'UgxNJeBGd2uo0FNvDVB4AaABAg',
#  'UgwvwJ0VA2BgKkLbWlJ4AaABAg',
#  'UgwCO5IvAmGY5P9HiYB4AaABAg',
#  'UgyX_HPiMFUGwfB0k-F4AaABAg',
#  'Ugxmc7vWQZxC5AKnIRB4AaABAg',
#  'UgzeHOjE_DFhrTAbMFB4AaABAg',
#  'UgygVKe7bLCx0iPp_AR4AaABAg',
#  'UgwL2fH9cbxK2r1rSYp4AaABAg',
#  'UgwQz3CFV_9E8IGaxpZ4AaABAg',
#  'UgyrOdGoMYK-MU4MPrl4AaABAg',
#  'UgwMcV8uG0HGCGDFZCR4AaABAg',
#  'Ugycr1PFz1PHBQM5UEN4AaABAg',
#  'UgxYgfxRHYkfjzc-f-p4AaABAg',
#  'Ugy6NsljS1kOqH_hqlJ4AaABAg',
#  'UgxptdDm2hqfT0qaEHd4AaABAg',
#  'UgwP_ZElrPmifsWYgiR4AaABAg',
#  'UgxKd4_YRYZzTysVoYl4AaABAg',
#  'UgxWkaVCVYGNMgC4Q4V4AaABAg',
#  'UgzCYMemMxysK8qKH8F4AaABAg',
#  'UgyRhacydB5OQyXuuUJ4AaABAg',
#  'UgzDwsXPPXDEtn-6od14AaABAg',
#  'Ugzn_TUq2hEPVO5EXrx4AaABAg',
#  'UgwTZjTLznXsn2G4ZrV4AaABAg',
#  'UgwWq-uV4wfCkAZaL8N4AaABAg',
#  'Ugzb8uY50P8wdn6TkMZ4AaABAg',
#  'Ugxyc9w3RKlbD5A9c5N4AaABAg',
#  'UgwpwfF3naR_X2hYVmx4AaABAg',
#  'UgyT7zwPXAk3iOyJilR4AaABAg',
#  'UgzmHPaVHGpy2s961St4AaABAg',
#  'UgyvnxqRIzHnEdsJ2X54AaABAg',
#  'UgxMJl3pdplSCh2Zft54AaABAg',
#  'Ugw2BShJoyDqOUR5ki14AaABAg',
#  'UgxijCEMnitVJH4r5kF4AaABAg',
#  'Ugxk2r3nmAe22dgBuqB4AaABAg',
#  'Ugxn8m6JujugbGnsihd4AaABAg',
#  'UgyalzUyvNeEwRqAc614AaABAg',
#  'UgyjGllCDYI0nGiwj6F4AaABAg',
#  'UgykybZfJSditkjFWI14AaABAg',
#  'Ugwh-RBL2NYUnCNEf6N4AaABAg',
#  'UgwSPHZFHhR49MsShGZ4AaABAg',
#  'Ugx4vENu_590spxpLWp4AaABAg',
#  'UgzCR8v3lCju7AWKb5V4AaABAg',
#  'UgxMiKO7vSfayczk9kx4AaABAg',
#  'Ugwa3Eto-RVID60grRp4AaABAg',
#  'Ugxd1sBQhVaQZXqlguh4AaABAg',
#  'UgybheT70MwHNrUqcch4AaABAg',
#  'Ugxl0ZWcDscwgTY-6894AaABAg',
#  'UgwTHhIxpivsM_QKn4p4AaABAg',
#  'Ugxxl1rq9PVCdLtUBSR4AaABAg',
#  'UgxpX3OesKXmojnQpch4AaABAg',
#  'Ugxz_mLwRJsnkiZgf7d4AaABAg',
#  'UgyF2hLg-Oxffi4XgTt4AaABAg',
#  'Ugw9HJKubnrxxr16vmV4AaABAg',
#  'UgyX6Lli9rsXHMwwmsh4AaABAg',
#  'UgyKPG2AypAzwlxqnj54AaABAg',
#  'UgxxX49gl_IIlCftFBx4AaABAg',
#  'UgwxJBkhdjfJPX5vtHd4AaABAg',
#  'UgzJx5zizAsfLbUu2494AaABAg',
#  'UgzRzlnpt2Td0_BULZJ4AaABAg',
#  'UgyI2VHceNpu7WIXBdd4AaABAg',
#  'UgzYGBstKXDLym5HFdZ4AaABAg',
#  'Ugw8C_MufJz7ox5kbiR4AaABAg',
#  'UgxqEY2ho2lum7rBPEp4AaABAg',
#  'UgzkCEhowaRJdWeKlLx4AaABAg',
#  'UgzL7BDaAbAfPXKl-_B4AaABAg',
#  'UgztrVPFZ7k6HThPL-94AaABAg',
#  'Ugyz2CZfLHOskRjDt3F4AaABAg',
#  'UgzJ8ZYGwpVWrHA8Ai94AaABAg',
#  'UgyhX31eP44cA5sk1Y54AaABAg',
#  'UgzdC-GoPYlBm1QYO014AaABAg',
#  'UgxVOZSHQNRNNDzUZGJ4AaABAg',
#  'Ugxls8gLmgIFKx9Fqxd4AaABAg',
#  'Ugy8nVbDWQyyrfvPblZ4AaABAg',
#  'UgxHXltYxu0dR9NtlHV4AaABAg',
#  'Ugzz8fu7K2qg7troMIx4AaABAg',
#  'UgxIQ_zxL68fw_zyVG14AaABAg',
#  'UgykO6wbF0bO6jdcv6x4AaABAg',
#  'UgyWwgR9FmU9HfWP__p4AaABAg',
#  'UgxohgLsrXjb0lySVjR4AaABAg',
#  'UgyNCif67MLmD53xrAB4AaABAg',
#  'UgyHsoZfTXs7drk6mWJ4AaABAg',
#  'Ugz1vl9aLE_2YkD-W1R4AaABAg',
#  'UgzffDeRVVCaD71rS9J4AaABAg',
#  'Ugw3e2uRx3JdCpOc51d4AaABAg',
#  'UgyM57HPuAjkowKaHsh4AaABAg',
#  'UgwkHTtcumFqoCxJTLd4AaABAg',
#  'UgzKl4ubsyLh2n6gbk14AaABAg',
#  'UgyDlT7gLYb3rhZZ1ft4AaABAg',
#  'UgyQJv8x39_zzYxO-nF4AaABAg',
#  'UgzBRD4TXvsTm9w2eFF4AaABAg',
#  'UgxRQSYHlcsY2qc29mx4AaABAg',
#  'UgwQLHLVna_ZGTAmbA54AaABAg',
#  'Ugw4lH5PKPzBAwyzDRl4AaABAg',
#  'Ugx5x_WWS0GhYd2QB154AaABAg',
#  'UgwK7wVf6U1ocQMb9Hl4AaABAg',
#  'UgxPMS-pCtksAXbTf2d4AaABAg',
#  'UgyVRxwPvocyvvz0yUd4AaABAg',
#  'UgyEZJVYnQIslz_g_214AaABAg',
#  'UgxuYTF_EJnzajqs3zh4AaABAg',
#  'Ugxzmoho3ytcztpSWnh4AaABAg',
#  'Ugz20n91VZ5n8QQ4YAt4AaABAg',
#  'UgyyTNVKUM4Lt7x6XqN4AaABAg',
#  'Ugz-ZLNfHhCG5dzfvoV4AaABAg',
#  'UgyNbAyErdOOjORKeX54AaABAg',
#  'UgweDeaWn_4YTSy_E754AaABAg',
#  'UgxSr7iapCz6SRPrDZV4AaABAg',
#  'Ugxp0i1Ndy2RalAh84J4AaABAg',
#  'UgzcrNMlkLqcCp-_ViJ4AaABAg',
#  'UgzXfMQnBVxvzAsgSnR4AaABAg',
#  'UgzRM-Y2uETIzvFcQcF4AaABAg',
#  'UgzM2m_teNtjjM3nfyd4AaABAg',
#  'UgwQy9oBrD5hlRBkhOB4AaABAg',
#  'Ugx9OA1RxWUImxSWu9N4AaABAg',
#  'Ugyk8DFOwt54sTOPAUN4AaABAg',
#  'Ugx5WKNYSEzHTStmADN4AaABAg',
#  'UgwpixyLPylvMgOJobh4AaABAg',
#  'UgyLcZQQ-UXT8opnnUp4AaABAg',
#  'Ugz81MTzOpt5mg5khCh4AaABAg',
#  'UgzTfWjaqzvXv7oVmep4AaABAg',
#  'Ugw4BeNFhyeI9XSexCh4AaABAg',
#  'Ugz7wU_D6xstyPvKxfZ4AaABAg',
#  'UgwQwus7UFE2C6EFMw94AaABAg',
#  'UgzkMJB3TX7AMNoaFLh4AaABAg',
#  'UgzulC9Ndj8Fbd6e2FR4AaABAg',
#  'UgzLj8QmN_o6mWkX3Ql4AaABAg',
#  'UgzGx2HeiplvHIoDdgV4AaABAg',
#  'UgySqkZ2bLiN8NuOu6p4AaABAg',
#  'Ugym_sa8pUTXqFHl6Ut4AaABAg',
#  'Ugz0Nc0cc-H7nm32yjN4AaABAg',
#  'Ugzqe4rUOre3lyzZ26p4AaABAg',
#  'UgzY_Y6_YWQ466PLg-l4AaABAg',
#  'UgwC19tDp6A2pSbMlHV4AaABAg',
#  'UgwMbMbOehOWQbtN2V94AaABAg',
#  'UgxxGteDI7X8c0ckTRR4AaABAg',
#  'Ugx3uHawZyz8EqUxbSN4AaABAg',
#  'Ugy3NMIhV4zkd7KgvAl4AaABAg',
#  'Ugw-AOQ6Kh-Qof2U9bd4AaABAg',
#  'UgxAgwYSf8ukj4NSSqZ4AaABAg',
#  'Ugw9JmxVbbGDBFQX_pF4AaABAg',
#  'UgzkapVLh03SI50Sp694AaABAg',
#  'Ugx0ELGM0N1LEXuqQPZ4AaABAg',
#  'UgwI9VN0j_psAct1aUZ4AaABAg',
#  'UgxViabiONesdn7jp354AaABAg',
#  'UgxLOUCbBhD4HL3sa-l4AaABAg',
#  'Ugz6x97-w32hVQYmeOV4AaABAg',
#  'UgyyrGqpoYL1ybZ6vL14AaABAg',
#  'Ugyj6qKsjjQS7bRLNtF4AaABAg',
#  'UgxeSmbYx6xVIW9d1AF4AaABAg',
#  'UgzKr3_2fr1aNgyWCBJ4AaABAg',
#  'Ugx6KSm0RejmWPRJXfp4AaABAg',
#  'UgwuC5x2t6oiub2men14AaABAg',
#  'Ugz1l5I7zU5_eoNmdjN4AaABAg',
#  'UgxKqf3sJZWLDkNoRSh4AaABAg',
#  'UgxqX6srqJek4DldWnZ4AaABAg',
#  'UgyRm3_wTKUiCSMP2OB4AaABAg',
#  'UgxSJqfQGaS7WrgtUxJ4AaABAg',
#  'UgzektWeMdeathsWBl94AaABAg',
#  'UgwxvnUYgERFDOZOxLZ4AaABAg',
#  'UgzRO66jPo6UpGz_rq94AaABAg',
#  'UgypBgOLvpyzVVKRNTd4AaABAg',
#  'UgySWx2wsESOlb4NLRZ4AaABAg',
#  'UgxFbmqSiajdf4B-N314AaABAg',
#  'UgxuPSfWYLD9j-LubLB4AaABAg',
#  'UgxSczE8xySl4Sa3hA14AaABAg',
#  'UgwlDPwGMMBDO3X353t4AaABAg',
#  'UgwmSTPe_-10KJxy3H54AaABAg',
#  'UgzHUfVn1XLF9KkQ7Gd4AaABAg',
#  'UgwRsHBAgejzwyD767N4AaABAg',
#  'UgwNQycHqXgdRbwsmK54AaABAg',
#  'UgxYl3Qh6eBOL2BHfRp4AaABAg',
#  'UgzMz-tCbyFZ3SV1NLh4AaABAg',
#  'UgyWAwZI-kXDXE1HBxF4AaABAg',
#  'UgyVl-hFJ04ZCKo1UaZ4AaABAg',
#  'UgxnVQt3Rtzv3Sl4B3x4AaABAg',
#  'Ugzi0stXNGW6GICZ4DJ4AaABAg',
#  'UgzM8M72jqKxC8RWQ3B4AaABAg',
#  'Ugy6qT3hWzdypmCcmXR4AaABAg',
#  'UgyjTPs1GjsFUo5VM8J4AaABAg',
#  'UgwtOAEyrE4Awk2-Y714AaABAg',
#  'Ugw_I4QstOoUSOZCg3l4AaABAg',
#  'Ugz_XMoK877uRgxc5yZ4AaABAg',
#  'UgwSPqB0lgqJLd9lRUJ4AaABAg',
#  'UgwlpamQu7z_HbiiQm14AaABAg',
#  'UgxUEF3rMDQz-Cp9tDN4AaABAg',
#  'UgwjfZtFT2v8BkYMUAh4AaABAg',
#  'Ugy3D1dE5KVUW84L8dR4AaABAg',
#  'UgxBBuFbXv2KOLHjIB14AaABAg',
#  'UgyNs40hsTc_SvBpk4B4AaABAg',
#  'UgzQw83Uq3RnxASJzHl4AaABAg',
#  'UgxSdPaCsfK6cIoc1P94AaABAg',
#  'UgxZxp8TBga8QlPXR354AaABAg',
#  'Ugwl3kkvKJNKEoN4rxN4AaABAg',
#  'UgwyAegC4I5xs5OViEt4AaABAg',
#  'UgzStzwgzSrm1q-xXVN4AaABAg',
#  'UgxQwRDcs9BUUYG7yLV4AaABAg',
#  'UgxwhpCDgfY-9uGBE8R4AaABAg',
#  'UgzhwIk2RcSw5JyGb454AaABAg',
#  'UgxGI3TBxV00-03f0Pt4AaABAg',
#  'Ugz8dKwESOo6XLzjvlV4AaABAg',
#  'UgwYzhEwjzmiuwgZ9G14AaABAg',
#  'UgydlQQgQHS9zWnJrhd4AaABAg',
#  'UgxfbF_j125kAWM3ct14AaABAg',
#  'Ugxz9dA_teocgbas_FN4AaABAg',
#  'Ugwhxl0no2RAeQil5iR4AaABAg',
#  'UgxqOkbany53kr_EzBl4AaABAg',
#  'Ugw3ZO7f5O2cqWFvrfN4AaABAg',
#  'Ugyp3FWBeoXDVQhpEFJ4AaABAg',
#  'UgzwIgN9uTQ2LS9I4fF4AaABAg',
#  'UgyRrQ6FDpi3ta4Cw5x4AaABAg',
#  'Ugy7QSr2Lu8xpI5LEkV4AaABAg',
#  'UgwlYVrr_1eQr7KzPrR4AaABAg',
#  'UgztfJgw5OLlGWImMTB4AaABAg',
#  'Ugzm_o1Qjlkjvi53PQp4AaABAg',
#  'UgzU5SSKhqYtcYIsWfx4AaABAg',
#  'Ugxg14mGh5FqtJJLE494AaABAg',
#  'UgwwK5QnBmIa_bD_Trx4AaABAg',
#  'Ugxh8tUXfxJNoBSFeCV4AaABAg',
#  'UgyQMxgJ3xvquXBshYx4AaABAg',
#  'UgxNFmOnjuoQ1QqWEqJ4AaABAg',
#  'UgwfsDAZX7CQNUQswr94AaABAg',
#  'Ugwj1EtcG0mvXTAD8-l4AaABAg',
#  'UgxfqwyJVF8EMMlJogd4AaABAg',
#  'Ugys9hwH_aN7AuWcJTB4AaABAg',
#  'Ugw9JbYPaj0yyJKHyzd4AaABAg',
#  'UgxoZ8f-l-UhiSMs2qR4AaABAg',
#  'UgxHL_BDh4n88jNNHj54AaABAg',
#  'Ugzoh7lL20a0djreO6x4AaABAg',
#  'UgxfiO_ErKNGrkFZSSZ4AaABAg',
#  'UgxGa9QCgP4v4ZOrncx4AaABAg',
#  'UgxjkJZTgYBzT8V_Xzx4AaABAg',
#  'UgwaekxQL6LVU_xvOwl4AaABAg',
#  'Ugy126OYRt6cOZFrGtV4AaABAg',
#  'UgwX5LON4ICYU6QcS3B4AaABAg',
#  'UgxlOcQrFzZ14G0G1_N4AaABAg',
#  'Ugyfd0B3lRulrjj1Qkt4AaABAg',
#  'UgzGNyA7LcMqqAWaULJ4AaABAg',
#  'UgzssW819hMR4nKhGMh4AaABAg',
#  'UgyO3w61yUC3KUoyath4AaABAg',
#  'UgwlfGEH0nQNl7NyxZd4AaABAg',
#  'Ugzs7FKjiwgHMftoq2J4AaABAg',
#  'Ugxgu6vv8LV_dMd0COB4AaABAg',
#  'UgwxbxDp8xZUSWBuBiZ4AaABAg',
#  'Ugw2kWlIAe_3be_nayB4AaABAg',
#  'UgxoSkZ8OPk_htYoU6x4AaABAg',
#  'UgwCqcd_EO6Ifpl3NQV4AaABAg',
#  'UgxILnyjIlcyAnAIvmh4AaABAg',
#  'UgyIN01FhkMxw7clUZJ4AaABAg',
#  'UgyLtbojkF9L5JVP0jt4AaABAg',
#  'UgwZHx7dq4pXwJbFVIV4AaABAg',
#  'UgyzUyNF794tfJQ8yZR4AaABAg',
#  'Ugz62M-20-Dn6-qj2qJ4AaABAg',
#  'UgxPfMQikDfzWx9S53R4AaABAg',
#  'UgzEyGK_NSGljH2jlS14AaABAg',
#  'UgxF9i2xg70BBfOQq-h4AaABAg',
#  'UgzBxLyF2gKskAKtGUN4AaABAg',
#  'UgzB0bwRdWNXxCOaNA54AaABAg',
#  'UgwL7-m1b7PiYsKWh5B4AaABAg',
#  'UgyrPUqVHWmvyBLsxN14AaABAg',
#  'UgzsyiLay1TVUUO0yk94AaABAg',
#  'Ugw79fAxcV_2cJXh7t94AaABAg',
#  'UgywJ5pmgnFjLDdQt5B4AaABAg',
#  'UgwA4x4pG7aJljXc2794AaABAg',
#  'Ugz4FRmj9fJqWdKkSn94AaABAg',
#  'UgzDq4h3I69YHz2QhA54AaABAg',
#  'UgwbTsQ68rMPh5usDb94AaABAg',
#  'UgyFRwOZrWmXGUjgDiR4AaABAg',
#  'UgwqgzcbOar-uXPEpSd4AaABAg',
#  'UgysUHJAjka26w-A2pJ4AaABAg',
#  'Ugx8UXABjfHUtJmtp-J4AaABAg',
#  'Ugw4cGutVuR2hLB7iaZ4AaABAg',
#  'UgxndAtMVAFPfC9M4Up4AaABAg',
#  'UgwRl62cnTX_a3YvoLZ4AaABAg',
#  'UgzhJa49rcwPfuPYjE54AaABAg',
#  'UgxVh81m8e-0Ivs7OBR4AaABAg',
#  'UgzF4-RDweWxeADBjLt4AaABAg',
#  'UgzTzy00AMA3DTnnZ814AaABAg',
#  'Ugwxr_ACcJ7EkybQLMV4AaABAg',
#  'UgxcsFHvTg7fOchAXFJ4AaABAg',
#  'UgzIjmPFm7HhNsdT7gx4AaABAg',
#  'Ugyu8Mj5xDGhWcyw8SR4AaABAg',
#  'UgwTurbF5UpmGjIw4Gp4AaABAg',
#  'UgwDCbUjB79lWDdoILN4AaABAg',
#  'UgxAhTxWuXPwkkmKHYh4AaABAg',
#  'UgzyOJSqEARJWY2ADHt4AaABAg',
#  'Ugyp53C5mcQVZjK2CuF4AaABAg',
#  'UgwhQLT7kTVvsbLC2st4AaABAg',
#  'UgyJ7kngHknrnRZcucF4AaABAg',
#  'Ugx8gKlv2EgrJ6FSkkR4AaABAg',
#  'UgzmlwQyUiDEL8cLxjd4AaABAg',
#  'UgwpmNeSvtiBVcVyiJl4AaABAg',
#  'UgzzUUTomxh55bFmYn94AaABAg',
#  'Ugz4NRLzR20xqtYi3sp4AaABAg',
#  'Ugx0auJv_U5lJtE8FaF4AaABAg',
#  'Ugxobp1PKy30ZC4d0iB4AaABAg',
#  'Ugy3ZJY3hp9_zq-qGrx4AaABAg',
#  'UgxomyJEWqu0Q_KpOJt4AaABAg',
#  'Ugwz9XmJAoyy9U4rptl4AaABAg',
#  'UgwYlSndAC75jREuLVt4AaABAg',
#  'UgydGUlxW7rcNwaGY1t4AaABAg',
#  'Ugya-nT8O07_SGfzqWF4AaABAg',
#  'UgwuqrAwd_r7h00qywh4AaABAg',
#  'UgxqXVFjJ64Uj6fCpaB4AaABAg',
#  'Ugzr3P1gMOLzP1toL914AaABAg',
#  'UgxLDFzU8LG_HwVrLvh4AaABAg',
#  'UgwzegeQQfcb7gYEqd94AaABAg',
#  'UgyzvA0LP4uxR6kPjaZ4AaABAg',
#  'UgwXtYzBUR23fDdzCqd4AaABAg',
#  'UgxQprFmP59JALsRZoR4AaABAg',
#  'UgxRsy3UOkdZQqyZhnV4AaABAg',
#  'UgxrKM_Df5gjs4QvbEB4AaABAg',
#  'UgxujRDqHInSvOCWfE54AaABAg',
#  'Ugw--0R2Pf3Wh3WvjX94AaABAg',
#  'Ugwg5lGVRWse5KY0EgJ4AaABAg',
#  'UgycZRBFPxYVXENVqgd4AaABAg',
#  'UgyYAzWSDahsV5pSbSR4AaABAg',
#  'UgzL4ysNhp7Sg1yFyIB4AaABAg',
#  'UgzOySGuE9HQnatUDiJ4AaABAg',
#  'Ugx7o3NeKwl4_jNEk0l4AaABAg',
#  'UgzrfrevuIbKT-sPILp4AaABAg',
#  'UgyRSRgfFGddHB3d4s14AaABAg',
#  'UgyxPKfkgOMAhK3xEOJ4AaABAg',
#  'UgyZb7P9u-CJDa1eadZ4AaABAg',
#  'UgwLf1IBxhS6RRK7xoR4AaABAg',
#  'UgzV6vY8kskxk_KeXuh4AaABAg',
#  'UgzRK0EHNU3H0OY1OWV4AaABAg',
#  'UgzIVF1iHVQrD8y3YVZ4AaABAg',
#  'UgyOSBzbWLegOm3_ZP54AaABAg',
#  'Ugw7CWoDR6gXarB53Ft4AaABAg',
#  'UgzVx52uHGz_pBc5xuJ4AaABAg',
#  'UgwLdYpd_u_beqpd6_94AaABAg',
#  'UgzbcjSpTCfS3yJiGDJ4AaABAg',
#  'UgwJJunc4_lKB2RVmNJ4AaABAg',
#  'UgxHOzdjU5LTubEngsx4AaABAg',
#  'UgzFFBoydsja2fn65gp4AaABAg',
#  'UgyTjoSPU0GwJuEhnsd4AaABAg',
#  'UgxHMq-NHwS7G3WWtAF4AaABAg',
#  'UgwDYGASYbfS39esBT94AaABAg',
#  'UgzUy2FeIodJS-pHvPN4AaABAg',
#  'Ugy50tCmVpYgT-auYNl4AaABAg',
#  'UgwCgaocWuSGTj8nZwR4AaABAg',
#  'UgxvqE4TZXCDdxhjIjt4AaABAg',
#  'UgwjQvwP5Wny9UOUFFZ4AaABAg',
#  'UgzRP3VrdqJ8w-nLAXp4AaABAg',
#  'UgxjLiz-rpmBz4i1lT54AaABAg',
#  'UgyckaC0PRPwipGBwOV4AaABAg',
#  'Ugzy8oy-IMVHqXmm2dh4AaABAg',
#  'Ugzqikuy3iA4iQ8OuSh4AaABAg',
#  'Ugxbv8jj-jKEmNiSmZV4AaABAg',
#  'UgyUsIGnXwa07cEWbb14AaABAg',
#  'UgzmPEZ9Q_F3Ocl2acJ4AaABAg',
#  'UgwOBC8smQIP7JCgG6N4AaABAg',
#  'Ugz-4pquJtlfUoHLz_d4AaABAg',
#  'UgyW04CJvHxLZVc4XNF4AaABAg',
#  'UgzANBoWT8fsEjZbeTJ4AaABAg',
#  'UgywALhfGqUvrFimlhN4AaABAg',
#  'UgzO11rpm4S-JTZ9CMJ4AaABAg',
#  'UgwgibkI2ukmOm5gsqF4AaABAg',
#  'UgyziZKRDVwUpFc5Vw14AaABAg',
#  'UgxdbHI7e52mQXldm7h4AaABAg',
#  'UgyaDSot1J8mLsDwIvR4AaABAg',
#  'UgxCgDYrAK4ywfxhwjl4AaABAg',
#  'UgzyA9JDyhbQqz12pVl4AaABAg',
#  'Ugz6XLEc7y_NFFwsWk94AaABAg',
#  'Ugy6GeMFXVL0KTo8kHF4AaABAg',
#  'UgykvSPftRHtmR_V1Wh4AaABAg',
#  'UgzuBtGkNdFDloio2U54AaABAg',
#  'UgzdXYdK2N9xqHGAcNx4AaABAg',
#  'UgzJ4nJ8p_GS6npgi1h4AaABAg',
#  'Ugxg6sU8XaPtLILuVgF4AaABAg',
#  'Ugy3cNwB2QpY-Xuxsit4AaABAg',
#  'UgyLEgN-4_rlg27MrP54AaABAg',
#  'Ugxeeu6W3vYLjoaainB4AaABAg',
#  'Ugz83EtYtBH-pVpJ9ZJ4AaABAg',
#  'UgyMdVQZLXRCm5iK15p4AaABAg',
#  'UgwMLSpegD05LsADUAl4AaABAg',
#  'UgwYpA3GAeTkcPGoAj54AaABAg',
#  'UgwNrL5J-Oi5tDxjHrF4AaABAg',
#  'Ugw0GSEyvuXOuzjOY6R4AaABAg',
#  'UgwgKKLlMi481U8rFbt4AaABAg',
#  'UgyKsXi7bxsFW-uKZjd4AaABAg',
#  'Ugy3ZEMyk0O7XcTxkLR4AaABAg',
#  'UgyqYNRgt7iSMFp-tS54AaABAg',
#  'Ugy1L7oAbn7piylSmKZ4AaABAg',
#  'UgxCHmoPJBekRBY0peB4AaABAg',
#  'UgxhuffONV7Pwoi_Erp4AaABAg',
#  'UgxGNJpjyef1K5fTJwN4AaABAg',
#  'UgyKLP1vXf_HhCj2pEx4AaABAg',
#  'UgwxuvMv5i8_tgQYxOp4AaABAg',
#  'Ugz6C85Kmmw1y_3R2BF4AaABAg',
#  'UgyozmdLewXCJiQLmsp4AaABAg',
#  'Ugxhxh2_pcHDNl8oR_x4AaABAg',
#  'UgzRAbhljdzOYC8ldah4AaABAg',
#  'UgwVKKk4zLqaW_mG_wp4AaABAg',
#  'Ugyqa7LjIHqT9K9A2EB4AaABAg',
#  'UgzLR6ncc3YUFcrgNzx4AaABAg',
#  'UgyDqyqioXHHRsaz-r54AaABAg',
#  'UgzxnDLuP53wtw-rMcd4AaABAg',
#  'UgwaVZ1sOcuDbWaw_Cl4AaABAg',
#  'Ugx3LKg5pDB7XTWvW7Z4AaABAg',
#  'Ugy92QMKhYiNFAs06q54AaABAg',
#  'Ugx6M9uMAroX_HaQDYp4AaABAg',
#  'UgwOaUYs8F4sIhIer5B4AaABAg',
#  'UgyTdUtAOJk4OwKL5E14AaABAg',
#  'Ugyy2jE765aM_w1bLtJ4AaABAg',
#  'UgxhdiqVy7HRjmVv0AN4AaABAg',
#  'UgzkLn1VXl1DtaFtzC14AaABAg',
#  'UgxH4b03vv6mM6s8UFp4AaABAg',
#  'UgwbQakHFbp2ke_BZRB4AaABAg',
#  'UgyoDLyOapW3SBOGpwV4AaABAg',
#  'Ugw8T5PdGC9ekeO84MN4AaABAg',
#  'UgwMdld0M4Ccc9rgWVd4AaABAg',
#  'UgwlmhGWml7-vusZMEp4AaABAg',
#  'Ugx7Nbdi9y68triT1K54AaABAg',
#  'Ugz0cqKNfLKw7WENmBp4AaABAg',
#  'UgzB2rV19kluZ4ZWKUJ4AaABAg',
#  'Ugycc3jel4ac2igJCH54AaABAg',
#  'UgxizqL9qG5BVHqbeiF4AaABAg',
#  'Ugw90P5ax3Gz3Fl9AGZ4AaABAg',
#  'UgxG7zJKXIvJMiEpOT94AaABAg',
#  'Ugxu8pvLudNSPvGvR0l4AaABAg',
#  'Ugx5UrYPbqn5-OflmG54AaABAg',
#  'UgxJG2Ije_qOWcmgxEJ4AaABAg',
#  'UgwKu7QEGM7C22HbLQt4AaABAg',
#  'UgwGFD-7VrZ9sUnuf9V4AaABAg',
#  'UgzDsU2RR6nreQS3IU94AaABAg',
#  'UgwNb6VWM3b8e28iqVB4AaABAg',
#  'Ugy_esJ5f8yPDmRX4Wx4AaABAg',
#  'UgxiLU27hnEgVa6ei8R4AaABAg',
#  'Ugwp63YgnmbU40EqV3l4AaABAg',
#  'Ugwrgi7bTqVx4vGdmwN4AaABAg',
#  'Ugz3031b7Kw95pXvTGF4AaABAg',
#  'Ugxlx4ccny1snoMcIWh4AaABAg',
#  'UgyMpcsWlHTsdkNqme94AaABAg',
#  'Ugxo0-jY7aS9V2zIQXx4AaABAg',
#  'UgzTauNn06TeZ2zEYq14AaABAg',
#  'Ugyalwh5DsqdqZc-vdt4AaABAg',
#  'Ugwz1nZwQgifaC0Sn014AaABAg',
#  'UgxdVZ5MyTEX92I9m9x4AaABAg',
#  'Ugxgleo_Tom_L5yhOol4AaABAg',
#  'Ugzb8gBLVdZ52Zjm6Q14AaABAg',
#  'UgwQU5Cdwe_1EHLWMQR4AaABAg',
#  'UgyTQE1zHsooZfWXxHd4AaABAg',
#  'UgzAey-NMzzvXpYySq14AaABAg',
#  'UgwKiDtsUnRp7Up3DWN4AaABAg',
#  'Ugxm4oJNIj573hHJ-X14AaABAg',
#  'Ugxo-p89AJ_y1C_jD4h4AaABAg',
#  'UgzBbtBWQY9bf5NQkxp4AaABAg',
#  'Ugy7tMKrSYvOsvX77JF4AaABAg',
#  'UgxyDcDPXxfqeyFTUGl4AaABAg',
#  'Ugy4isMUVkQ5SKfavQN4AaABAg',
#  'UgyHuJQM-RbrDHo4W_d4AaABAg',
#  'Ugz_CgmlYq_nfkYj2u14AaABAg',
#  'UgziC1easmsN6vdfzc14AaABAg',
#  'Ugzox1nu0ygKGrpWDwt4AaABAg',
#  'UgyfOmMdsqnBWNwV68F4AaABAg',
#  'Ugx_Uh-LhjWKLsRp13l4AaABAg',
#  'UgzzOlqmEchpYrxSzwd4AaABAg',
#  'Ugx414gLLe0Dk34fByx4AaABAg',
#  'UgwcmMNJM8lHN6YKgF94AaABAg',
#  'UgyvyA_wInJb5spbFLF4AaABAg',
#  'UgyOcuFzWGCBmo92SnR4AaABAg',
#  'UgxWwEtnNIoiCOORTql4AaABAg',
#  'UgwSSKfq7hauwfGgnA94AaABAg',
#  'UgyArpI3eIZca9Nkx-x4AaABAg',
#  'UgyrdDpZ0Jt2k0krx_94AaABAg',
#  'Ugw71c0HtZY_nWdXbUB4AaABAg',
#  'Ugym8TgahwTQ3kk2dxh4AaABAg',
#  'UgzjNMwRDpB2VX5NbfZ4AaABAg',
#  'UgwjvlkYMuW-0Nux6Rd4AaABAg',
#  'UgxfLWlLfFu63wjUG2d4AaABAg',
#  'UgyFP3U2jbmkdfobaO94AaABAg',
#  'UgyTLl66aKReXKWVey94AaABAg',
#  'UgwcVZZQcTFeTpjMmnh4AaABAg',
#  'UgyiJXoihT5Y_ihSGm14AaABAg',
#  'Ugy_zADex1SqJoufVWF4AaABAg',
#  'UgxByW1JN3cAIylxVah4AaABAg',
#  'UgxBptdxBbJKrxJ3JYB4AaABAg',
#  'UgwWl5dzjgiEUkLTn0R4AaABAg',
#  'UgwdyBtDMWwWGKT2Bml4AaABAg',
#  'UgxzdohQKFuyBaYiOmt4AaABAg',
#  'Ugy1Vl8jcqAhVMaXePN4AaABAg',
#  'UgxnUAAMTMetmkF7vFF4AaABAg',
#  'UgzommAy8o4ColDGuN14AaABAg',
#  'UgxMR2EU59yXFotl9xF4AaABAg',
#  'UgxA5dRtjBwPUXa2w3d4AaABAg',
#  'Ugy9ShOvRS8wRbsVxTV4AaABAg',
#  'UgzXcDMZDBAFwJxVSo54AaABAg',
#  'UgxLhxvmFnvx3bhXX694AaABAg',
#  'Ugxfzb8h8N9qaPeUlA94AaABAg',
#  'UgyKoJ0-6OlyD0Acq3h4AaABAg',
#  'Ugzd2WHQV4NhezRy9cN4AaABAg',
#  'UgzZEnzv-pKEuUHj0614AaABAg',
#  'Ugx-En00DegtKWMeJ8J4AaABAg',
#  'UgyMNujFDXn7rAr1Thd4AaABAg',
#  'Ugw9-y7yWkvVjJkgVFZ4AaABAg',
#  'UgxPeyOfjbcxWNdRcqN4AaABAg',
#  'UgwjWeDbfdSR3_IbDmp4AaABAg',
#  'UgyinSqqQm8AElB7A7V4AaABAg',
#  'UgzvME2PsyyXv_fSe_x4AaABAg',
#  'Ugz7lI0Qe65FT6uBgv94AaABAg',
#  'UgzADer1-RXEFBwFnVN4AaABAg',
#  'Ugys4ylmqzbG72stT4x4AaABAg',
#  'Ugzn2UXNEmTejVReNsd4AaABAg',
#  'UgyZqXBQyQ0_lafrIzV4AaABAg',
#  'UgypF6hrLgPTz3YNmSh4AaABAg',
#  'UgzkuNkU-9KoQcsL0EF4AaABAg',
#  'Ugzo5Fh4Dd6elkS_aG94AaABAg',
#  'UgzEDmUC94iiIn-cwKN4AaABAg',
#  'UgxagHpwgXsn-uUmXeV4AaABAg',
#  'UgykZAifisDqxp6sYt94AaABAg',
#  'UgxVLFHHjm8xBaogqEJ4AaABAg',
#  'UgwrcPo-6Py1yTaUsrN4AaABAg',
#  'Ugwq3nmlCNhnOuraJph4AaABAg',
#  'Ugxs6qx7Yu9ci_wlZ1Z4AaABAg',
#  'UgxgjC4Dmu3LqajcHNN4AaABAg',
#  'Ugxr9wiHDMjFmJS7GQR4AaABAg',
#  'UgzTlSt3LGn787KTrlx4AaABAg',
#  'Ugy2xrZw09X6fMH2a_J4AaABAg',
#  'UgzObsEUPy43qwuVi3x4AaABAg',
#  'Ugz0HKpUlHjau4iiy-d4AaABAg',
#  'UgwC6FafI0ojmseTkft4AaABAg',
#  'Ugz_OX-fQcS4uSGXThl4AaABAg',
#  'UgybspOs9eO6zmJXpDB4AaABAg',
#  'Ugy80498fucawp1M6yx4AaABAg',
#  'UgyDh7eOpm_CzAYXHhV4AaABAg',
#  'Ugx_i8yvXs_6GwAQotJ4AaABAg',
#  'UgzOHwXI1aQnLEpqmT94AaABAg',
#  'UgxJ6hg8-yJTa79fdc14AaABAg',
#  'UgzDvgGSuPJmv61-Ye54AaABAg',
#  'UgyvxNPyyGoYT-qr5r14AaABAg',
#  'UgxZ9nBb17sQGtv6u254AaABAg',
#  'UgxANin9rkI988irlLt4AaABAg',
#  'UgxlPAmIxf7xVxqDwSF4AaABAg',
#  'UgzXACm6VMoOgnK9Ph54AaABAg',
#  'Ugx-cg_VRX54O-SqTCV4AaABAg',
#  'UgxY3CC6XwdJeJVxYFJ4AaABAg',
#  'UgxFfcwZRTXGR6bzSUJ4AaABAg',
#  'UgyJm_MNja9Qp3hH9qN4AaABAg',
#  'UgyS2iEQVCR4XJCLllN4AaABAg',
#  'UgzSp6IecYaCZ0dqsk94AaABAg',
#  'Ugx23lCfaWZ5xp2FvBZ4AaABAg',
#  'UgzgHYFCny5KkEFUGTx4AaABAg',
#  'Ugwf93Uz7Y2SluxNYzt4AaABAg',
#  'UgzOJft7zgF9jOlEQrh4AaABAg',
#  'UgxRm0kI6bSNX2Dtkw54AaABAg',
#  'UgxeB00nhU0IfAsd4Rl4AaABAg',
#  'UgzDNweB8je3HrCH1uB4AaABAg',
#  'UgzIJKGpQy3IgnmtLHR4AaABAg',
#  'UgzjIGjb3N406PftEUh4AaABAg',
#  'Ugy7Km4QcYk8DcMnB714AaABAg',
#  'Ugwrvn10lRZ_uSWbBLN4AaABAg',
#  'UgyJK1Mz0GfgXwPtu8p4AaABAg',
#  'UgxLXP0Fu6OqOgcejxh4AaABAg',
#  'Ugycv81Ou6Q1-OJcVPN4AaABAg',
#  'UgzRv4fdv73nKOmqO4V4AaABAg',
#  'UgzmZIi9J7F1IYpoZr94AaABAg',
#  'Ugyx-lKfkv7AobKo24d4AaABAg',
#  'UgzRd5qTTxxCcRQWl9V4AaABAg',
#  'Ugxcvzi1uCdIuIE9iQV4AaABAg',
#  'Ugw1Ipsye0zIPA26AgB4AaABAg',
#  'Ugw0B3FT-nhOq61wauF4AaABAg',
#  'UgzOVUQySvdSixJtvq94AaABAg',
#  'UgwQ8QssIOdGWE2ngIJ4AaABAg',
#  'UgwWnTwJ0muBbu--mg94AaABAg',
#  'Ugy0H_NUssHG9-S8vI14AaABAg',
#  'Ugz7To5CI0mCk6w9ICl4AaABAg',
#  'Ugy4mQXLiT6PUO3EN214AaABAg',
#  'UgwMW3Qk4zOfdhea9Cx4AaABAg',
#  'UgwGiPNrzYYSwaInlnR4AaABAg',
#  'Ugz4BU3rzU1i7eI3aDp4AaABAg',
#  'UgwiMr7dd4nkBV9yGOV4AaABAg',
#  'Ugx65F_GX28DAfk9MtR4AaABAg',
#  'Ugy7iU5CuTREMh2Gq714AaABAg',
#  'UgxQt9uW7juSvINQ08x4AaABAg',
#  'UgyFwI48uJRZL1VP_3Z4AaABAg',
#  'Ugy60Kxt4mDl1LYQ9ip4AaABAg',
#  'Ugyc_xSwfboLMj7fVCp4AaABAg',
#  'UgylsBZ3O8FaT-fEArZ4AaABAg',
#  'Ugxkfn2ZhdPtqGgNhfF4AaABAg',
#  'UgxdqaXX0DHI6wOhAxZ4AaABAg',
#  'Ugzl84oAaMHKdPUwAOx4AaABAg',
#  'Ugy5HrNcBTjnpX-pR7t4AaABAg',
#  'UgzWXcH5lbjRwLfUid14AaABAg',
#  'Ugw4-vj9Do2N-AuvXy94AaABAg',
#  'UgzYL3dLZwgfPhKMN1d4AaABAg',
#  'UgyDuSciyhBFQCgmIAB4AaABAg',
#  'Ugwb8SiPFXNkZ-Iwf7R4AaABAg',
#  'UgwYBxh1Mp-zfmCMGvN4AaABAg',
#  'UgzFXIgIrRrQpY8TcQx4AaABAg',
#  'Ugwtl80UnHvMly9n5PZ4AaABAg',
#  'UgzOYcPckpOg7g03MXF4AaABAg',
#  'Ugw8Q0vpzadqsDwWLAx4AaABAg',
#  'UgyX7BgiUeTo3IWicF54AaABAg',
#  'UgyWSVgTKz76hG5mGEV4AaABAg',
#  'UgzBBq-lDUmyNwwxWzB4AaABAg',
#  'UgxZVRJf7TVXXKrZRJB4AaABAg',
#  'UgwXbzbfUnCs7wo8uad4AaABAg',
#  'UgwMR3H0mbeEFzl4fJN4AaABAg',
#  'UgzhZF_K0OhEJ5sleFt4AaABAg',
#  'Ugw_1b-Io9zs_UCqwxd4AaABAg',
#  'UgzFvHbr1QUzq9uHr1R4AaABAg',
#  'UgymUUUB7BRLMm77npZ4AaABAg',
#  'UgxrIda7IHnDqeFSg6N4AaABAg',
#  'UgzPWBl9Hk8HJtWV-fZ4AaABAg',
#  'Ugz1-KrM1YhY--Ok50B4AaABAg',
#  'UgzKsLYXSr9tk7aSvNN4AaABAg',
#  'UgxlYENQ8hwoLo8R_Fd4AaABAg',
#  'UgzPhMd4Sjq5J6SFXYt4AaABAg',
#  'UgwDORImXSZdfx25bh14AaABAg',
#  'UgzkQH6jqR5_piM8mlF4AaABAg',
#  'Ugw_JvCWk-9Th0F_ELR4AaABAg',
#  'Ugy5oYkGksLdd7JbYWN4AaABAg',
#  'UgytLfDp4vz88KIxaqJ4AaABAg',
#  'Ugy1dYveQeWmX6eVVgx4AaABAg',
#  'Ugw3l-x0MU0f2KJ9OMd4AaABAg',
#  'UgyyEs8p6jn4c-FAsYd4AaABAg',
#  'UgyQ00Vm2En2h2VimXx4AaABAg',
#  'Ugzvfg1xCE9mZjHCLMN4AaABAg',
#  'UgwcntP_ZPOUlv4mo354AaABAg',
#  'UgzBdWASQ377LWMcw494AaABAg',
#  'UgwaCYf5yEODk4GRgAh4AaABAg',
#  'UgwLL1_YK_peHxzzdoZ4AaABAg',
#  'UgwX1apr9Oz5tF232sp4AaABAg',
#  'UgwRK11YYopOdHwbt-Z4AaABAg',
#  'UgzWTwNukBiTbtFUJ6N4AaABAg',
#  'UgwXT7hVi9fFzNs8TQt4AaABAg',
#  'UgyoK8d9q3RG7IXImFh4AaABAg',
#  'UgwD4spNhOA1c3U17cZ4AaABAg',
#  'Ugw1Ial_FQ5gAaGTqQR4AaABAg',
#  'Ugw6ftBLxwp7almTK6R4AaABAg',
#  'Ugz-rgt1eR-NGLHCr8J4AaABAg',
#  'UgyNpvfMPIxPJ0FSOtd4AaABAg',
#  'UgxvS4Zio6w03bq6Tat4AaABAg',
#  'UgwHnaKNVTDOdcda0pB4AaABAg',
#  'UgzuzrDHnVetmPf2AAp4AaABAg',
#  'Ugw-BcMdaWHfzZg2wLd4AaABAg',
#  'UgyU8D5LlUlpvi7WMXF4AaABAg',
#  'Ugz6FtC6HjoJB0x9cOd4AaABAg',
#  'UgyI--hUg0boHKo_R4p4AaABAg',
#  'Ugze0FoTh9lldnYqz5l4AaABAg',
#  'Ugwkv5_T2vYMvi5zve54AaABAg',
#  'UgwcIoNGg43Ytz6US6Z4AaABAg',
#  'UgxCZf2b1oDFoWbZeUZ4AaABAg',
#  'Ugx6Hwjsj4VOhH8qg854AaABAg',
#  'UgxDKoO0iXTAmVQeVhp4AaABAg',
#  'UgwrxJXKK6qcttn9bkR4AaABAg',
#  'Ugxu3VPrb47gntiDryd4AaABAg',
#  'UgwtIdMIM8jdLKKFfbt4AaABAg',
#  'UgwuluAS4ulz5E2FOiN4AaABAg',
#  'Ugyhf5hndVRJ4bAq3z94AaABAg',
#  'UgzOEKsIAfll3jTSAVR4AaABAg',
#  'UgzLgVFZd5D5P-ZWKYR4AaABAg',
#  'UgxbOhQaxS8TdNWLjeZ4AaABAg',
#  'Ugy6Q-ROQJqcEEO0v0B4AaABAg',
#  'UgwmOhNcObQyjNVhzhB4AaABAg',
#  'UgwYcB7KTz3ur16EfTN4AaABAg',
#  'Ugx66OnJjX8XUsDYPpJ4AaABAg',
#  'UgzxqqpMg2TFCumDcXF4AaABAg',
#  'UgxZmT9ujhHrjlfh-9N4AaABAg',
#  'UgwMgDNXEVyEjNgabfp4AaABAg',
#  'Ugyx74GU6Pid76HWTTl4AaABAg',
#  'Ugwtb0MSIh1mdFeTh6d4AaABAg',
#  'UgzxinKCVEVfmu4AvGp4AaABAg',
#  'Ugx65722qwsslvLll894AaABAg',
#  'UgyiZ1dFaozdsUFrhUN4AaABAg',
#  'UgwVkM5hyK6PYdEjXKV4AaABAg',
#  'UgyxyDNT-fo0cPniSnN4AaABAg',
#  'Ugy93nuknShwxiQhJJt4AaABAg',
#  'UgwkO88AGBdtMACkGmN4AaABAg',
#  'UgySuyWULSHw84_CFAp4AaABAg',
#  'Ugw9yCULytsBUwifl0h4AaABAg',
#  'UgzWsS7E4aCyT7t4Dgd4AaABAg',
#  'UgxMYPF3aMxSLdo1Q7V4AaABAg',
#  'UgymyBEYu-Z0IdvExGh4AaABAg',
#  'UgzRXVPOUxRlzBgDJFN4AaABAg',
#  'UgwYZD452k2SkpdLJwF4AaABAg',
#  'UgxI4FHxOTK0wjiUpsB4AaABAg',
#  'UgwX9oNJ4fnevY3fDsR4AaABAg',
#  'UgzIy-QDApAD9klYhdZ4AaABAg',
#  'UgzXKksf2TW5E6hS6Vd4AaABAg',
#  'UgzSaQ2mbGlykN4jMkt4AaABAg',
#  'UgyL-NBXktG-h6XGrVp4AaABAg',
#  'UgyEXJEFWSAR4wXQVcF4AaABAg',
#  'UgzjXRTh2Ic-DO-K8xB4AaABAg',
#  'Ugzpz20GXymymbTJiZ94AaABAg',
#  'UgzyQ483ipFD1QaxXaB4AaABAg',
#  'UgylGKZ3YLZqoaDQwHp4AaABAg',
#  'UgyGT-j2AUDZ_jbtdnl4AaABAg',
#  'UgwJa_T87AxppSiAWKp4AaABAg',
#  'UgzWpIl51EHPb3wsxpN4AaABAg',
#  'UgzBTOJndlTuFWgRtbZ4AaABAg',
#  'Ugx71MTTINjWeUTpdM54AaABAg',
#  'UgwCgS87xtLoaWaImyx4AaABAg',
#  'Ugx2qve9epws4ouBLlh4AaABAg',
#  'UgwRph9CFU8i11xi35h4AaABAg',
#  'UgzQ7d6C40EPFONiJGt4AaABAg',
#  'UgwMsJQneJDzBTQ5iwB4AaABAg',
#  'Ugyf-HpU_BJ7RIt8Mg54AaABAg',
#  'UgysCqR_w_sMonEKFXR4AaABAg',
#  'UgxgGcU1DjfkMX7OXEZ4AaABAg',
#  'UgzqkGnGedpjCBFLu_d4AaABAg',
#  'UgwvpooyCTd4Cyy_SgN4AaABAg',
#  'UgyPEPBPPZ_ksu5PK0d4AaABAg',
#  'UgyIDZfTiu3kP9z9L_J4AaABAg',
#  'UgxhEwRPlWdBbKOfeC14AaABAg',
#  'UgydZV40NNzao8Q3Kz94AaABAg',
#  'UgxJl7t3bHyY0vaQFMt4AaABAg',
#  'UgxvFRJQhCASqlHIQCZ4AaABAg',
#  'Ugw8E6pSkJ9GzbxwSZt4AaABAg',
#  'Ugz9076nLv-xQradZUp4AaABAg',
#  'UgzQt5VEiiA5OzVypox4AaABAg',
#  'Ugxu3L35Hucp5zImu6Z4AaABAg',
#  'UgwvEVTQVhT7MxPj3rJ4AaABAg',
#  'UgyFWfhP6cXnHLBKzx14AaABAg',
#  'Ugw10yDEUhOIQurKqid4AaABAg',
#  'Ugzp_Hr2VMHJb40wCOR4AaABAg',
#  'Ugz6VF5HPErLAFSpZYt4AaABAg',
#  'UgwV12SrZ8AMIJ0Nt7J4AaABAg',
#  'UgyFRsADW0FI0NghKGF4AaABAg',
#  'Ugy32-FefJwZmoqcixJ4AaABAg',
#  'UgwKPF1vUwpevD_jIdt4AaABAg',
#  'UgzU6eQN7RMFTsBkO854AaABAg',
#  'UgzOdByAVPVk50h5jJJ4AaABAg',
#  'Ugz5sOrANeZPrtTXLmN4AaABAg',
#  'Ugya7Bif0J2uDqFIlux4AaABAg',
#  'Ugx2SC08yUuKhXKTVGR4AaABAg',
#  'UgweBWmQLg0p6UdNN2t4AaABAg',
#  'Ugy3e7IG-qb3XDWEMO54AaABAg',
#  'Ugz7EYsVRo07OsoFnCx4AaABAg',
#  'Ugwwky0U9rAIQ4Xv-Sx4AaABAg',
#  'Ugy3_mYdTq3hlDxl9KF4AaABAg',
#  'UgzEd2Y2E_T85Bqg7IN4AaABAg',
#  'Ugy-PMVCAClRDbHuQw94AaABAg',
#  'UgzxtOVBLzwXY5i6ACh4AaABAg',
#  'Ugx5ziMOuKD9CrLprcx4AaABAg',
#  'UgyGb7zTpcZxkccA1b14AaABAg',
#  'Ugxluvb0AC_gw_ujre14AaABAg',
#  'Ugwjuw6jfhVFlNuDCzB4AaABAg',
#  'UgxmBptbn3gV-jKgtbF4AaABAg',
#  'Ugyqb3Kq60pUUbkgI454AaABAg',
#  'Ugz4wFQ2EP-0_cmTx4B4AaABAg',
#  'UgwXhJCsVi7b_IO07AZ4AaABAg',
#  'Ugxy-_rPLK0U0L8LuF54AaABAg',
#  'UgzFIc4uQ39KvDEpL_14AaABAg',
#  'Ugw9B34t7xff6-4P8Od4AaABAg',
#  'UgyW44aqHf8AhmWYUh14AaABAg',
#  'UgxB4nuQE9MXDow0qip4AaABAg',
#  'UgxBWKd-548aJnx4d0R4AaABAg',
#  'UgzOfZzDV1YcXEZGDHR4AaABAg',
#  'Ugw14v_HVgePxI67kp14AaABAg',
#  'UgxpFzw-hTswiO4nKUZ4AaABAg',
#  'UgyHbOsMjulyPogOqzl4AaABAg',
#  'UgzkczWuJz50THzOCnh4AaABAg',
#  'Ugx0r7RwWaGYQZa5RNx4AaABAg',
#  'Ugy9lmeX8gOukb50gOR4AaABAg',
#  'UgwrgrAhSIYbdP35D3Z4AaABAg',
#  'UgyYqxJwUWeqfJOu1q94AaABAg',
#  'UgyWsNlL3wiEYHJC7ax4AaABAg',
#  'UgwgBADrJiWsD1oMZK54AaABAg',
#  'UgxvQ0-MtFnBSTNa-4Z4AaABAg',
#  'UgwjHHgaWcqqmrEtkzZ4AaABAg',
#  'UgyJ4xFqJO-KFl3DrBF4AaABAg',
#  'Ugx55JcTgcj--2ygIXV4AaABAg',
#  'Ugwb8mza6kXRgYmzfT14AaABAg',
#  'UgzSo73zcYZm1UJy9Cx4AaABAg',
#  'Ugy9YL96VnXmjc_Mdex4AaABAg',
#  'UgwJRbXCgAl96NbS_Rh4AaABAg',
#  'UgwWO5s4lFsWEcfyECB4AaABAg',
#  'Ugw_azKZH_6N37Cna9d4AaABAg',
#  'UgxREcWl_ediNcQAQPF4AaABAg',
#  'UgyoAyHeXUXji7Ue9NZ4AaABAg',
#  'UgzrxYDFntvXFY4XAa94AaABAg',
#  'UgzyAFKZjwYcv1Hb4zJ4AaABAg',
#  'UgxeA77w9e2bXub023d4AaABAg',
#  'UgzfvXLidwbOggxIV654AaABAg',
#  'UgwwwVDWu0F2Wm13fxd4AaABAg',
#  'UgyZUOC51FNrURaxU8Z4AaABAg',
#  'UgwvusbgyKKmvBEXX454AaABAg',
#  'UgzWd2fSXOMyv-BQvdt4AaABAg',
#  'Ugw8aVm_-nUPdfqlZ_Z4AaABAg',
#  'UgzVgPdLw-TkjuehZaB4AaABAg',
#  'Ugz486Ynv5w8xWsA8Dd4AaABAg',
#  'UgwuUZKP2atIBvL-pVB4AaABAg',
#  'UgxHci3qt78lJBM0vGJ4AaABAg',
#  'UgwvaAizi_VZ4syf5ZZ4AaABAg',
#  'UgwkBJ5AXHsVKeawbzV4AaABAg',
#  'Ugw3XT2WN_esKDbmZJl4AaABAg',
#  'UgzxCh2KU7dH-eNjMlR4AaABAg',
#  'UgyIxq7L0gKu1WTUKiZ4AaABAg',
#  'Ugx3JrNgDMhHKRW1sPN4AaABAg',
#  'Ugxuj51d2ZjkYEjGYz54AaABAg',
#  'UgxsQkIYjecIpAT4f2F4AaABAg',
#  ...]

# %%
len(lista_comentarios)
# Out:
# 128

# %%
for comentario in lista_comentarios:
    df_resposta_comentarios \
        .filter(df_resposta_comentarios.ID_COMENTARIO == comentario) \
        .write \
        .parquet(f'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_{comentario}.parquet')

# %%
spark.stop()

# %%
conn = hive.Connection(host='localhost', port=10000, username='rodrigo')

# %%
cursor = conn.cursor()
cursor.execute('USE youtube')
for chave,  comentario in enumerate(lista_comentarios):

    print(f'iteração {chave + 1} --- de {str(len(lista_comentarios) - 1)}')
    try:
        

        query = f'''
        LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_{comentario}.parquet'
        INTO TABLE resposta_comentarios_youtube
        '''
        print(query)
        
        cursor.execute(query)
    except:
        cursor.close()
        print(f'deu ruim em {chave + 1}')
        break

cursor.close()
# Out:
# iteração 1 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzjtG8FbUI4PSjDgcR4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 2 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyAygBP4Kagzw-BsRN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 3 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzqzEXFZeRzGP1vJoZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 4 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyJhCBeqvIRcNEoxxh4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 5 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwFgHQkWlDlA3sLFih4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 6 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwSRK_MaZP50f6aR8V4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 7 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyGN7EJFMJIGALL3uZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 8 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgysLWomkRBgycwEh4h4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 9 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzO0izK_075lBI6Tht4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 10 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwpWB7x2I0GbZa-2UR4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 11 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyzwNWRIzCMRmwpq7J4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 12 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwSPDUA5_cH8KWNeJJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 13 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugx4913uDBuip0pUJpl4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 14 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgymIasxqwNFSUjv7RZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 15 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugyn9QPEUFRhCqJGB8h4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 16 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzFezA0NrM0DZClCot4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 17 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxXgWLksXhddT8xijl4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 18 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz6Lh1IxEyBJrYZeL14AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 19 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyRSE9vvhbEpQarJv54AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 20 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz6khMdz9YrKVuPzoB4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 21 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzHt3fHKL1Q8XTYA6Z4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 22 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugy0TCJeuMP4ZYhjrLx4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 23 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyFlNjY9y9WCdHG5nx4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 24 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwR2k1v4CBgPHJVk5R4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 25 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugw3HdsDNDMQt74QF394AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 26 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxJh_42tlc8oblQVYx4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 27 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugy1qzQk5dkEzQOSUUl4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 28 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxfxfzA68wQy7IX7Nt4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 29 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugxc6l-cggcM8rfEu554AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 30 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxfSuM-BvKNfHj_22V4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 31 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugxd1H-6iumroOfI6p54AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 32 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugwj4srswzwMwsM77Hp4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 33 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxXoRieCkrK-gJ5tQd4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 34 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwxLIgYShzoymlziL54AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 35 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugy7wYt-WzUbXWUX20x4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 36 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugws_ZumJrZMh-iVlMB4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 37 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyRxMkksC1YPoHPHAJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 38 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxHdhcW6Y1Fp2KhMNp4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 39 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxvJjndxMCws4J5uMh4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 40 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxR1_KxWLJ1oCKqIn94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 41 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyL1gllk_FUl906IQV4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 42 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgylYVYgBa0K05bWPNx4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 43 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwemzC1_iNiVxgSn6J4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 44 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxqKg7do2O2t1SatU94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 45 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgykLTHQNvQkB9ZN85p4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 46 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzcMSMjs3Oyym5Y7194AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 47 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz61cPStg5DIxvmTGx4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 48 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwG2Z6q8Fb9eNviEBd4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 49 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugxc9hrY5wwCGNyDLR14AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 50 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgywHj11NM5M74rCpJp4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 51 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxdyVex8HinQdQ7QyZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 52 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugx5KX2nZFPGlOMfOSJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 53 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzmQf8oYGDtA6EhuRV4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 54 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugyih3bSiywQub6ppuF4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 55 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwijNBY9ICHHe3Z8_t4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 56 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzlwF0si1Htbcotxbp4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 57 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzLKocVFGR7fDgcdxd4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 58 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzPkk3qw5BPxgMt9t94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 59 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzM51oaOTmYTQJ4B854AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 60 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxKPSmr3uSlDcmXv6p4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 61 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxZLOFUWSb5tbcz38J4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 62 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugyc3nJfN2VNt9QFyQR4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 63 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxPMVS4QYIQcLEd5fN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 64 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwlQl-acLQEdNP8fC14AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 65 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugwd1jErCx9m6X4Nrzx4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 66 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyPs962f_gbhdZMLyN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 67 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwJPWxNkXPaYPxPmyJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 68 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyKdGMvHdJfpL5jUV14AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 69 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwVUlKnbQhJS6Vx2UR4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 70 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwKL4pj9hbYeA46Grx4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 71 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzwizlpV0KjRZBbWyV4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 72 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyvyTOlV06Xmel5rbN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 73 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwickGe_2Pi-ZtYwIF4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 74 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxiTBr7T0Yd9U887fh4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 75 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwL3ANOEuxD9HupTjx4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 76 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwZdO1TVSd-wgKKk394AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 77 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugw6sBAWtYMDfAUFjeJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 78 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwFHg9pkUxlKE0Vx454AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 79 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwcscFXDbaQoFbYcNN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 80 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwAwIfRzg6gK1EIVCd4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 81 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxfYmWHqBxH16WXm4p4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 82 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyYpSSPRS042KFlau94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 83 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwQVrCdzHaCUcoWIsZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 84 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugyl431QFsj2KalrgAt4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 85 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwYuVfYfmqGDUlP-lJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 86 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugy4NROACu15ZHZ-VNh4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 87 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugwo1V78z5Cnu7CApXZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 88 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxMdyNx9OaRXaklNkt4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 89 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwouuUFkdLt2dChQIx4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 90 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzoXf2oCAfbECeB9054AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 91 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgypQMMnJuixHAWL1JN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 92 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwWA8EYB9d18wQ7hfd4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 93 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwZ5t_gghdsK6XeeQN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 94 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugwkgvk1DIUIhfVxqb54AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 95 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz_Q9B-Ch1IjkJJ1iF4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 96 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgykKoDSnkdjnHFcOBJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 97 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz5RkTTobiAB7A5GGd4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 98 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxHfYBPLoPJCKOZeoZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 99 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxClu1h1wC4Stvhk094AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 100 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugx1-gzck_0GfYHpT0x4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 101 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwIxI3x7YMHdyBUzuN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 102 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyOHQ5Q2zx1cz6IOcJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 103 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugzf1BJgluqBGWrH7ft4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 104 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwF3gdrQNzjPO5ZI4J4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 105 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyzYeWoosMm9D845it4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 106 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwUZpoCNxDDnGqle0Z4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 107 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzhymE0036a5duvGxx4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 108 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzM82qP8m5SOG6vtyt4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 109 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugwxy5KLNhTRQtQzwy94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 110 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugx-oAnP8izbWG97UIl4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 111 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxErdI6AaDyXuED-0d4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 112 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugx63ICjpAFVzVcVv1N4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 113 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz3R87c8g6FpDvfEMl4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 114 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxJf7fAx9_YcELcSBh4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 115 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzqDc8MR3YL-tiAulV4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 116 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz8Stav6u4uISTwxEJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 117 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzIMi9Z5qkxdM6gbc94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 118 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwQ1-zhGuNZMqi6max4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 119 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzG_7WV6_SRO_xlxs94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 120 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugx0sGQbMj6b8jP6fI14AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 121 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzBe77r7b5SGDJhkm54AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 122 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz37aaTklYsxqaQjR14AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 123 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyJe2MUKuz9lAmvIxV4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 124 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugzmz2n6guVebS2VWtR4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 125 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwLEzblCYhyrSZY46F4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 126 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugy3mvOmhflP0gcIXGd4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 127 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwpfqPZKTQFKjFflkZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 128 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzKfH-jzu_bzCvVT5J4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 129 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugyke45h7jX1gEY9Usp4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 130 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxDb24SXDyxTRFmwvV4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 131 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxKK_kz70ob_P5DMr14AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 132 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzjfSr_b1mn4gAsFAd4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 133 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugzmp_6tp2DAzxVHXFV4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 134 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwIwmPSXfo3Lunvik94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 135 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugy6oqcqeq6MMnsxpyB4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 136 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxKWbhOdwuzEiydCRN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 137 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzmYbtNH41mkcFbtR54AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 138 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugyr1iDkDWQdIfRRiHh4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 139 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugxru9Ibnn5H0EgrPC94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 140 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyyRQ1JtKRTVbxUpEx4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 141 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugzdvv_RJSmgvLcqxYR4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 142 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzIBG5f7svyiKnKb0Z4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 143 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzXe5rJxXeVtkTiLDF4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 144 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwBhgQpxrmPbxsVaGN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 145 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxwZDuNONTFBZqjfCp4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 146 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzyMapZPoJeMvGQtm54AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 147 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz0hRRRILcz1IfgTsp4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 148 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgysqO0fznEfRgcL8nJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 149 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxMVsPY5bcdwLNmh_B4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 150 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyzP42r2goyAmmEL2d4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 151 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzOREOHrur13F8hz-R4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 152 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugzjpfcqpkt6A3NpT8J4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 153 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxZwi9c8arAWmMXUol4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 154 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwsolFxkM_Atqem2SJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 155 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwjTYtohUgZJeOUpdN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 156 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugw5y-c2afPE2ol4y_14AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 157 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugw9sBiYMzBeZSyS7Ul4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 158 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz3fPOBeTeBFmvLNxl4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 159 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz245-GzoLCPcuf39d4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 160 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxzOnl5-IWaX4QilPN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 161 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwKbhMnClNfgb_I9xB4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 162 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxTL7Cr-Mz8QJfHMlt4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 163 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwM5X1_RKCBh_ZNxTB4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 164 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugy2GIBxAQPUjxGJrkt4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 165 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgybYifXVrUpnu48Swp4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 166 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwhLBhnT80P4LsTSxh4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 167 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzTQBBM8cNfVCQZ98p4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 168 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyyCCSTmCm9-Gs0SkR4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 169 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugy3Vihnrj0gq0JUUax4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 170 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugyv2VB5OF9eWadu-WR4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 171 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugw6ApmqHSnHEmlDrK14AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 172 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzbaiXvf2_MISUDcHp4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 173 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxGxvuG6LVHLdAjSlh4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 174 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzblVG7Vv9eaW9drRl4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 175 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxryhaL67Xx5eaGixd4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 176 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugxe1T1GjJl-ZptSRAV4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 177 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugwi1oI0dV2GqIhn0C54AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 178 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyfCP3twoOPgx2--BZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 179 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwAhMNcynWuKlE4Se94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 180 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxxkcLt3iBANaHCEVx4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 181 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxHVJtWCfauIuFO6hx4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 182 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz0sYRCCgi2KKRTwuR4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 183 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugy5s2yUgecYdQXMEZJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 184 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzCgPGrN8CSSK_ySyl4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 185 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyN7bJDvvmCYNA3Ngt4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 186 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzZs44iBIlXkUtv_c94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 187 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxMnYH4aeHhxl_wLnV4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 188 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxJyPxcGsSLnLRVaj14AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 189 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugws0GPwiRnGXexDN0p4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 190 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwsaJYOpgQS_2ei3Xp4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 191 --- de 1354
#
# ...
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 314 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxSr7iapCz6SRPrDZV4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 315 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugxp0i1Ndy2RalAh84J4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 316 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzcrNMlkLqcCp-_ViJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 317 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzXfMQnBVxvzAsgSnR4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 318 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzRM-Y2uETIzvFcQcF4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 319 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzM2m_teNtjjM3nfyd4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 320 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwQy9oBrD5hlRBkhOB4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 321 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugx9OA1RxWUImxSWu9N4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 322 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugyk8DFOwt54sTOPAUN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 323 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugx5WKNYSEzHTStmADN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 324 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwpixyLPylvMgOJobh4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 325 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyLcZQQ-UXT8opnnUp4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 326 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz81MTzOpt5mg5khCh4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 327 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzTfWjaqzvXv7oVmep4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 328 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugw4BeNFhyeI9XSexCh4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 329 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz7wU_D6xstyPvKxfZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 330 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwQwus7UFE2C6EFMw94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 331 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzkMJB3TX7AMNoaFLh4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 332 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzulC9Ndj8Fbd6e2FR4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 333 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzLj8QmN_o6mWkX3Ql4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 334 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzGx2HeiplvHIoDdgV4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 335 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgySqkZ2bLiN8NuOu6p4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 336 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugym_sa8pUTXqFHl6Ut4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 337 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz0Nc0cc-H7nm32yjN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 338 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugzqe4rUOre3lyzZ26p4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 339 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzY_Y6_YWQ466PLg-l4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 340 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwC19tDp6A2pSbMlHV4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 341 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwMbMbOehOWQbtN2V94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 342 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxxGteDI7X8c0ckTRR4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 343 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugx3uHawZyz8EqUxbSN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 344 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugy3NMIhV4zkd7KgvAl4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 345 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugw-AOQ6Kh-Qof2U9bd4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 346 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxAgwYSf8ukj4NSSqZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 347 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugw9JmxVbbGDBFQX_pF4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 348 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzkapVLh03SI50Sp694AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 349 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugx0ELGM0N1LEXuqQPZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 350 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwI9VN0j_psAct1aUZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 351 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxViabiONesdn7jp354AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 352 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxLOUCbBhD4HL3sa-l4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 353 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz6x97-w32hVQYmeOV4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 354 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyyrGqpoYL1ybZ6vL14AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 355 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugyj6qKsjjQS7bRLNtF4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 356 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxeSmbYx6xVIW9d1AF4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 357 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzKr3_2fr1aNgyWCBJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 358 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugx6KSm0RejmWPRJXfp4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 359 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwuC5x2t6oiub2men14AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 360 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_Ugz1l5I7zU5_eoNmdjN4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 361 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxKqf3sJZWLDkNoRSh4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 362 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxqX6srqJek4DldWnZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 363 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgyRm3_wTKUiCSMP2OB4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 364 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxSJqfQGaS7WrgtUxJ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 365 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzektWeMdeathsWBl94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 366 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwxvnUYgERFDOZOxLZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 367 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzRO66jPo6UpGz_rq94AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 368 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgypBgOLvpyzVVKRNTd4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 369 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgySWx2wsESOlb4NLRZ4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 370 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxFbmqSiajdf4B-N314AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 371 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxuPSfWYLD9j-LubLB4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 372 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgxSczE8xySl4Sa3hA14AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 373 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwlDPwGMMBDO3X353t4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 374 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwmSTPe_-10KJxy3H54AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 375 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgzHUfVn1XLF9KkQ7Gd4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube
#
# iteração 376 --- de 1354
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/resposta_comentarios/resposta_comentarios_UgwRsHBAgejzwyD767N4AaABAg.parquet'
#         INTO TABLE resposta_comentarios_youtube

# %%
print('oi')

# %% [markdown]
#  - Trends

# %%
spark = SparkSession.builder.appName('CARGA').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.112:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>CARGA</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_trends = spark.read.parquet('/home/rodrigo/Documentos/projetos/open_weather_api_apache/analise_dados_youtube/data/projetos_youtube_v2/ouro/trends_brazil/trends_brazil/trends_brazil.parquet')

# %%
df_trends.show()
# Out:
# [Stage 32:>                                                         (0 + 1) / 1]
# +-------------------------+-------------------------+-------------------+---------------+-----------------+-----------+-----------------------+-------------------+---------------------+---------------+-------------+------------+--------------------+-----------+
# |                 NM_CANAL|             TITULO_VIDEO|TOTAL_VISUALIZACOES|TOTAL_FAVORITOS|TOTAL_COMENTARIOS|TOTAL_LIKES|TOTAL_VISUALIZACOES_DIA|TOTAL_FAVORITOS_DIA|TOTAL_COMENTARIOS_DIA|TOTAL_LIKES_DIA|data_extracao|ID_CATEGORIA|            ID_CANAL|   ID_VIDEO|
# +-------------------------+-------------------------+-------------------+---------------+-----------------+-----------+-----------------------+-------------------+---------------------+---------------+-------------+------------+--------------------+-----------+
# |     Melhor Futebol do...|     REAL SOCIEDAD VEN...|             124186|              0|              163|       4569|                   3115|                  0|                    7|            112|   2023-10-26|          17|UCiQ7Ll2Gsb5eQhgQ...|j4TlIePiewE|
# |     Melhor Futebol do...|     REAL SOCIEDAD VEN...|             121071|              0|              156|       4457|                 121071|                  0|                  156|           4457|   2023-10-25|          17|UCiQ7Ll2Gsb5eQhgQ...|j4TlIePiewE|
# |     Melhor Futebol do...|     REAL SOCIEDAD VEN...|             125404|              0|              164|       4620|                   1218|                  0|                    1|             51|   2023-10-27|          17|UCiQ7Ll2Gsb5eQhgQ...|j4TlIePiewE|
# |(G)I-DLE (여자)아이들 ...|(여자)아이들((G)I-DLE)...|            8627209|              0|            19048|     476803|                8627209|                  0|                19048|         476803|   2023-10-15|          10|UCritGVo7pLJLUS8w...|Iewisp9KYRw|
# |     Cortes do Casimit...|     CASIMIRO REAGE: U...|             736472|              0|             3084|      52139|                   2575|                  0|                   10|            131|   2023-10-25|          24|UC4aiJNDUviw_vMhd...|MHQXhXJdQB4|
# |     Cortes do Casimit...|     CASIMIRO REAGE: U...|             686166|              0|             2963|      49394|                  38432|                  0|                  115|           1970|   2023-10-20|          24|UC4aiJNDUviw_vMhd...|MHQXhXJdQB4|
# |     Cortes do Casimit...|     CASIMIRO REAGE: U...|             647734|              0|             2848|      47424|                 647734|                  0|                 2848|          47424|   2023-10-19|          24|UC4aiJNDUviw_vMhd...|MHQXhXJdQB4|
# |     Cortes do Casimit...|     CASIMIRO REAGE: U...|             709132|              0|             3031|      50729|                  22966|                  0|                   68|           1335|   2023-10-21|          24|UC4aiJNDUviw_vMhd...|MHQXhXJdQB4|
# |     Cortes do Casimit...|     CASIMIRO REAGE: U...|             720502|              0|             3059|      51320|                  11370|                  0|                   28|            591|   2023-10-22|          24|UC4aiJNDUviw_vMhd...|MHQXhXJdQB4|
# |     Cortes do Casimit...|     CASIMIRO REAGE: U...|             733897|              0|             3074|      52008|                   4030|                  0|                    1|            205|   2023-10-24|          24|UC4aiJNDUviw_vMhd...|MHQXhXJdQB4|
# |     Cortes do Casimit...|     CASIMIRO REAGE: U...|             729867|              0|             3073|      51803|                   9365|                  0|                   14|            483|   2023-10-23|          24|UC4aiJNDUviw_vMhd...|MHQXhXJdQB4|
# |     Vem a mim língua ...|     Cheguei em Moscou...|             692101|              0|             7044|      70564|                  37272|                  0|                  161|           2874|   2023-10-26|          19|UCX8pfKRW496XSHsU...|05yeNSE8jDc|
# |     Vem a mim língua ...|     Cheguei em Moscou...|             605469|              0|             6582|      63706|                  62974|                  0|                  349|           4275|   2023-10-24|          19|UCX8pfKRW496XSHsU...|05yeNSE8jDc|
# |     Vem a mim língua ...|     Cheguei em Moscou...|             542495|              0|             6233|      59431|                  69374|                  0|                  446|           4671|   2023-10-23|          19|UCX8pfKRW496XSHsU...|05yeNSE8jDc|
# |     Vem a mim língua ...|     Cheguei em Moscou...|             654829|              0|             6883|      67690|                  49360|                  0|                  301|           3984|   2023-10-25|          19|UCX8pfKRW496XSHsU...|05yeNSE8jDc|
# |     Vem a mim língua ...|     Cheguei em Moscou...|             718524|              0|             7167|      72471|                  26423|                  0|                  123|           1907|   2023-10-27|          19|UCX8pfKRW496XSHsU...|05yeNSE8jDc|
# |     CANAL DO NILSON C...|     NILSON CESAR DETO...|              89034|              0|              811|       4342|                   1102|                  0|                    8|             15|   2023-10-20|          17|UC407XQEh4grFPh-F...|1EEZtNFDU8Q|
# |     CANAL DO NILSON C...|     NILSON CESAR DETO...|              92245|              0|              813|       4485|                    509|                  0|                  813|             24|   2023-10-24|          17|UC407XQEh4grFPh-F...|1EEZtNFDU8Q|
# |     CANAL DO NILSON C...|     NILSON CESAR DETO...|              92541|              0|              813|       4500|                    296|                  0|                  813|             15|   2023-10-25|          17|UC407XQEh4grFPh-F...|1EEZtNFDU8Q|
# |     CANAL DO NILSON C...|     NILSON CESAR DETO...|              87932|              0|              803|       4327|                  87932|                  0|                  803|           4327|   2023-10-19|          17|UC407XQEh4grFPh-F...|1EEZtNFDU8Q|
# +-------------------------+-------------------------+-------------------+---------------+-----------------+-----------+-----------------------+-------------------+---------------------+---------------+-------------+------------+--------------------+-----------+
# only showing top 20 rows

# %%
df_trends.printSchema()
# Out:
# root
#  |-- NM_CANAL: string (nullable = true)
#  |-- TITULO_VIDEO: string (nullable = true)
#  |-- TOTAL_VISUALIZACOES: integer (nullable = true)
#  |-- TOTAL_FAVORITOS: string (nullable = true)
#  |-- TOTAL_COMENTARIOS: string (nullable = true)
#  |-- TOTAL_LIKES: string (nullable = true)
#  |-- TOTAL_VISUALIZACOES_DIA: integer (nullable = true)
#  |-- TOTAL_FAVORITOS_DIA: integer (nullable = true)
#  |-- TOTAL_COMENTARIOS_DIA: integer (nullable = true)
#  |-- TOTAL_LIKES_DIA: integer (nullable = true)
#  |-- data_extracao: date (nullable = true)
#  |-- ID_CATEGORIA: integer (nullable = true)
#  |-- ID_CANAL: string (nullable = true)
#  |-- ID_VIDEO: string (nullable = true)

# %%
df_trends.groupBy('ID_CANAL').count().orderBy('count', ascending=False).show()
# Out:
# [Stage 32:=================================================>      (71 + 9) / 80]
# +--------------------+-----+
# |            ID_CANAL|count|
# +--------------------+-----+
# |UCgCKagVhzGnZcuP9...|   39|
# |UC2bYhAHyaqfWlPXW...|   39|
# |UC2EWGw-KBjEReUbX...|   38|
# |UCw4YGFtvDgOL09Kr...|   36|
# |UCw5-xj3AKqEizC7M...|   35|
# |UC_oToDrJ6uca7d1d...|   35|
# |UCV306eHqgo0LvBf3...|   34|
# |UCIXguhHCl8eDTkXp...|   31|
# |UC63iwP6BtIjxB6xn...|   29|
# |UCv-Nx8pSfG_LxbVi...|   28|
# |UCZiYbVptd3PVPf4f...|   28|
# |UC3KHYFWeB0WimMBf...|   23|
# |UCTNFtLQWA94BNeu0...|   22|
# |UCEWHPFNilsT0IfQf...|   21|
# |UC2AcGGX4MHhKJihe...|   21|
# |UCAI8SmRbXgSpP8Zo...|   20|
# |UCWKtHaeXVzUscYGc...|   19|
# |UCaGmdJSSiR7fkh2A...|   18|
# |UCboK4EZXs0YRg_YV...|   18|
# |UCFZsvdD_Sb98qFdt...|   16|
# +--------------------+-----+
# only showing top 20 rows

# %%
lista_id_canais = [ linha['ID_CANAL'] for linha in df_trends.select('ID_CANAL').distinct().collect()]

# %%
# for canal in lista_id_canais:
#     df_trends \
#         .filter(df_trends.ID_CANAL == canal) \
#         .write \
#         .parquet(f'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_{canal}.parquet')

# %%
spark.stop()

# %%
conn = hive.Connection(host='localhost', port=10000, username='rodrigo')

# %%
cursor = conn.cursor()
cursor.execute('USE youtube')
for chave,  canal in enumerate(lista_id_canais):

    print(f'iteração {chave + 1} --- de {str(len(lista_id_canais) - 1)}')
    try:
        

        query = f'''
        LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_{canal}.parquet'
        INTO TABLE trends_youtube
        '''
        print(query)
        
        cursor.execute(query)
    except:
        cursor.close()
        print(f'deu ruim em {chave + 1}')
        break

cursor.close()
# Out:
# iteração 1 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCritGVo7pLJLUS8wEu32vow.parquet'
#         INTO TABLE trends_youtube
#
# iteração 2 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCiQ7Ll2Gsb5eQhgQQhZ2lGQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 3 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCX8pfKRW496XSHsUyXgDXDA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 4 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC407XQEh4grFPh-FYCWEKUw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 5 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC4aiJNDUviw_vMhdCq5Kq1Q.parquet'
#         INTO TABLE trends_youtube
#
# iteração 6 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCJ-_JtS_-0G7pt6C7kkLJ3g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 7 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCIv5-lGsVuW3JKPGQEMVXrg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 8 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCAAPXtnzlg9krw6MtNbfR-g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 9 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCv-Nx8pSfG_LxbViMz14RWQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 10 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCTNFtLQWA94BNeu0lE4YwuQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 11 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCgLuBHpgnAXKKq3uQfjXfSA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 12 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCLhgIX2L5ZCaWdlaxR_oTAg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 13 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCs-6sCz2LJm1PrWQN4ErsPw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 14 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCc0cU92Tf7rvd2gr-CpVO4Q.parquet'
#         INTO TABLE trends_youtube
#
# iteração 15 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCP_WlkTCG-e4ULEA0gTsg2g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 16 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC3d7Ix6GrtxESULE5Auj_Zg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 17 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC0LlPl_mWhIFqVxcH1l3xpQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 18 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCyJ-fWKmF40BQ1FNMMhTPxQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 19 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCEWOoncsrmirqnFqxer9lmA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 20 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC2EWGw-KBjEReUbXMJEiaCA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 21 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCjlcZ5YIXlBTaob0BkS_gDg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 22 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCpNmFOSrkfqsmc37_UrCbZA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 23 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCmF5w6pmvYfnMOqjQowgraA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 24 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCw5-xj3AKqEizC7MvHaIPqA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 25 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCy7aeNy60EVhMwBziYsET-A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 26 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC3nU0d4kEhtljMLh2entwrw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 27 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCqifkpdmE1z3VhfQoJzwpJQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 28 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCriRvZSnEFPSMqSya2s2U6g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 29 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC2t5bjwHdUX4vM2g8TRDq5g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 30 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCIpylxq_JDl2YpvTpN11p9Q.parquet'
#         INTO TABLE trends_youtube
#
# iteração 31 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCGBIIPnw0AYM3BFsmTsjeAw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 32 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCn-0dkyNA4pPMrBfuBozAyA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 33 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCCqgWX3afPoiYKa965Z8jMw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 34 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC3KHYFWeB0WimMBfm3NEahQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 35 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCDX3MD1sjB_OKAoWMfSfMmw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 36 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCv-QXC04JCxklAUQQe9vCuQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 37 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCIXguhHCl8eDTkXpEuiGPUA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 38 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCLT-2H1NUV3pEwuM_zL7LhA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 39 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCZiYbVptd3PVPf4f6eR6UaQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 40 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCUlLpAC2QoQ5UsU08mPXVUQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 41 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCD1Em4q90ZUK2R5HKesszJg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 42 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCZaOZdn-Y-I5ikrofkWBLgQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 43 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC-bOPhs_XA5bETT3G37WF8A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 44 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCP391YRAjSOdM_bwievgaZA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 45 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCADFFCsD8JQBa9RQmyisjpA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 46 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCevaIHgjRXaYX3S6uQY8rig.parquet'
#         INTO TABLE trends_youtube
#
# iteração 47 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCsuHTmaYOim2oHxjyEf4nAg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 48 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCCwyP8AJzBEwYpq-y4pSjow.parquet'
#         INTO TABLE trends_youtube
#
# iteração 49 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCaZY_c71TTugtIMKGlPtsmg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 50 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCVrx8gt9oAHPbOjA-EjFblw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 51 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCJLtfES4K2aYCLFz-i5teFA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 52 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCG-fFAxQjZgJmn0w7Brj5xQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 53 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCjhrZMxlOEqhM6KV3is2a-A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 54 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCANLZYMidaCbLQFWXBC95Jg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 55 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCngRsuvI1zxHR9vwNZvpTAw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 56 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCOEm1yr1ZE_DZ5elhTiDhvA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 57 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCezhRry1J2kNRNCdNDHimNA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 58 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCxUNQ-7UbT5SRrDnknAon9g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 59 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCBFcL3nMWFcNnoWOEtacp1w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 60 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCFYMZ4wMKUP-qqW48JtTkiQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 61 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCHUhlZy-CbS0-YvPQ5yBRIQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 62 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCAnCxJ1Weh2pUAKJW0bro0Q.parquet'
#         INTO TABLE trends_youtube
#
# iteração 63 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCiQotbmKsXF1n3xp3MYvoiw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 64 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCrpLBn22arVETOO5alUbW7A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 65 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCmWyesNAlftV3kJlFhD6q6w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 66 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC0GUaQ6lVzvu0FWklbsKFhg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 67 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCFZsvdD_Sb98qFdtSU7Et2Q.parquet'
#         INTO TABLE trends_youtube
#
# iteração 68 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC_oToDrJ6uca7d1dFVBmLtg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 69 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCr0aVp0-APOWTZ2RUzVnCuw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 70 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC4SkxWmVRnERdmdl16SFcCQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 71 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCPIqRikiL3q7aebEu_CBsfg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 72 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCdkhkda5VQPbKSzx03HohMw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 73 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCF5WzS-iBJRfp_EcFI-GT1w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 74 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCK0oFT3Lk0kVB9rnjU4nTYg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 75 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCthbIFAxbXTTQEC7EcQvP1Q.parquet'
#         INTO TABLE trends_youtube
#
# iteração 76 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCBb1-xvHcXUuH3ysuiL3Xyw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 77 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCaGmdJSSiR7fkh2A-c6emsA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 78 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC-6xqzMBF2CXTImn_a4aCVg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 79 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCN-opsqqDunWO6h5uCp9Y4g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 80 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCAkZ7bimIU9m7wT6Th0FcEw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 81 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC376n347Ob5Lwzq2WGzF1AA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 82 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC0Yx7ZU62c3u_hyM0jVMwGg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 83 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCAI8SmRbXgSpP8Zo3xZbxzQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 84 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC9eXFedzizQtlY5snZ-IFkg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 85 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCamgdcs45ToPrIV7wmT7iYg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 86 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCmofVw_WgKPDy3pEiXLskug.parquet'
#         INTO TABLE trends_youtube
#
# iteração 87 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC6IV24QPvsASJbzqDbmK8gw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 88 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCXUf_NoRtZcarN82SXbJAdQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 89 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCsiCOcr5SZAWlJMfcw9P__w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 90 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCgCKagVhzGnZcuP9bSMgMCg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 91 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCPX0gLduKAfgr-HJENa7CFw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 92 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCKAdZfnAhMY9RFSD4qL4KCQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 93 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCaf4uhI8ItLyM_6kZ5I5Zdw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 94 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCvdwhh_fDyWccR42-rReZLw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 95 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCrOH1V-FyMunBIMrKL0y0xQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 96 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC2bYhAHyaqfWlPXWBVk4BcA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 97 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCw4YGFtvDgOL09KrFpqj6kg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 98 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCoa-D_VfMkFrCYodrOC9-mA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 99 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCLoL96fSeaLOen3mpDYeqtA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 100 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCH6WyZxB-SMr8hRnawJBOrQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 101 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UClG7ik2BxqqYCJaFc9xlM8w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 102 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCd7VVhgnd2eCv9JEghvR_1w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 103 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCP-Vg2PcmLiWpEdvMI1R35w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 104 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCglAoXBdPAMUxvMlqhUnJsQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 105 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCuiw7EoVUMbIS-zbNW5uZAQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 106 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCYDZsRrVuSdf3HCfpAokjGA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 107 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCQ-YGnapg8TJ9d3ePKWIN8Q.parquet'
#         INTO TABLE trends_youtube
#
# iteração 108 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCiS882YPwZt1NfaM0gR0D9Q.parquet'
#         INTO TABLE trends_youtube
#
# iteração 109 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCqNSlyRZyMjVBHJ_Iqr5VGg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 110 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCdaaMVXWVQXGt97oh7fadIw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 111 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCqPbkJrjrsQb_RGlC_4HEgg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 112 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC-yA8YhrAgpFp4aVHRaNyMA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 113 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCmBA_wu8xGg1OfOkfW13Q0Q.parquet'
#         INTO TABLE trends_youtube
#
# iteração 114 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCuNjvqjTzw9LcD9PVpTVWRA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 115 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC48mLXk1ASg1EQbaS3MheWQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 116 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCDiQ-LZ8dfc3cmoGBxMDS7Q.parquet'
#         INTO TABLE trends_youtube
#
# iteração 117 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCPWqL6OWIZNO-dVm5euF-ng.parquet'
#         INTO TABLE trends_youtube
#
# iteração 118 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCEPRQVF6hxGGM9gi1ELaWHg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 119 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCrm0LFyOM03IZrpb0cFo_GQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 120 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC0uRT_armQXqds_rjTjqJ0g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 121 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCWKtHaeXVzUscYGcm0hEunw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 122 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCEOGSdXwcXcNfcuDGbjmgOw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 123 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCXFqI7y1ks-aTA4cffywiVQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 124 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UClpsCjjjkZiVrCpXsb9R0fg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 125 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC5-aueB1RqpUc-EeAjtx9Lw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 126 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCaZLOsun_sY6BonjwR8Zo4A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 127 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCiIZY89KwQkxAW-4Le7U7zg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 128 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCDVS7-YYxiQ62r46KXmp-kw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 129 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCooVYzDxdwTtGYAkcPmOgOw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 130 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC7hi0V23j2OZtLNzHKXb4KQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 131 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCqECaJ8Gagnn7YCbPEzWH6g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 132 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCcdTweO6MT_aXamxdp4kH7A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 133 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCLocu7ZcbxGvSr0z24vmq4A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 134 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCuVIWETFdxzwlHEHMbhm2_w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 135 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCebRa_3r9QtaTNpKvpTQ8Nw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 136 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC9zqTTVeClpqMQ5CLuJdWtw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 137 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCjBp_7RuDBUYbd1LegWEJ8g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 138 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCFxjZDrLCOCHkUCu632AmMQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 139 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCV5UiFF5AlNKW4sLXcYMG_g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 140 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCOa-WaNwQaoyFHLCDk7qKIw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 141 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCuiLR4p6wQ3xLEm15pEn1Xw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 142 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCH2958aySlHIuMzpUE8Xe9A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 143 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCgpfg0lMsq_E7KjDG62YFTA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 144 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCUouM5ZRqZoFNzUvpDeYNGQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 145 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCYcClChNM-0rjqCGobSfJ4A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 146 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCV306eHqgo0LvBf3Mh36AHg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 147 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCmrCKY8VWRxz8QLovVmgTKg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 148 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC00DIzrNfhYeXh9Z01fk_9w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 149 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCvuJTWl_peL49CUfF2EAbyg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 150 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCRD1ypvmK7e_05Rtu9zHOfQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 151 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCf2WBemooP2gBBx3lrraNQw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 152 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCm1dsgJNnhaLkY3uAdqN4mA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 153 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCVxnZCA6ibfIEDXCrBr5m5g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 154 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCu7O9lAbeZp3WW96Lf5Xk7g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 155 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCSS13SwFDxkiC6Yz-tF11UA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 156 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCfLTxnQboSLcoSakgONmukQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 157 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCANI7Bc9luucnZfQbAO2iLg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 158 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCQSDP7H4BINtrZ0bJc_FNIA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 159 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCiP3MvJ1pWayTBQ5YkgwDew.parquet'
#         INTO TABLE trends_youtube
#
# iteração 160 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCauE-yGwb8bJ55BswgrGxAg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 161 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC2AcGGX4MHhKJihegueWyqQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 162 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCBi24ZUXnSzpDJOPQS4djsQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 163 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCboK4EZXs0YRg_YVASzO-vg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 164 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCGV72aVJuWP0QPNGH4YgIww.parquet'
#         INTO TABLE trends_youtube
#
# iteração 165 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCqC_GY2ZiENFz2pwL0cSfAw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 166 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCJuJ-koqw44a0wNUE3w9bTQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 167 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCVgBrXR9eLnuIftnOGuRu3g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 168 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCEOMB0FexwjN4ViZTZLFrkQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 169 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCEUzhqtu0dAS79dtu8m5AUg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 170 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCqjDN62GwDsdNt8R-FFJjqQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 171 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCEIi7zFR_wE23jFncVtd6-A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 172 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCXBY-tNwbGkF5P__nN5IRbg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 173 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC6i4mzH3OPrZV0p64zoz-Ww.parquet'
#         INTO TABLE trends_youtube
#
# iteração 174 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCEAyAWDPVDQoi6gAz7a1NHg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 175 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCcYrdFJF7hmPXRNaWdrko4w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 176 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCjTVNkbx5megxlnl1spy2jg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 177 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCO9LPWL-UtupgPug7Ad6nSA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 178 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCaO6TYtlC8U5ttz62hTrZgg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 179 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCmpHPgeCBgvk_fDXZQKsnAA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 180 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCbTAwyq6nWOLnFag-PR0XVw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 181 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCEf_Bc-KVd7onSeifS3py9g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 182 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UChEmvd47U5S-lCbZvUjzGcA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 183 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCBKc-rPDivvwFiWdG-81wxw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 184 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC2yJDeDFcv1cAHA0BgfJ9ww.parquet'
#         INTO TABLE trends_youtube
#
# iteração 185 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCGH4Wx-WL10iB4ZAdewkuDw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 186 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCm4aitnUJK8t6CT5mesAcdw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 187 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCiF6IBAtpD_-QJ9mmPD4wQA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 188 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCpOdPfjjxpEAzATZJQX4_Hg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 189 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCOuITB17apVzGlwCYkfG3Eg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 190 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCaA4bQAfKP7YC8sQdnfykRA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 191 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC-JrEOZQwdI5nvlo-x_Oi0A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 192 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCKd9e3BrkQ-dZdalLpOEFJg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 193 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCzU8-lZlRfkV3nj0RzAZdrQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 194 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC-VToYWDckgTEhQYh3rI_Rw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 195 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCc4K7bAqpdBP8jh1j9XZAww.parquet'
#         INTO TABLE trends_youtube
#
# iteração 196 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCTa_X-4mmje4Tk0lig9t4Mw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 197 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCCgr0Hp8Rs0ynVD2tjXFnIQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 198 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCQ6byO2M8FIqqg0d4YMpwGw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 199 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCLs0R47-6DgKbPUrOW4aZrg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 200 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCXQe9ldCtjN_RP1V_c9hNUw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 201 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCaeO5vkdj5xOQHp4UmIN6dw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 202 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCr2xjaS7CIx1OY7hYwrXb8A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 203 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCRRu9OXVYd5clj2Bs29gUVQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 204 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCuUUWPHIioyfmctnDpwsFzw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 205 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCRJwDCRuD4tERaaLqUWtiAg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 206 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCj-RTZE-V3Q6jleatRR9k2A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 207 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCRkYVEDbFcX8ZE-Bxk28bYw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 208 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC2HvWg5ROXZrfBK1Wxg0ZcQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 209 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCMf_wuiFqxdhZI1GVx02mmw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 210 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCtKndmEnQyqkhOQfpi5CgvQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 211 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCm1_S0MCQYO9EWukQoAcRFA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 212 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCcCvGkfzka0pNvFxXoCs5ww.parquet'
#         INTO TABLE trends_youtube
#
# iteração 213 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC9rMiEjNaCSsebs31MRDCRA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 214 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCTTKtO5pU4OC7dqxG2bZflw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 215 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCcx4WJUVEGzr-tIyk8r3VHw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 216 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC3jOd7GUMhpgJRBhiLzuLsg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 217 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCDVAzIDnbgElNB4XCrYLvsA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 218 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC-2Y8dQb0S6DtpxNgAKoJKA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 219 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCFzNesgMSlpWPFWLMSJoetQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 220 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCOgK2xOEXxCr6GnvRyXejqw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 221 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UClGt31UbcgINSaH1ZHuFLxA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 222 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC9BAQ8a4ctfC5W88K9k-OYw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 223 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCyEHckavb7hMh5f8j4WEiIg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 224 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCDxG-MhtaQIpUXoWvDKhlEg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 225 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UChly4JLxUacQ-LgT8yR2DgA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 226 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCF8MQYobXcHejWAaet4nSxA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 227 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCqjP5TCnGhgJpLmndJhoJwg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 228 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCQaBi4mxFO87zLw2uM3-6-A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 229 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCnJoUTYXU142gxoyDzp-KRQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 230 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCaqLTryO8w6MQwpkFRVS4ow.parquet'
#         INTO TABLE trends_youtube
#
# iteração 231 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCxsqBxW8l7JT_sgpKnwx4sA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 232 --- de 371
#
# ...
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCgrFZP2B8H6pWgPL1bAqkiQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 297 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC607Gii1uo93qDqiGR6-c3w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 298 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCvI402C0VvqaGVK9gP6PjXQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 299 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCukwGwBD-pAbGzoJo6ZXPtQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 300 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCtPl3514BvY5B2DYxfJ4TmQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 301 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC-8Uff7i2h5qtIvjXJDJqYA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 302 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCkIEY6rUSPy4qQjLqBBLUSg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 303 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCn9Erjy00mpnWeLnRqhsA1g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 304 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UChMJkHCD2wdvSO7CMOuLR-w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 305 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCIRseertPt5kAzr40COpH6A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 306 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCBFLqK7PAP9DQ3JpIrWFI7w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 307 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCul9agDzTZxruNd9wEUWL7w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 308 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCLkAepWjdylmXSltofFvsYQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 309 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC12HMtO5MYph9dCZZ7yygng.parquet'
#         INTO TABLE trends_youtube
#
# iteração 310 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCnYjd7cPNluC7Hi9AZrBNMw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 311 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCqjjyPUghDSSKFBABM_CXMw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 312 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCZD5qcen7lbLPFTjfvdLFcw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 313 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCDcXzHEjw71Y5EMj13QCCpA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 314 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC0ZV6M2THA81QT9hrVWJG3A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 315 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCNuHTAjL3Y4TQD270QRM7FQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 316 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCF108KZPnFVxP8lILiJ1kng.parquet'
#         INTO TABLE trends_youtube
#
# iteração 317 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCukVuQspRmzLqHk-7lxltUQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 318 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC3RpTX6fEMJ6KBNTTgXJB9w.parquet'
#         INTO TABLE trends_youtube
#
# iteração 319 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCB_qr75-ydFVKSF9Dmo6izg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 320 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCcqcrpCct3dlF8H-3lv7sKA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 321 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCI-Q7uYhRVMxyrmcZRf0Egg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 322 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCqly9F4Fr_jf2Y1Cy5hacRg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 323 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCwM4g999Q94nkJr4gC881AA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 324 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCcqRCjHozEb9CQHwf_cffdQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 325 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCz2A8OXLR2xwYE63zWbu7IA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 326 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCYDmx2Sfpnaxg488yBpZIGg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 327 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCio9eHYbIrKYK0j71nfUEqA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 328 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCLd4dSmXdrJykO_hgOzbfPw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 329 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC-4TwmWQShd0R6YZ_HJ0NfA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 330 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCMbYwAo0KbzxYagAZ3BLhMw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 331 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCNFf1QdVK-73ZODRfpFwubg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 332 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC8Kf4sbOVvlgXAaBm8IaYKg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 333 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCwi0ZfIm4_DIt42RJoa3Qqg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 334 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCuPivVjnfNo4mb3Oog_frZg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 335 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCEUsbKNdilM6Z-HMJDpo-yQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 336 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC7iyparkdas-4UTSL_gktQg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 337 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC7RaQvO8fqoyd62RmIg_yGA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 338 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCzfyYtgvkx5mLy8nlLlayYg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 339 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCHkLdUqjUct7f4iskfqQzWQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 340 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC6LIcG7_jWgQ-9BNKzbUyOg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 341 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCsSsgPaZ2GSmO6il8Cb5iGA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 342 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCEdPGz3k0PTVXe2MsIAyzNg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 343 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCJ36g3bOCbNIEOzIluej52A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 344 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCl5i1KWUAV7hdT5_tL8l6RA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 345 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCmhx7Q1WRB85e7bF-MHcehA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 346 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCsVpgRB8YHLWA0ZrkhtHvTA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 347 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCpnI9qlEYFCFRVo2IT3jBqg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 348 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCRRy-8RPGUsC_WATzeSCuTw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 349 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCgJpIiTMqiGwNEGIALbMrNw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 350 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCYALxwppPJjYyTMEwwEcNCQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 351 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCOPi8iWwV6BkL-boz69eJ5g.parquet'
#         INTO TABLE trends_youtube
#
# iteração 352 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCX6OQ3DkcsbYNE6H8uQQuVA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 353 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC78CKlsbDeQt-zSkzvxOcsg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 354 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCKdG852wkTilD2Qyd74kgqg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 355 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC_Fk7hHbl7vv_7K8tYqJd5A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 356 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCcX_Y4AzabYwn5ORHuO_ZJw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 357 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCvhVqA_5HnM7M5X6OcZlMbg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 358 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UClE9GGSO-HMiiKQUsHyJviA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 359 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC6VcWc1rAoWdBCM0JxrRQ3A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 360 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCxwENW5gfb72OnMnRycgflA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 361 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCj9R9rOhl81fhnKxBpwJ-yw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 362 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCuD2V9FCQiDTjTLZrpoFSJA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 363 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCQEUV7le_zYKNKGmUJOwvBw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 364 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCEWHPFNilsT0IfQfutVzsag.parquet'
#         INTO TABLE trends_youtube
#
# iteração 365 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCCt8cGO1NfZgi0XO_kbsesw.parquet'
#         INTO TABLE trends_youtube
#
# iteração 366 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCgMuI-QIs-U8kNNjo4NCjRQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 367 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCN2bQLTTvNPZWCWU5TYghKA.parquet'
#         INTO TABLE trends_youtube
#
# iteração 368 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC0bC92gFO25qcJcECTQNN_A.parquet'
#         INTO TABLE trends_youtube
#
# iteração 369 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC4ncvgh5hFr5O83MH7-jRJg.parquet'
#         INTO TABLE trends_youtube
#
# iteração 370 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UC1sELGmy5jp5fQUugmuYlXQ.parquet'
#         INTO TABLE trends_youtube
#
# iteração 371 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCvO2BExvkAbGMsTGnEnI_Ng.parquet'
#         INTO TABLE trends_youtube
#
# iteração 372 --- de 371
#
#         LOAD DATA INPATH 'hdfs://localhost:9000/projeto/datalake_youtube/particao_por_campo/trends/trends_UCoHV8LxUFKeIvifJsB3c7Ww.parquet'
#         INTO TABLE trends_youtube
