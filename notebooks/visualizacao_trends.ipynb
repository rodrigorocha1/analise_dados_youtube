# %%
import pandas as pd

# %%
base_trends = pd.read_parquet('../data/ouro_csv/trends/trends_novo.parquet')

# %%
base_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29399 entries, 0 to 29398
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID_CATEGORIA            29399 non-null  int32
#  1   ID_CANAL                29399 non-null  string
#  2   NM_CANAL                29399 non-null  string
#  3   ID_VIDEO                29399 non-null  string
#  4   TITULO_VIDEO            29399 non-null  string
#  5   DURACAO                 29399 non-null  string
#  6   DESCRICAO               28676 non-null  string
#  7   TOTAL_COMENTARIOS       28472 non-null  float32
#  8   TOTAL_FAVORITOS         29399 non-null  int32
#  9   TOTAL_LIKES             28796 non-null  float32
#  10  TOTAL_VISUALIZACOES     29399 non-null  int32
#  11  DATA_EXTRACAO           29399 non-null  datetime64[ns]
#  12  HORA_EXTRACAO           29399 non-null  int32
#  13  TURNO_EXTRACAO          29399 non-null  string
# ...

# %%
round(base_trends.memory_usage(deep=True).sum() / (1024 ** 2), 2)
# Out:
# 81.45

# %%
base_trends.head()
# Out:
#    ID_CATEGORIA                  ID_CANAL            NM_CANAL     ID_VIDEO  \
# 0            20  UCHuZmQ0lSW8TG81dVZZh5rw          LipaoGamer  qvgmMih8FOc
# 1            17  UCv-Nx8pSfG_LxbViMz14RWQ  Jovem Pan Esportes  Rq1RqHl2AO0
# 2            26  UCuD2V9FCQiDTjTLZrpoFSJA     Maurício Arruda  ua1DsYjuavo
# 3            17  UCv-Nx8pSfG_LxbViMz14RWQ  Jovem Pan Esportes  l_tNmRX2DHM
# 4            24  UCvuJTWl_peL49CUfF2EAbyg       Camila Loures  sgJ6EjZjZ2k
#
#                                         TITULO_VIDEO   DURACAO  \
# 0  SPIDER MAN 2 PS5 - O inicio do jogo em MUNDO A...  PT26M59S
# 1  "CADÊ O 'PLANO' NESSE ANO?? POUCO SE FALA DISS...  PT21M28S
# 2                                  TOUR NO MEU SÍTIO  PT29M48S
# 3  "FOI UMA BOA ESTREIA! O Flamengo com o Tite fo...   PT20M7S
# 4  CONTEI QUE ESTOU GRÁVIDA PARA O MEU NAMORADO!!...  PT10M42S
#
#                                            DESCRICAO  TOTAL_COMENTARIOS  \
# ...

# %% [markdown]
# # Métricas Trends

# %% [markdown]
# - Categorias Populares por data de extração

# %%
base_categoria = base_trends.query(' ID_CATEGORIA == 20 ')
base_categoria
# Out:
#        ID_CATEGORIA                  ID_CANAL            NM_CANAL  \
# 0                20  UCHuZmQ0lSW8TG81dVZZh5rw          LipaoGamer
# 12               20  UCn26TbctVxc6mUTeSZ60_iw              MucaHD
# 19               20  UCtXXSuHUWh1-PRC7AeDB7mg             Saadhak
# 21               20  UCgWiuB2PQIUhJgEN9No281g  VALORANT // Brasil
# 30               20  UCKAdZfnAhMY9RFSD4qL4KCQ            Tigre TV
# ...             ...                       ...                 ...
# 29356            20  UCEOGSdXwcXcNfcuDGbjmgOw      Julia MineGirl
# 29368            20  UC3nU0d4kEhtljMLh2entwrw      Ana Toys games
# 29371            20  UCjBp_7RuDBUYbd1LegWEJ8g                Xbox
# 29377            20  UCDVS7-YYxiQ62r46KXmp-kw        Luluca Games
# 29385            20  UCIXguhHCl8eDTkXpEuiGPUA           Jazzghost
#
#           ID_VIDEO                                       TITULO_VIDEO  \
# 0      qvgmMih8FOc  SPIDER MAN 2 PS5 - O inicio do jogo em MUNDO A...
# ...
